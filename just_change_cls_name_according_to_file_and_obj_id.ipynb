# %%
import os, time
import xml.etree.ElementTree as ET
SEED_XML_DIR = '/media/yyp/DATA/Public_Datasets/ZENITH_DATASETS/VOCdevkit_Highway/VOC2007/Annotations/'
#OBJ_DIR = '/media/yyp/DATA/Public_Datasets/ZENITH_DATASETS/selected_obj/real_car_erro_truck_bus/'
OBJ_DIR = '/media/yyp/DATA/Public_Datasets/ZENITH_DATASETS/selected/20190704/obj/will2truck/'
#OBJ_DIR = '/media/yyp/DATA/Public_Datasets/ZENITH_DATASETS/selected_obj/real_bus_erro_truck_car/'
#OBJ_DIR = '/media/yyp/DATA/Public_Datasets/ZENITH_DATASETS/selected_obj/real_motorbike/'

GENE_XML_DIR = SEED_XML_DIR
os.system('mkdir -p ' + GENE_XML_DIR[:-1])
obj_names = os.listdir(OBJ_DIR)
obj_names.sort(reverse=False)
REAL = 'truck'
#print(seed_xml_names)
def get_obj_from_xml(xml):
    in_file = open(xml_name)
    tree=ET.parse(in_file)
    root = tree.getroot()
    return [obj for obj in root.iter('object')]
def get_cls_from_xmlobj(obj_element):    
    return obj_element.find('name').text

def get_bbox_from_xmlobj(obj_element):
    xmlbox = obj_element.find('bndbox')
    return [float(xmlbox.find('xmin').text), float(xmlbox.find('xmax').text), 
            float(xmlbox.find('ymin').text), float(xmlbox.find('ymax').text)]

for obj in obj_names:
    if(not obj.endswith('.jpg')):
        continue
    #parse xml name and obj id
    print(obj)
    str_list = obj.split('_')[:-5]
    xml_id = '_'.join(str_list)

    xml_name = xml_id + '.xml'
    obj_id = obj.split('_')[-1][:-4]
    #print(xml_name)
    #print(obj_id)
    #continue
    #break
    in_file = open(SEED_XML_DIR + xml_name)
    tree=ET.parse(in_file)
    root = tree.getroot()

    i = 0
    for obj in root.iter('object'):      
        if(i < int(obj_id)):
            i = i+1
            continue
        cls = obj.find('name').text
        bbox = get_bbox_from_xmlobj(obj)
        print(cls)
        print(bbox)
        obj.find('name').text = REAL        
        tree.write(GENE_XML_DIR + xml_name)
        print('xml {0} changed'.format(xml_name))
        break
# Out:
# 00000054035_458.0_583.0_434.0_592.0_15.jpg
# bus
# [458.0, 583.0, 434.0, 592.0]
# xml 00000054035.xml changed
# 00000054357_31.0_374.0_766.0_1078.0_15.jpg
# bus
# [31.0, 374.0, 766.0, 1078.0]
# xml 00000054357.xml changed
# 00000054398_389.0_632.0_578.0_1067.0_19.jpg
# bus
# [389.0, 632.0, 578.0, 1067.0]
# xml 00000054398.xml changed
# 00000054470_532.0_649.0_534.0_679.0_4.jpg
# bus
# [532.0, 649.0, 534.0, 679.0]
# xml 00000054470.xml changed
# 00000054630_1117.0_1379.0_699.0_1007.0_19.jpg
# bus
# [1117.0, 1379.0, 699.0, 1007.0]
# xml 00000054630.xml changed
# 00000054986_447.0_587.0_413.0_619.0_11.jpg
# bus
# [447.0, 587.0, 413.0, 619.0]
# xml 00000054986.xml changed
# 00000056032_1246.0_1544.0_461.0_717.0_30.jpg
# bus
# [1246.0, 1544.0, 461.0, 717.0]
# xml 00000056032.xml changed
# 00000056033_1223.0_1496.0_427.0_702.0_24.jpg
# bus
# [1223.0, 1496.0, 427.0, 702.0]
# xml 00000056033.xml changed
# 00000056036_1697.0_1914.0_765.0_1050.0_28.jpg
# bus
# [1697.0, 1914.0, 765.0, 1050.0]
# xml 00000056036.xml changed
# 00000056044_1263.0_1428.0_522.0_670.0_28.jpg
# bus
# [1263.0, 1428.0, 522.0, 670.0]
# xml 00000056044.xml changed
# 00000056059_1550.0_1920.0_671.0_1080.0_29.jpg
# bus
# [1550.0, 1920.0, 671.0, 1080.0]
# xml 00000056059.xml changed
# 00000056075_1573.0_1889.0_794.0_1045.0_21.jpg
# bus
# [1573.0, 1889.0, 794.0, 1045.0]
# xml 00000056075.xml changed
# 00000056160_1304.0_1639.0_681.0_966.0_25.jpg
# bus
# [1304.0, 1639.0, 681.0, 966.0]
# xml 00000056160.xml changed
# 00000056173_359.0_511.0_546.0_777.0_24.jpg
# bus
# [359.0, 511.0, 546.0, 777.0]
# xml 00000056173.xml changed
# 00000056301_348.0_486.0_559.0_754.0_25.jpg
# bus
# [348.0, 486.0, 559.0, 754.0]
# xml 00000056301.xml changed
# 00000056309_421.0_581.0_431.0_657.0_23.jpg
# bus
# [421.0, 581.0, 431.0, 657.0]
# xml 00000056309.xml changed
# 00000056310_387.0_560.0_460.0_709.0_16.jpg
# bus
# [387.0, 560.0, 460.0, 709.0]
# xml 00000056310.xml changed
# 00000056312_269.0_537.0_505.0_898.0_24.jpg
# bus
# [269.0, 537.0, 505.0, 898.0]
# xml 00000056312.xml changed
# 00000056462_320.0_486.0_582.0_799.0_21.jpg
# bus
# [320.0, 486.0, 582.0, 799.0]
# xml 00000056462.xml changed
# 00000056612_1351.0_1655.0_573.0_766.0_20.jpg
# bus
# [1351.0, 1655.0, 573.0, 766.0]
# xml 00000056612.xml changed
# 00000056759_497.0_674.0_491.0_776.0_26.jpg
# bus
# [497.0, 674.0, 491.0, 776.0]
# xml 00000056759.xml changed
# 00000056937_409.0_566.0_443.0_669.0_19.jpg
# bus
# [409.0, 566.0, 443.0, 669.0]
# xml 00000056937.xml changed
# 00000058096_857.0_1081.0_724.0_1071.0_20.jpg
# bus
# [857.0, 1081.0, 724.0, 1071.0]
# xml 00000058096.xml changed
# 00000058152_762.0_936.0_531.0_798.0_28.jpg
# bus
# [762.0, 936.0, 531.0, 798.0]
# xml 00000058152.xml changed
# 00000058304_895.0_1217.0_812.0_1080.0_33.jpg
# bus
# [895.0, 1217.0, 812.0, 1080.0]
# xml 00000058304.xml changed
# 00000058325_891.0_1051.0_369.0_678.0_19.jpg
# bus
# [891.0, 1051.0, 369.0, 678.0]
# xml 00000058325.xml changed
# 00000058722_558.0_830.0_566.0_895.0_14.jpg
# bus
# [558.0, 830.0, 566.0, 895.0]
# xml 00000058722.xml changed
# 00000058765_868.0_1043.0_438.0_664.0_18.jpg
# bus
# [868.0, 1043.0, 438.0, 664.0]
# xml 00000058765.xml changed
# 00000060648_463.0_632.0_603.0_879.0_18.jpg
# bus
# [463.0, 632.0, 603.0, 879.0]
# xml 00000060648.xml changed
# 00000061005_1368.0_1655.0_639.0_912.0_11.jpg
# bus
# [1368.0, 1655.0, 639.0, 912.0]
# xml 00000061005.xml changed
# 00000062082_420.0_563.0_438.0_624.0_5.jpg
# bus
# [420.0, 563.0, 438.0, 624.0]
# xml 00000062082.xml changed
# 00000062090_709.0_873.0_738.0_994.0_1.jpg
# bus
# [709.0, 873.0, 738.0, 994.0]
# xml 00000062090.xml changed
# 00000062446_503.0_695.0_473.0_809.0_5.jpg
# bus
# [503.0, 695.0, 473.0, 809.0]
# xml 00000062446.xml changed
# 00000201476_291.0_367.0_282.0_375.0_4.jpg
# bus
# [291.0, 367.0, 282.0, 375.0]
# xml 00000201476.xml changed
# 00000201971_350.0_440.0_355.0_444.0_2.jpg
# bus
# [350.0, 440.0, 355.0, 444.0]
# xml 00000201971.xml changed
