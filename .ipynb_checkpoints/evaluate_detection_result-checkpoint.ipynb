# %%
import sys,os,datetime
import cv2
import xml.etree.ElementTree as ET
from PIL import Image
import numpy as np
import random
#from pathlib import Path

from ctypes import *
import math
#cv2_root = "/usr/local/lib-bk/python2.7/dist-packages/cv2"
#sys.path.insert(0,cv2_root)
#cv2_lib_avcodec = "/usr/lib/x86_64-linux-gnu/bkavcodec"
#sys.path.insert(0,cv2_lib_avcodec)

time_str = (datetime.datetime.now()).strftime("%Y%m%d")
f = open("/media/yyp/DATA/Public_Datasets/ZENITH_DATASETS/2007_val.txt", 'r')
data = f.readlines()
seed_xml_names = []
GENE_XML_DIR = '/data/darknet/python/' + time_str + '_detection_result/'
GENE_XML_DIR = '/data/darknet/python/' + time_str + '_detection_result_864/'
for line in data:
    #print line
    xml_name = line.replace('JPEGImages', 'Annotations')
    xml_name = line.replace('.jpg', '.xml')
    seed_xml_names.append(xml_name)
    
'''
data_file = '/data/darknet/cfg/coco.data'
cfg_file = '/data/darknet/cfg/yolov3-nob-288.cfg'
weights_file = '/data/weights/header_int_aaa_yolov3.weights'
'''

#weights_file = '/data/darknet/weights/yolov3-tiny-ncs-without-last-maxpool-refined-anchors_120000.weights'
seed_xml_names.sort()

# %%
def sample(probs):
    s = sum(probs)
    probs = [a/s for a in probs]
    r = random.uniform(0, 1)
    for i in range(len(probs)):
        r = r - probs[i]
        if r <= 0:
            return i
    return len(probs)-1

def c_array(ctype, values):
    arr = (ctype*len(values))()
    arr[:] = values
    return arr

class BOX(Structure):
    _fields_ = [("x", c_float),
                ("y", c_float),
                ("w", c_float),
                ("h", c_float)]

class DETECTION(Structure):
    _fields_ = [("bbox", BOX),
                ("classes", c_int),
                ("prob", POINTER(c_float)),
                ("mask", POINTER(c_float)),
                ("objectness", c_float),
                ("sort_class", c_int)]


class IMAGE(Structure):
    _fields_ = [("w", c_int),
                ("h", c_int),
                ("c", c_int),
                ("data", POINTER(c_float))]

class METADATA(Structure):
    _fields_ = [("classes", c_int),
                ("names", POINTER(c_char_p))]
    
def classify(net, meta, im):
    out = predict_image(net, im)
    res = []
    for i in range(meta.classes):
        res.append((meta.names[i], out[i]))
    res = sorted(res, key=lambda x: -x[1])
    return res

def detect(net, meta, image, thresh=.5, hier_thresh=.5, nms=.45):
    im = load_image(image, 0, 0)
    num = c_int(0)
    pnum = pointer(num)
    predict_image(net, im)
    dets = get_network_boxes(net, im.w, im.h, thresh, hier_thresh, None, 0, pnum)
    num = pnum[0]
    if (nms): do_nms_obj(dets, num, meta.classes, nms);

    res = []
    for j in range(num):
        for i in range(meta.classes):
            if dets[j].prob[i] > 0:
                b = dets[j].bbox
                res.append((meta.names[i], dets[j].prob[i], (b.x, b.y, b.w, b.h)))
    res = sorted(res, key=lambda x: -x[1])
    free_image(im)
    free_detections(dets, num)
    return res
#lib = CDLL("/home/pjreddie/documents/darknet/libdarknet.so", RTLD_GLOBAL)
lib = CDLL("/data/darknet/libdarknet.so", RTLD_GLOBAL)
lib.network_width.argtypes = [c_void_p]
lib.network_width.restype = c_int
lib.network_height.argtypes = [c_void_p]
lib.network_height.restype = c_int

predict = lib.network_predict
predict.argtypes = [c_void_p, POINTER(c_float)]
predict.restype = POINTER(c_float)

set_gpu = lib.cuda_set_device
set_gpu.argtypes = [c_int]

make_image = lib.make_image
make_image.argtypes = [c_int, c_int, c_int]
make_image.restype = IMAGE

get_network_boxes = lib.get_network_boxes
get_network_boxes.argtypes = [c_void_p, c_int, c_int, c_float, c_float, POINTER(c_int), c_int, POINTER(c_int)]
get_network_boxes.restype = POINTER(DETECTION)

make_network_boxes = lib.make_network_boxes
make_network_boxes.argtypes = [c_void_p]
make_network_boxes.restype = POINTER(DETECTION)

free_detections = lib.free_detections
free_detections.argtypes = [POINTER(DETECTION), c_int]

free_ptrs = lib.free_ptrs
free_ptrs.argtypes = [POINTER(c_void_p), c_int]

network_predict = lib.network_predict
network_predict.argtypes = [c_void_p, POINTER(c_float)]

reset_rnn = lib.reset_rnn
reset_rnn.argtypes = [c_void_p]

load_net = lib.load_network
load_net.argtypes = [c_char_p, c_char_p, c_int]
load_net.restype = c_void_p

do_nms_obj = lib.do_nms_obj
do_nms_obj.argtypes = [POINTER(DETECTION), c_int, c_int, c_float]

do_nms_sort = lib.do_nms_sort
do_nms_sort.argtypes = [POINTER(DETECTION), c_int, c_int, c_float]

free_image = lib.free_image
free_image.argtypes = [IMAGE]

letterbox_image = lib.letterbox_image
letterbox_image.argtypes = [IMAGE, c_int, c_int]
letterbox_image.restype = IMAGE

load_meta = lib.get_metadata
lib.get_metadata.argtypes = [c_char_p]
lib.get_metadata.restype = METADATA

load_image = lib.load_image_color
load_image.argtypes = [c_char_p, c_int, c_int]
load_image.restype = IMAGE

rgbgr_image = lib.rgbgr_image
rgbgr_image.argtypes = [IMAGE]

predict_image = lib.network_predict_image
predict_image.argtypes = [c_void_p, IMAGE]
predict_image.restype = POINTER(c_float)

# %%
data_file = '/data/darknet/cfg/voc-veichle.data'

all_wieghts_dir = '/media/yyp/DATA/EVALUATE/'
weights = os.listdir(all_wieghts_dir)
weights.sort()
for weight in weights:
    if(not weight.endswith('.weights')):
        continue
    cfg_file = all_wieghts_dir + weight[:-len(weight.split('_')[-1])] + 'test.cfg'
    generated_xml_dir = GENE_XML_DIR + weight.split('.weights')[0] + '/'
    #os.system('rm -rf ' + GENE_XML_DIR)
    os.system('mkdir -p ' + generated_xml_dir)
    weights_file = all_wieghts_dir + weight
    net = load_net(cfg_file, weights_file, 0)
    meta = load_meta(data_file)
    for image_file in data:
        image = image_file.split('/')[-1]
        image = image[:-1]
        image_file = image_file[:-1]
        ret = image_file.endswith('.jpg')
        if ret == False:
            print('+++++++++++')
            continue
        #print('detect')
        r = detect(net, meta, image_file, 0.3, 0.5, 0.75)
        #print(len(r))

        origimg = cv2.imread(image_file)
        height = origimg.shape[0]
        width = origimg.shape[1]
        depth = origimg.shape[2]

        xml_str = "<annotation>\n\t\
        <folder>image</folder>\n\t\
        <filename>" + image + "</filename>\n\t\
        " + "<path>" + image_file + "</path>\n\t\
        <source>\n\t\t\
        <database>Unknown</database>\n\t\
        </source>\n\t\
        <size>\n\t\t\
        <width>" + str(width) + "</width>\n\t\t\
        <height>" + str(height) + "</height>\n\t\t\
        <depth>" + str(depth) + "</depth>\n\t\
        </size>\n\t\
        <segmented>0</segmented>"
        #print(xml_str)
        found_flag = False
        for i in range(len(r)):
            cls = r[i][0]
            #print(cls)
            if(cls not in ['bus','car','truck', 'motorbike','bicycle','person', 'B', 'C', 'T']):
            #if(cls not in ['person', 'motorbike','bicycle']):
                continue
            found_flag = True
            score = r[i][1]
            bbox = r[i][2]

            x1 = max(0, (bbox[0] - bbox[2]/2))
            y1 = max(0, (bbox[1] - bbox[3]/2))
            x2 = min(width, (bbox[0] + bbox[2]/2))
            y2 = min(height, (bbox[1] + bbox[3]/2))      

            p1 = (int(x1), int(y1))
            p2 = (int(x2), int(y2))

            obj_str = "\n\t\
            <object>\n\t\t\
            <name>" + cls + "</name>\n\t\t\
            <pose>Unspecified</pose>\n\t\t\
            <truncated>0</truncated>\n\t\t\
            <difficult>0</difficult>\n\t\t\
            <bndbox>\n\t\t\t\
            <xmin>" + str(int(x1)) + "</xmin>\n\t\t\t\
            <ymin>" + str(int(y1)) + "</ymin>\n\t\t\t\
            <xmax>" + str(int(x2)) + "</xmax>\n\t\t\t\
            <ymax>" + str(int(y2)) + "</ymax>\n\t\t\
            </bndbox>\n\t\
            </object>"

            xml_str += obj_str

            cv2.rectangle(origimg, p1, p2, (0,255,0))
            p3 = (max(p1[0], 15), max(p1[1], 15))
            title = "%s:%.2f" % (cls, score)
            cv2.putText(origimg, title, p3, cv2.FONT_ITALIC, 0.6, (0, 255, 0), 1)
        xml_str += "\n</annotation>"
        #print('found_flag {0}'.format(found_flag))
        if (not found_flag):
            continue
        fileObject = open(generated_xml_dir + image[:-4] + '.xml', 'w')  
        fileObject.write(xml_str)
        fileObject.close()
        #cv2.imwrite('/data/'+ image_file.split('/')[-1], origimg)
        print("Created : " + generated_xml_dir + image[:-4] + '.xml')
# Out:
# Created : /data/darknet/python/20190529_detection_result/yolov3-tiny-ncs-without-last-maxpool-refined-anchors-3cls-extend-remove-maxpooling_10000/00000070003.xml
# Created : /data/darknet/python/20190529_detection_result/yolov3-tiny-ncs-without-last-maxpool-refined-anchors-3cls-extend-remove-maxpooling_10000/00000070010.xml
# Created : /data/darknet/python/20190529_detection_result/yolov3-tiny-ncs-without-last-maxpool-refined-anchors-3cls-extend-remove-maxpooling_10000/00000070020.xml
# Created : /data/darknet/python/20190529_detection_result/yolov3-tiny-ncs-without-last-maxpool-refined-anchors-3cls-extend-remove-maxpooling_10000/00000070059.xml
# Created : /data/darknet/python/20190529_detection_result/yolov3-tiny-ncs-without-last-maxpool-refined-anchors-3cls-extend-remove-maxpooling_10000/00000070035.xml
# Created : /data/darknet/python/20190529_detection_result/yolov3-tiny-ncs-without-last-maxpool-refined-anchors-3cls-extend-remove-maxpooling_10000/00000070089.xml
# Created : /data/darknet/python/20190529_detection_result/yolov3-tiny-ncs-without-last-maxpool-refined-anchors-3cls-extend-remove-maxpooling_10000/00000070520.xml
# Created : /data/darknet/python/20190529_detection_result/yolov3-tiny-ncs-without-last-maxpool-refined-anchors-3cls-extend-remove-maxpooling_10000/00000070538.xml
# Created : /data/darknet/python/20190529_detection_result/yolov3-tiny-ncs-without-last-maxpool-refined-anchors-3cls-extend-remove-maxpooling_10000/00000070085.xml
# Created : /data/darknet/python/20190529_detection_result/yolov3-tiny-ncs-without-last-maxpool-refined-anchors-3cls-extend-remove-maxpooling_10000/00000070091.xml
# Created : /data/darknet/python/20190529_detection_result/yolov3-tiny-ncs-without-last-maxpool-refined-anchors-3cls-extend-remove-maxpooling_10000/00000070095.xml
# Created : /data/darknet/python/20190529_detection_result/yolov3-tiny-ncs-without-last-maxpool-refined-anchors-3cls-extend-remove-maxpooling_10000/00000070098.xml
# Created : /data/darknet/python/20190529_detection_result/yolov3-tiny-ncs-without-last-maxpool-refined-anchors-3cls-extend-remove-maxpooling_10000/00000070100.xml
# Created : /data/darknet/python/20190529_detection_result/yolov3-tiny-ncs-without-last-maxpool-refined-anchors-3cls-extend-remove-maxpooling_10000/00000070225.xml
# Created : /data/darknet/python/20190529_detection_result/yolov3-tiny-ncs-without-last-maxpool-refined-anchors-3cls-extend-remove-maxpooling_10000/00000070228.xml
# Created : /data/darknet/python/20190529_detection_result/yolov3-tiny-ncs-without-last-maxpool-refined-anchors-3cls-extend-remove-maxpooling_10000/00000070233.xml
# Created : /data/darknet/python/20190529_detection_result/yolov3-tiny-ncs-without-last-maxpool-refined-anchors-3cls-extend-remove-maxpooling_10000/00000070243.xml
# Created : /data/darknet/python/20190529_detection_result/yolov3-tiny-ncs-without-last-maxpool-refined-anchors-3cls-extend-remove-maxpooling_10000/00000070250.xml
# Created : /data/darknet/python/20190529_detection_result/yolov3-tiny-ncs-without-last-maxpool-refined-anchors-3cls-extend-remove-maxpooling_10000/00000070254.xml
# Created : /data/darknet/python/20190529_detection_result/yolov3-tiny-ncs-without-last-maxpool-refined-anchors-3cls-extend-remove-maxpooling_10000/00000070327.xml
# Created : /data/darknet/python/20190529_detection_result/yolov3-tiny-ncs-without-last-maxpool-refined-anchors-3cls-extend-remove-maxpooling_10000/00000070332.xml
# Created : /data/darknet/python/20190529_detection_result/yolov3-tiny-ncs-without-last-maxpool-refined-anchors-3cls-extend-remove-maxpooling_10000/00000070337.xml
# Created : /data/darknet/python/20190529_detection_result/yolov3-tiny-ncs-without-last-maxpool-refined-anchors-3cls-extend-remove-maxpooling_10000/00000070353.xml
# Created : /data/darknet/python/20190529_detection_result/yolov3-tiny-ncs-without-last-maxpool-refined-anchors-3cls-extend-remove-maxpooling_10000/00000070355.xml
# Created : /data/darknet/python/20190529_detection_result/yolov3-tiny-ncs-without-last-maxpool-refined-anchors-3cls-extend-remove-maxpooling_10000/00000070364.xml
# Created : /data/darknet/python/20190529_detection_result/yolov3-tiny-ncs-without-last-maxpool-refined-anchors-3cls-extend-remove-maxpooling_10000/00000070365.xml
# Created : /data/darknet/python/20190529_detection_result/yolov3-tiny-ncs-without-last-maxpool-refined-anchors-3cls-extend-remove-maxpooling_10000/00000070369.xml
# Created : /data/darknet/python/20190529_detection_result/yolov3-tiny-ncs-without-last-maxpool-refined-anchors-3cls-extend-remove-maxpooling_10000/00000070379.xml
# Created : /data/darknet/python/20190529_detection_result/yolov3-tiny-ncs-without-last-maxpool-refined-anchors-3cls-extend-remove-maxpooling_10000/00000070382.xml
# Created : /data/darknet/python/20190529_detection_result/yolov3-tiny-ncs-without-last-maxpool-refined-anchors-3cls-extend-remove-maxpooling_10000/00000070387.xml
# Created : /data/darknet/python/20190529_detection_result/yolov3-tiny-ncs-without-last-maxpool-refined-anchors-3cls-extend-remove-maxpooling_10000/00000070513.xml
# Created : /data/darknet/python/20190529_detection_result/yolov3-tiny-ncs-without-last-maxpool-refined-anchors-3cls-extend-remove-maxpooling_10000/00000070522.xml
# Created : /data/darknet/python/20190529_detection_result/yolov3-tiny-ncs-without-last-maxpool-refined-anchors-3cls-extend-remove-maxpooling_10000/00000070528.xml
# Created : /data/darknet/python/20190529_detection_result/yolov3-tiny-ncs-without-last-maxpool-refined-anchors-3cls-extend-remove-maxpooling_10000/00000070543.xml
# Created : /data/darknet/python/20190529_detection_result/yolov3-tiny-ncs-without-last-maxpool-refined-anchors-3cls-extend-remove-maxpooling_10000/00000070549.xml
# Created : /data/darknet/python/20190529_detection_result/yolov3-tiny-ncs-without-last-maxpool-refined-anchors-3cls-extend-remove-maxpooling_10000/00000070602.xml
# Created : /data/darknet/python/20190529_detection_result/yolov3-tiny-ncs-without-last-maxpool-refined-anchors-3cls-extend-remove-maxpooling_10000/00000070605.xml
# Created : /data/darknet/python/20190529_detection_result/yolov3-tiny-ncs-without-last-maxpool-refined-anchors-3cls-extend-remove-maxpooling_10000/00000070606.xml
# Created : /data/darknet/python/20190529_detection_result/yolov3-tiny-ncs-without-last-maxpool-refined-anchors-3cls-extend-remove-maxpooling_10000/00000070611.xml
# Created : /data/darknet/python/20190529_detection_result/yolov3-tiny-ncs-without-last-maxpool-refined-anchors-3cls-extend-remove-maxpooling_10000/00000070616.xml
# Created : /data/darknet/python/20190529_detection_result/yolov3-tiny-ncs-without-last-maxpool-refined-anchors-3cls-extend-remove-maxpooling_10000/00000070640.xml
# Created : /data/darknet/python/20190529_detection_result/yolov3-tiny-ncs-without-last-maxpool-refined-anchors-3cls-extend-remove-maxpooling_10000/00000070647.xml
# Created : /data/darknet/python/20190529_detection_result/yolov3-tiny-ncs-without-last-maxpool-refined-anchors-3cls-extend-remove-maxpooling_10000/00000070649.xml
# Created : /data/darknet/python/20190529_detection_result/yolov3-tiny-ncs-without-last-maxpool-refined-anchors-3cls-extend-remove-maxpooling_10000/00000070650.xml
# Created : /data/darknet/python/20190529_detection_result/yolov3-tiny-ncs-without-last-maxpool-refined-anchors-3cls-extend-remove-maxpooling_10000/00000070705.xml
# Created : /data/darknet/python/20190529_detection_result/yolov3-tiny-ncs-without-last-maxpool-refined-anchors-3cls-extend-remove-maxpooling_10000/00000070713.xml
# Created : /data/darknet/python/20190529_detection_result/yolov3-tiny-ncs-without-last-maxpool-refined-anchors-3cls-extend-remove-maxpooling_10000/00000070721.xml
# Created : /data/darknet/python/20190529_detection_result/yolov3-tiny-ncs-without-last-maxpool-refined-anchors-3cls-extend-remove-maxpooling_10000/00000070725.xml
# Created : /data/darknet/python/20190529_detection_result/yolov3-tiny-ncs-without-last-maxpool-refined-anchors-3cls-extend-remove-maxpooling_10000/00000070730.xml
# Created : /data/darknet/python/20190529_detection_result/yolov3-tiny-ncs-without-last-maxpool-refined-anchors-3cls-extend-remove-maxpooling_10000/00000070733.xml
# Created : /data/darknet/python/20190529_detection_result/yolov3-tiny-ncs-without-last-maxpool-refined-anchors-3cls-extend-remove-maxpooling_10000/00000070737.xml
# Created : /data/darknet/python/20190529_detection_result/yolov3-tiny-ncs-without-last-maxpool-refined-anchors-3cls-extend-remove-maxpooling_10000/00000070744.xml
# Created : /data/darknet/python/20190529_detection_result/yolov3-tiny-ncs-without-last-maxpool-refined-anchors-3cls-extend-remove-maxpooling_10000/00000070758.xml
# Created : /data/darknet/python/20190529_detection_result/yolov3-tiny-ncs-without-last-maxpool-refined-anchors-3cls-extend-remove-maxpooling_10000/00000070759.xml
# Created : /data/darknet/python/20190529_detection_result/yolov3-tiny-ncs-without-last-maxpool-refined-anchors-3cls-extend-remove-maxpooling_10000/00000070766.xml
# Created : /data/darknet/python/20190529_detection_result/yolov3-tiny-ncs-without-last-maxpool-refined-anchors-3cls-extend-remove-maxpooling_10000/00000070771.xml
# Created : /data/darknet/python/20190529_detection_result/yolov3-tiny-ncs-without-last-maxpool-refined-anchors-3cls-extend-remove-maxpooling_10000/00000070796.xml
# Created : /data/darknet/python/20190529_detection_result/yolov3-tiny-ncs-without-last-maxpool-refined-anchors-3cls-extend-remove-maxpooling_10000/00000070812.xml
# Created : /data/darknet/python/20190529_detection_result/yolov3-tiny-ncs-without-last-maxpool-refined-anchors-3cls-extend-remove-maxpooling_10000/00000070814.xml
# Created : /data/darknet/python/20190529_detection_result/yolov3-tiny-ncs-without-last-maxpool-refined-anchors-3cls-extend-remove-maxpooling_10000/00000070832.xml
# Created : /data/darknet/python/20190529_detection_result/yolov3-tiny-ncs-without-last-maxpool-refined-anchors-3cls-extend-remove-maxpooling_10000/00000070834.xml
# Created : /data/darknet/python/20190529_detection_result/yolov3-tiny-ncs-without-last-maxpool-refined-anchors-3cls-extend-remove-maxpooling_10000/00000070839.xml
# Created : /data/darknet/python/20190529_detection_result/yolov3-tiny-ncs-without-last-maxpool-refined-anchors-3cls-extend-remove-maxpooling_10000/00000070849.xml
# Created : /data/darknet/python/20190529_detection_result/yolov3-tiny-ncs-without-last-maxpool-refined-anchors-3cls-extend-remove-maxpooling_10000/00000070874.xml
# Created : /data/darknet/python/20190529_detection_result/yolov3-tiny-ncs-without-last-maxpool-refined-anchors-3cls-extend-remove-maxpooling_10000/00000070881.xml
# Created : /data/darknet/python/20190529_detection_result/yolov3-tiny-ncs-without-last-maxpool-refined-anchors-3cls-extend-remove-maxpooling_10000/00000070887.xml
# Created : /data/darknet/python/20190529_detection_result/yolov3-tiny-ncs-without-last-maxpool-refined-anchors-3cls-extend-remove-maxpooling_10000/00000070893.xml
# Created : /data/darknet/python/20190529_detection_result/yolov3-tiny-ncs-without-last-maxpool-refined-anchors-3cls-extend-remove-maxpooling_10000/00000070903.xml
# Created : /data/darknet/python/20190529_detection_result/yolov3-tiny-ncs-without-last-maxpool-refined-anchors-3cls-extend-remove-maxpooling_10000/00000070905.xml
# Created : /data/darknet/python/20190529_detection_result/yolov3-tiny-ncs-without-last-maxpool-refined-anchors-3cls-extend-remove-maxpooling_10000/00000070915.xml
# Created : /data/darknet/python/20190529_detection_result/yolov3-tiny-ncs-without-last-maxpool-refined-anchors-3cls-extend-remove-maxpooling_10000/00000070916.xml
# Created : /data/darknet/python/20190529_detection_result/yolov3-tiny-ncs-without-last-maxpool-refined-anchors-3cls-extend-remove-maxpooling_10000/00000070929.xml
# Created : /data/darknet/python/20190529_detection_result/yolov3-tiny-ncs-without-last-maxpool-refined-anchors-3cls-extend-remove-maxpooling_10000/00000070947.xml
# Created : /data/darknet/python/20190529_detection_result/yolov3-tiny-ncs-without-last-maxpool-refined-anchors-3cls-extend-remove-maxpooling_10000/00000070950.xml
# Created : /data/darknet/python/20190529_detection_result/yolov3-tiny-ncs-without-last-maxpool-refined-anchors-3cls-extend-remove-maxpooling_10000/0001009.xml
# Created : /data/darknet/python/20190529_detection_result/yolov3-tiny-ncs-without-last-maxpool-refined-anchors-3cls-extend-remove-maxpooling_10000/0001016.xml
# Created : /data/darknet/python/20190529_detection_result/yolov3-tiny-ncs-without-last-maxpool-refined-anchors-3cls-extend-remove-maxpooling_10000/0002003.xml
# Created : /data/darknet/python/20190529_detection_result/yolov3-tiny-ncs-without-last-maxpool-refined-anchors-3cls-extend-remove-maxpooling_10000/0002009.xml
# Created : /data/darknet/python/20190529_detection_result/yolov3-tiny-ncs-without-last-maxpool-refined-anchors-3cls-extend-remove-maxpooling_10000/0002030.xml
# Created : /data/darknet/python/20190529_detection_result/yolov3-tiny-ncs-without-last-maxpool-refined-anchors-3cls-extend-remove-maxpooling_10000/20190527113212527169_0000006.xml
# Created : /data/darknet/python/20190529_detection_result/yolov3-tiny-ncs-without-last-maxpool-refined-anchors-3cls-extend-remove-maxpooling_10000/20190527113321162257_00000070021.xml
# Created : /data/darknet/python/20190529_detection_result/yolov3-tiny-ncs-without-last-maxpool-refined-anchors-3cls-extend-remove-maxpooling_10000/20190527113417280125_00000070040.xml
# Created : /data/darknet/python/20190529_detection_result/yolov3-tiny-ncs-without-last-maxpool-refined-anchors-3cls-extend-remove-maxpooling_10000/20190527113514419412_00000070062.xml
# Created : /data/darknet/python/20190529_detection_result/yolov3-tiny-ncs-without-last-maxpool-refined-anchors-3cls-extend-remove-maxpooling_10000/20190527113526971826_00000070067.xml
# Created : /data/darknet/python/20190529_detection_result/yolov3-tiny-ncs-without-last-maxpool-refined-anchors-3cls-extend-remove-maxpooling_10000/20190527113545859577_00000070074.xml
# Created : /data/darknet/python/20190529_detection_result/yolov3-tiny-ncs-without-last-maxpool-refined-anchors-3cls-extend-remove-maxpooling_10000/20190527113627469657_00000070091.xml
# Created : /data/darknet/python/20190529_detection_result/yolov3-tiny-ncs-without-last-maxpool-refined-anchors-3cls-extend-remove-maxpooling_10000/20190527113632213401_00000070093.xml
# Created : /data/darknet/python/20190529_detection_result/yolov3-tiny-ncs-without-last-maxpool-refined-anchors-3cls-extend-remove-maxpooling_10000/20190527113637210350_00000070095.xml
# Created : /data/darknet/python/20190529_detection_result/yolov3-tiny-ncs-without-last-maxpool-refined-anchors-3cls-extend-remove-maxpooling_10000/20190527113647475071_00000070099.xml
# Created : /data/darknet/python/20190529_detection_result/yolov3-tiny-ncs-without-last-maxpool-refined-anchors-3cls-extend-remove-maxpooling_10000/20190527113653625964_00000070222.xml
# Created : /data/darknet/python/20190529_detection_result/yolov3-tiny-ncs-without-last-maxpool-refined-anchors-3cls-extend-remove-maxpooling_10000/20190527113656483681_00000070224.xml
# Created : /data/darknet/python/20190529_detection_result/yolov3-tiny-ncs-without-last-maxpool-refined-anchors-3cls-extend-remove-maxpooling_10000/20190527113704031275_00000070229.xml
# Created : /data/darknet/python/20190529_detection_result/yolov3-tiny-ncs-without-last-maxpool-refined-anchors-3cls-extend-remove-maxpooling_10000/20190527113714812629_00000070236.xml
# Created : /data/darknet/python/20190529_detection_result/yolov3-tiny-ncs-without-last-maxpool-refined-anchors-3cls-extend-remove-maxpooling_10000/20190527113751456353_00000070258.xml
# Created : /data/darknet/python/20190529_detection_result/yolov3-tiny-ncs-without-last-maxpool-refined-anchors-3cls-extend-remove-maxpooling_10000/20190527113755033830_00000070260.xml
# Created : /data/darknet/python/20190529_detection_result/yolov3-tiny-ncs-without-last-maxpool-refined-anchors-3cls-extend-remove-maxpooling_10000/20190527113447119680_00000070051.xml
# Created : /data/darknet/python/20190529_detection_result/yolov3-tiny-ncs-without-last-maxpool-refined-anchors-3cls-extend-remove-maxpooling_10000/20190527113806789878_00000070269.xml
# Created : /data/darknet/python/20190529_detection_result/yolov3-tiny-ncs-without-last-maxpool-refined-anchors-3cls-extend-remove-maxpooling_10000/20190527113811825236_00000070324.xml
# Created : /data/darknet/python/20190529_detection_result/yolov3-tiny-ncs-without-last-maxpool-refined-anchors-3cls-extend-remove-maxpooling_10000/20190527113825592758_00000070335.xml
# Created : /data/darknet/python/20190529_detection_result/yolov3-tiny-ncs-without-last-maxpool-refined-anchors-3cls-extend-remove-maxpooling_10000/20190527113903357896_00000070367.xml
# Created : /data/darknet/python/20190529_detection_result/yolov3-tiny-ncs-without-last-maxpool-refined-anchors-3cls-extend-remove-maxpooling_10000/20190527113921107603_00000070381.xml
# Created : /data/darknet/python/20190529_detection_result/yolov3-tiny-ncs-without-last-maxpool-refined-anchors-3cls-extend-remove-maxpooling_10000/20190527113939340471_00000070395.xml
# Created : /data/darknet/python/20190529_detection_result/yolov3-tiny-ncs-without-last-maxpool-refined-anchors-3cls-extend-remove-maxpooling_10000/20190527114028541750_00000070503.xml
# Created : /data/darknet/python/20190529_detection_result/yolov3-tiny-ncs-without-last-maxpool-refined-anchors-3cls-extend-remove-maxpooling_10000/20190527114349343702_00000070521.xml
# Created : /data/darknet/python/20190529_detection_result/yolov3-tiny-ncs-without-last-maxpool-refined-anchors-3cls-extend-remove-maxpooling_10000/20190527114407352134_00000070523.xml
# Created : /data/darknet/python/20190529_detection_result/yolov3-tiny-ncs-without-last-maxpool-refined-anchors-3cls-extend-remove-maxpooling_10000/20190527114556860499_00000070534.xml
# Created : /data/darknet/python/20190529_detection_result/yolov3-tiny-ncs-without-last-maxpool-refined-anchors-3cls-extend-remove-maxpooling_10000/20190527114616172809_00000070536.xml
# Created : /data/darknet/python/20190529_detection_result/yolov3-tiny-ncs-without-last-maxpool-refined-anchors-3cls-extend-remove-maxpooling_10000/20190527114655196699_00000070540.xml
# Created : /data/darknet/python/20190529_detection_result/yolov3-tiny-ncs-without-last-maxpool-refined-anchors-3cls-extend-remove-maxpooling_10000/20190527113759618819_00000070264.xml
# Created : /data/darknet/python/20190529_detection_result/yolov3-tiny-ncs-without-last-maxpool-refined-anchors-3cls-extend-remove-maxpooling_10000/20190527113830972765_00000070340.xml
# Created : /data/darknet/python/20190529_detection_result/yolov3-tiny-ncs-without-last-maxpool-refined-anchors-3cls-extend-remove-maxpooling_10000/20190527113934338698_00000070392.xml
# Created : /data/darknet/python/20190529_detection_result/yolov3-tiny-ncs-without-last-maxpool-refined-anchors-3cls-extend-remove-maxpooling_10000/20190527115014966935_00000070611.xml
# Created : /data/darknet/python/20190529_detection_result/yolov3-tiny-ncs-without-last-maxpool-refined-anchors-3cls-extend-remove-maxpooling_10000/20190527115104426586_00000070616.xml
# Created : /data/darknet/python/20190529_detection_result/yolov3-tiny-ncs-without-last-maxpool-refined-anchors-3cls-extend-remove-maxpooling_10000/20190527115115421218_00000070617.xml
# Created : /data/darknet/python/20190529_detection_result/yolov3-tiny-ncs-without-last-maxpool-refined-anchors-3cls-extend-remove-maxpooling_10000/20190527115609355205_00000070701.xml
# Created : /data/darknet/python/20190529_detection_result/yolov3-tiny-ncs-without-last-maxpool-refined-anchors-3cls-extend-remove-maxpooling_10000/20190527115629954994_00000070705.xml
# Created : /data/darknet/python/20190529_detection_result/yolov3-tiny-ncs-without-last-maxpool-refined-anchors-3cls-extend-remove-maxpooling_10000/20190527115634821159_00000070706.xml
# Created : /data/darknet/python/20190529_detection_result/yolov3-tiny-ncs-without-last-maxpool-refined-anchors-3cls-extend-remove-maxpooling_10000/20190527115706604186_00000070712.xml
# Created : /data/darknet/python/20190529_detection_result/yolov3-tiny-ncs-without-last-maxpool-refined-anchors-3cls-extend-remove-maxpooling_10000/20190527115711881841_00000070713.xml
# Created : /data/darknet/python/20190529_detection_result/yolov3-tiny-ncs-without-last-maxpool-refined-anchors-3cls-extend-remove-maxpooling_10000/20190527115748468303_00000070720.xml
# Created : /data/darknet/python/20190529_detection_result/yolov3-tiny-ncs-without-last-maxpool-refined-anchors-3cls-extend-remove-maxpooling_10000/20190527115840350574_00000070730.xml
# Created : /data/darknet/python/20190529_detection_result/yolov3-tiny-ncs-without-last-maxpool-refined-anchors-3cls-extend-remove-maxpooling_10000/20190527115913611989_00000070736.xml
# Created : /data/darknet/python/20190529_detection_result/yolov3-tiny-ncs-without-last-maxpool-refined-anchors-3cls-extend-remove-maxpooling_10000/20190527115923652243_00000070738.xml
# Created : /data/darknet/python/20190529_detection_result/yolov3-tiny-ncs-without-last-maxpool-refined-anchors-3cls-extend-remove-maxpooling_10000/20190527120223799994_00000070771.xml
# Created : /data/darknet/python/20190529_detection_result/yolov3-tiny-ncs-without-last-maxpool-refined-anchors-3cls-extend-remove-maxpooling_10000/20190527120253045447_00000070776.xml
# Created : /data/darknet/python/20190529_detection_result/yolov3-tiny-ncs-without-last-maxpool-refined-anchors-3cls-extend-remove-maxpooling_10000/20190527120317469534_00000070781.xml
# Created : /data/darknet/python/20190529_detection_result/yolov3-tiny-ncs-without-last-maxpool-refined-anchors-3cls-extend-remove-maxpooling_10000/20190527120445051154_00000070798.xml
# Created : /data/darknet/python/20190529_detection_result/yolov3-tiny-ncs-without-last-maxpool-refined-anchors-3cls-extend-remove-maxpooling_10000/20190527120510508429_00000070812.xml
# Created : /data/darknet/python/20190529_detection_result/yolov3-tiny-ncs-without-last-maxpool-refined-anchors-3cls-extend-remove-maxpooling_10000/20190527115529629853_00000070646.xml
# Created : /data/darknet/python/20190529_detection_result/yolov3-tiny-ncs-without-last-maxpool-refined-anchors-3cls-extend-remove-maxpooling_10000/20190527120516514101_00000070816.xml
# Created : /data/darknet/python/20190529_detection_result/yolov3-tiny-ncs-without-last-maxpool-refined-anchors-3cls-extend-remove-maxpooling_10000/20190527120531113749_00000070827.xml
# Created : /data/darknet/python/20190529_detection_result/yolov3-tiny-ncs-without-last-maxpool-refined-anchors-3cls-extend-remove-maxpooling_10000/20190527120532557196_00000070828.xml
# Created : /data/darknet/python/20190529_detection_result/yolov3-tiny-ncs-without-last-maxpool-refined-anchors-3cls-extend-remove-maxpooling_10000/20190527120539838236_00000070834.xml
# Created : /data/darknet/python/20190529_detection_result/yolov3-tiny-ncs-without-last-maxpool-refined-anchors-3cls-extend-remove-maxpooling_10000/20190527120549452673_00000070841.xml
# Created : /data/darknet/python/20190529_detection_result/yolov3-tiny-ncs-without-last-maxpool-refined-anchors-3cls-extend-remove-maxpooling_10000/20190527120606907615_00000070854.xml
# Created : /data/darknet/python/20190529_detection_result/yolov3-tiny-ncs-without-last-maxpool-refined-anchors-3cls-extend-remove-maxpooling_10000/20190527120615117499_00000070860.xml
# Created : /data/darknet/python/20190529_detection_result/yolov3-tiny-ncs-without-last-maxpool-refined-anchors-3cls-extend-remove-maxpooling_10000/20190527120620433928_00000070864.xml
# Created : /data/darknet/python/20190529_detection_result/yolov3-tiny-ncs-without-last-maxpool-refined-anchors-3cls-extend-remove-maxpooling_10000/20190527120623951244_00000070867.xml
# Created : /data/darknet/python/20190529_detection_result/yolov3-tiny-ncs-without-last-maxpool-refined-anchors-3cls-extend-remove-maxpooling_10000/20190527120705170065_00000070907.xml
# Created : /data/darknet/python/20190529_detection_result/yolov3-tiny-ncs-without-last-maxpool-refined-anchors-3cls-extend-remove-maxpooling_10000/20190527120707696920_00000070909.xml
# Created : /data/darknet/python/20190529_detection_result/yolov3-tiny-ncs-without-last-maxpool-refined-anchors-3cls-extend-remove-maxpooling_10000/20190527120721748517_00000070921.xml
# Created : /data/darknet/python/20190529_detection_result/yolov3-tiny-ncs-without-last-maxpool-refined-anchors-3cls-extend-remove-maxpooling_10000/20190527120756740281_00000070948.xml
# Created : /data/darknet/python/20190529_detection_result/yolov3-tiny-ncs-without-last-maxpool-refined-anchors-3cls-extend-remove-maxpooling_10000/20190527120822247330_0001002.xml
# Created : /data/darknet/python/20190529_detection_result/yolov3-tiny-ncs-without-last-maxpool-refined-anchors-3cls-extend-remove-maxpooling_10000/20190527120834763256_0001008.xml
# Created : /data/darknet/python/20190529_detection_result/yolov3-tiny-ncs-without-last-maxpool-refined-anchors-3cls-extend-remove-maxpooling_10000/20190527120621411222_00000070865.xml
# Created : /data/darknet/python/20190529_detection_result/yolov3-tiny-ncs-without-last-maxpool-refined-anchors-3cls-extend-remove-maxpooling_10000/20190527120702732112_00000070905.xml
# Created : /data/darknet/python/20190529_detection_result/yolov3-tiny-ncs-without-last-maxpool-refined-anchors-3cls-extend-remove-maxpooling_10000/20190527120717858843_00000070918.xml
# Created : /data/darknet/python/20190529_detection_result/yolov3-tiny-ncs-without-last-maxpool-refined-anchors-3cls-extend-remove-maxpooling_10000/20190527121214712718_0002009.xml
# Created : /data/darknet/python/20190529_detection_result/yolov3-tiny-ncs-without-last-maxpool-refined-anchors-3cls-extend-remove-maxpooling_10000/20190527121742564907_0002027.xml
# Created : /data/darknet/python/20190529_detection_result/yolov3-tiny-ncs-without-last-maxpool-refined-anchors-3cls-extend-remove-maxpooling_10000/20190527155849848450_0000000.xml
# Created : /data/darknet/python/20190529_detection_result/yolov3-tiny-ncs-without-last-maxpool-refined-anchors-3cls-extend-remove-maxpooling_10000/croped_20190527113158726298_0000004.xml
# Created : /data/darknet/python/20190529_detection_result/yolov3-tiny-ncs-without-last-maxpool-refined-anchors-3cls-extend-remove-maxpooling_10000/croped_20190527113229556165_00000070003.xml
# Created : /data/darknet/python/20190529_detection_result/yolov3-tiny-ncs-without-last-maxpool-refined-anchors-3cls-extend-remove-maxpooling_10000/croped_20190527113251998811_00000070011.xml
# Created : /data/darknet/python/20190529_detection_result/yolov3-tiny-ncs-without-last-maxpool-refined-anchors-3cls-extend-remove-maxpooling_10000/croped_20190527113309698625_00000070017.xml
# Created : /data/darknet/python/20190529_detection_result/yolov3-tiny-ncs-without-last-maxpool-refined-anchors-3cls-extend-remove-maxpooling_10000/croped_20190527113312734290_00000070018.xml
# Created : /data/darknet/python/20190529_detection_result/yolov3-tiny-ncs-without-last-maxpool-refined-anchors-3cls-extend-remove-maxpooling_10000/croped_20190527113333347850_00000070025.xml
# Created : /data/darknet/python/20190529_detection_result/yolov3-tiny-ncs-without-last-maxpool-refined-anchors-3cls-extend-remove-maxpooling_10000/croped_20190527113351422979_00000070031.xml
# Created : /data/darknet/python/20190529_detection_result/yolov3-tiny-ncs-without-last-maxpool-refined-anchors-3cls-extend-remove-maxpooling_10000/croped_20190527113400112162_00000070034.xml
# Created : /data/darknet/python/20190529_detection_result/yolov3-tiny-ncs-without-last-maxpool-refined-anchors-3cls-extend-remove-maxpooling_10000/croped_20190527113414760913_00000070039.xml
# Created : /data/darknet/python/20190529_detection_result/yolov3-tiny-ncs-without-last-maxpool-refined-anchors-3cls-extend-remove-maxpooling_10000/croped_20190527113507263294_00000070059.xml
# Created : /data/darknet/python/20190529_detection_result/yolov3-tiny-ncs-without-last-maxpool-refined-anchors-3cls-extend-remove-maxpooling_10000/croped_20190527113611379968_00000070085.xml
# Created : /data/darknet/python/20190529_detection_result/yolov3-tiny-ncs-without-last-maxpool-refined-anchors-3cls-extend-remove-maxpooling_10000/croped_20190527113616642248_00000070087.xml
# Created : /data/darknet/python/20190529_detection_result/yolov3-tiny-ncs-without-last-maxpool-refined-anchors-3cls-extend-remove-maxpooling_10000/croped_20190527113740069251_00000070251.xml
# Created : /data/darknet/python/20190529_detection_result/yolov3-tiny-ncs-without-last-maxpool-refined-anchors-3cls-extend-remove-maxpooling_10000/croped_20190527113804259650_00000070267.xml
# Created : /data/darknet/python/20190529_detection_result/yolov3-tiny-ncs-without-last-maxpool-refined-anchors-3cls-extend-remove-maxpooling_10000/croped_20190527113837517992_00000070345.xml
# Created : /data/darknet/python/20190529_detection_result/yolov3-tiny-ncs-without-last-maxpool-refined-anchors-3cls-extend-remove-maxpooling_10000/croped_20190527113849134997_00000070355.xml
# Created : /data/darknet/python/20190529_detection_result/yolov3-tiny-ncs-without-last-maxpool-refined-anchors-3cls-extend-remove-maxpooling_10000/croped_20190527113942649847_00000070398.xml
# Created : /data/darknet/python/20190529_detection_result/yolov3-tiny-ncs-without-last-maxpool-refined-anchors-3cls-extend-remove-maxpooling_10000/croped_20190527114358443273_00000070522.xml
# Created : /data/darknet/python/20190529_detection_result/yolov3-tiny-ncs-without-last-maxpool-refined-anchors-3cls-extend-remove-maxpooling_10000/croped_20190527114626431563_00000070537.xml
# Created : /data/darknet/python/20190529_detection_result/yolov3-tiny-ncs-without-last-maxpool-refined-anchors-3cls-extend-remove-maxpooling_10000/croped_20190527114636834538_00000070538.xml
# Created : /data/darknet/python/20190529_detection_result/yolov3-tiny-ncs-without-last-maxpool-refined-anchors-3cls-extend-remove-maxpooling_10000/croped_20190527114852925725_00000070603.xml
# Created : /data/darknet/python/20190529_detection_result/yolov3-tiny-ncs-without-last-maxpool-refined-anchors-3cls-extend-remove-maxpooling_10000/croped_20190527114933551264_00000070607.xml
# Created : /data/darknet/python/20190529_detection_result/yolov3-tiny-ncs-without-last-maxpool-refined-anchors-3cls-extend-remove-maxpooling_10000/croped_20190527115217108360_00000070624.xml
# Created : /data/darknet/python/20190529_detection_result/yolov3-tiny-ncs-without-last-maxpool-refined-anchors-3cls-extend-remove-maxpooling_10000/croped_20190527115226940690_00000070625.xml
# Created : /data/darknet/python/20190529_detection_result/yolov3-tiny-ncs-without-last-maxpool-refined-anchors-3cls-extend-remove-maxpooling_10000/croped_20190527115332757151_00000070632.xml
# Created : /data/darknet/python/20190529_detection_result/yolov3-tiny-ncs-without-last-maxpool-refined-anchors-3cls-extend-remove-maxpooling_10000/croped_20190527115349805565_00000070634.xml
# Created : /data/darknet/python/20190529_detection_result/yolov3-tiny-ncs-without-last-maxpool-refined-anchors-3cls-extend-remove-maxpooling_10000/croped_20190527115406794768_00000070636.xml
# Created : /data/darknet/python/20190529_detection_result/yolov3-tiny-ncs-without-last-maxpool-refined-anchors-3cls-extend-remove-maxpooling_10000/croped_20190527115521977028_00000070645.xml
# Created : /data/darknet/python/20190529_detection_result/yolov3-tiny-ncs-without-last-maxpool-refined-anchors-3cls-extend-remove-maxpooling_10000/croped_20190527115650718301_00000070709.xml
# Created : /data/darknet/python/20190529_detection_result/yolov3-tiny-ncs-without-last-maxpool-refined-anchors-3cls-extend-remove-maxpooling_10000/croped_20190527115711881841_00000070713.xml
# Created : /data/darknet/python/20190529_detection_result/yolov3-tiny-ncs-without-last-maxpool-refined-anchors-3cls-extend-remove-maxpooling_10000/croped_20190527115928291741_00000070739.xml
# Created : /data/darknet/python/20190529_detection_result/yolov3-tiny-ncs-without-last-maxpool-refined-anchors-3cls-extend-remove-maxpooling_10000/croped_20190527115951986113_00000070744.xml
# Created : /data/darknet/python/20190529_detection_result/yolov3-tiny-ncs-without-last-maxpool-refined-anchors-3cls-extend-remove-maxpooling_10000/croped_20190527120002110031_00000070746.xml
# Created : /data/darknet/python/20190529_detection_result/yolov3-tiny-ncs-without-last-maxpool-refined-anchors-3cls-extend-remove-maxpooling_10000/croped_20190527120053057798_00000070755.xml
# Created : /data/darknet/python/20190529_detection_result/yolov3-tiny-ncs-without-last-maxpool-refined-anchors-3cls-extend-remove-maxpooling_10000/croped_20190527120307238712_00000070779.xml
# Created : /data/darknet/python/20190529_detection_result/yolov3-tiny-ncs-without-last-maxpool-refined-anchors-3cls-extend-remove-maxpooling_10000/croped_20190527120500835744_00000070805.xml
# Created : /data/darknet/python/20190529_detection_result/yolov3-tiny-ncs-without-last-maxpool-refined-anchors-3cls-extend-remove-maxpooling_10000/croped_20190527120507729264_00000070810.xml
# Created : /data/darknet/python/20190529_detection_result/yolov3-tiny-ncs-without-last-maxpool-refined-anchors-3cls-extend-remove-maxpooling_10000/croped_20190527120512055648_00000070813.xml
# Created : /data/darknet/python/20190529_detection_result/yolov3-tiny-ncs-without-last-maxpool-refined-anchors-3cls-extend-remove-maxpooling_10000/croped_20190527120513558215_00000070814.xml
# Created : /data/darknet/python/20190529_detection_result/yolov3-tiny-ncs-without-last-maxpool-refined-anchors-3cls-extend-remove-maxpooling_10000/croped_20190527120520579233_00000070819.xml
# Created : /data/darknet/python/20190529_detection_result/yolov3-tiny-ncs-without-last-maxpool-refined-anchors-3cls-extend-remove-maxpooling_10000/croped_20190527120610899962_00000070857.xml
# Created : /data/darknet/python/20190529_detection_result/yolov3-tiny-ncs-without-last-maxpool-refined-anchors-3cls-extend-remove-maxpooling_10000/croped_20190527120619005565_00000070863.xml
# Created : /data/darknet/python/20190529_detection_result/yolov3-tiny-ncs-without-last-maxpool-refined-anchors-3cls-extend-remove-maxpooling_10000/croped_20190527120625665163_00000070869.xml
# Created : /data/darknet/python/20190529_detection_result/yolov3-tiny-ncs-without-last-maxpool-refined-anchors-3cls-extend-remove-maxpooling_10000/croped_20190527120631168591_00000070874.xml
# Created : /data/darknet/python/20190529_detection_result/yolov3-tiny-ncs-without-last-maxpool-refined-anchors-3cls-extend-remove-maxpooling_10000/croped_20190527120636376534_00000070879.xml
# Created : /data/darknet/python/20190529_detection_result/yolov3-tiny-ncs-without-last-maxpool-refined-anchors-3cls-extend-remove-maxpooling_10000/croped_20190527120658659244_00000070901.xml
# Created : /data/darknet/python/20190529_detection_result/yolov3-tiny-ncs-without-last-maxpool-refined-anchors-3cls-extend-remove-maxpooling_10000/croped_20190527120713860203_00000070915.xml
# Created : /data/darknet/python/20190529_detection_result/yolov3-tiny-ncs-without-last-maxpool-refined-anchors-3cls-extend-remove-maxpooling_10000/croped_20190527120738821336_00000070935.xml
# Created : /data/darknet/python/20190529_detection_result/yolov3-tiny-ncs-without-last-maxpool-refined-anchors-3cls-extend-remove-maxpooling_10000/croped_20190527120940457891_0002001.xml
# Created : /data/darknet/python/20190529_detection_result/yolov3-tiny-ncs-without-last-maxpool-refined-anchors-3cls-extend-remove-maxpooling_10000/croped_20190527121137608974_0002007.xml
# Created : /data/darknet/python/20190529_detection_result/yolov3-tiny-ncs-without-last-maxpool-refined-anchors-3cls-extend-remove-maxpooling_10000/croped_20190527121232437360_0002010.xml
# Created : /data/darknet/python/20190529_detection_result/yolov3-tiny-ncs-without-last-maxpool-refined-anchors-3cls-extend-remove-maxpooling_10000/croped_20190527121742564907_0002027.xml
# Created : /data/darknet/python/20190529_detection_result/yolov3-tiny-ncs-without-last-maxpool-refined-anchors-3cls-extend-remove-maxpooling_10000/croped_20190527121922566998_0002032.xml
# Created : /data/darknet/python/20190529_detection_result/yolov3-tiny-ncs-without-last-maxpool-refined-anchors-3cls-extend-remove-maxpooling_10000/croped_20190527122016679159_0002034.xml
# Created : /data/darknet/python/20190529_detection_result/yolov3-tiny-ncs-without-last-maxpool-refined-anchors-3cls-extend-remove-maxpooling_10000/fliped_20190527113226613781_00000070002.xml
# Created : /data/darknet/python/20190529_detection_result/yolov3-tiny-ncs-without-last-maxpool-refined-anchors-3cls-extend-remove-maxpooling_10000/fliped_20190527113241624797_00000070007.xml
# Created : /data/darknet/python/20190529_detection_result/yolov3-tiny-ncs-without-last-maxpool-refined-anchors-3cls-extend-remove-maxpooling_10000/fliped_20190527113321162257_00000070021.xml
# Created : /data/darknet/python/20190529_detection_result/yolov3-tiny-ncs-without-last-maxpool-refined-anchors-3cls-extend-remove-maxpooling_10000/fliped_20190527113345324552_00000070029.xml
# Created : /data/darknet/python/20190529_detection_result/yolov3-tiny-ncs-without-last-maxpool-refined-anchors-3cls-extend-remove-maxpooling_10000/fliped_20190527113417280125_00000070040.xml
# Created : /data/darknet/python/20190529_detection_result/yolov3-tiny-ncs-without-last-maxpool-refined-anchors-3cls-extend-remove-maxpooling_10000/croped_20190527120707696920_00000070909.xml
# Created : /data/darknet/python/20190529_detection_result/yolov3-tiny-ncs-without-last-maxpool-refined-anchors-3cls-extend-remove-maxpooling_10000/fliped_20190527113312734290_00000070018.xml
# Created : /data/darknet/python/20190529_detection_result/yolov3-tiny-ncs-without-last-maxpool-refined-anchors-3cls-extend-remove-maxpooling_10000/fliped_20190527113619262408_00000070088.xml
# Created : /data/darknet/python/20190529_detection_result/yolov3-tiny-ncs-without-last-maxpool-refined-anchors-3cls-extend-remove-maxpooling_10000/fliped_20190527113627469657_00000070091.xml
# Created : /data/darknet/python/20190529_detection_result/yolov3-tiny-ncs-without-last-maxpool-refined-anchors-3cls-extend-remove-maxpooling_10000/fliped_20190527113651949234_00000070221.xml
# Created : /data/darknet/python/20190529_detection_result/yolov3-tiny-ncs-without-last-maxpool-refined-anchors-3cls-extend-remove-maxpooling_10000/fliped_20190527113659320977_00000070226.xml
# Created : /data/darknet/python/20190529_detection_result/yolov3-tiny-ncs-without-last-maxpool-refined-anchors-3cls-extend-remove-maxpooling_10000/fliped_20190527113711891260_00000070234.xml
# Created : /data/darknet/python/20190529_detection_result/yolov3-tiny-ncs-without-last-maxpool-refined-anchors-3cls-extend-remove-maxpooling_10000/fliped_20190527113714812629_00000070236.xml
# Created : /data/darknet/python/20190529_detection_result/yolov3-tiny-ncs-without-last-maxpool-refined-anchors-3cls-extend-remove-maxpooling_10000/fliped_20190527113723073570_00000070241.xml
# Created : /data/darknet/python/20190529_detection_result/yolov3-tiny-ncs-without-last-maxpool-refined-anchors-3cls-extend-remove-maxpooling_10000/fliped_20190527113844910300_00000070352.xml
# Created : /data/darknet/python/20190529_detection_result/yolov3-tiny-ncs-without-last-maxpool-refined-anchors-3cls-extend-remove-maxpooling_10000/fliped_20190527113859263368_00000070364.xml
# Created : /data/darknet/python/20190529_detection_result/yolov3-tiny-ncs-without-last-maxpool-refined-anchors-3cls-extend-remove-maxpooling_10000/fliped_20190527113901166950_00000070365.xml
# Created : /data/darknet/python/20190529_detection_result/yolov3-tiny-ncs-without-last-maxpool-refined-anchors-3cls-extend-remove-maxpooling_10000/fliped_20190527113903357896_00000070367.xml
# Created : /data/darknet/python/20190529_detection_result/yolov3-tiny-ncs-without-last-maxpool-refined-anchors-3cls-extend-remove-maxpooling_10000/fliped_20190527113905822626_00000070369.xml
# Created : /data/darknet/python/20190529_detection_result/yolov3-tiny-ncs-without-last-maxpool-refined-anchors-3cls-extend-remove-maxpooling_10000/fliped_20190527113910959760_00000070373.xml
# Created : /data/darknet/python/20190529_detection_result/yolov3-tiny-ncs-without-last-maxpool-refined-anchors-3cls-extend-remove-maxpooling_10000/fliped_20190527113921107603_00000070381.xml
# Created : /data/darknet/python/20190529_detection_result/yolov3-tiny-ncs-without-last-maxpool-refined-anchors-3cls-extend-remove-maxpooling_10000/fliped_20190527114123350124_00000070508.xml
# Created : /data/darknet/python/20190529_detection_result/yolov3-tiny-ncs-without-last-maxpool-refined-anchors-3cls-extend-remove-maxpooling_10000/fliped_20190527114517920087_00000070530.xml
# Created : /data/darknet/python/20190529_detection_result/yolov3-tiny-ncs-without-last-maxpool-refined-anchors-3cls-extend-remove-maxpooling_10000/fliped_20190527114607250856_00000070535.xml
# Created : /data/darknet/python/20190529_detection_result/yolov3-tiny-ncs-without-last-maxpool-refined-anchors-3cls-extend-remove-maxpooling_10000/fliped_20190527114805308804_00000070547.xml
# Created : /data/darknet/python/20190529_detection_result/yolov3-tiny-ncs-without-last-maxpool-refined-anchors-3cls-extend-remove-maxpooling_10000/fliped_20190527114933551264_00000070607.xml
# Created : /data/darknet/python/20190529_detection_result/yolov3-tiny-ncs-without-last-maxpool-refined-anchors-3cls-extend-remove-maxpooling_10000/fliped_20190527115014966935_00000070611.xml
# Created : /data/darknet/python/20190529_detection_result/yolov3-tiny-ncs-without-last-maxpool-refined-anchors-3cls-extend-remove-maxpooling_10000/fliped_20190527115053838044_00000070615.xml
# Created : /data/darknet/python/20190529_detection_result/yolov3-tiny-ncs-without-last-maxpool-refined-anchors-3cls-extend-remove-maxpooling_10000/fliped_20190527115341748722_00000070633.xml
# Created : /data/darknet/python/20190529_detection_result/yolov3-tiny-ncs-without-last-maxpool-refined-anchors-3cls-extend-remove-maxpooling_10000/fliped_20190527114050473028_00000070505.xml
# Created : /data/darknet/python/20190529_detection_result/yolov3-tiny-ncs-without-last-maxpool-refined-anchors-3cls-extend-remove-maxpooling_10000/fliped_20190527115743409853_00000070719.xml
# Created : /data/darknet/python/20190529_detection_result/yolov3-tiny-ncs-without-last-maxpool-refined-anchors-3cls-extend-remove-maxpooling_10000/fliped_20190527115956851010_00000070745.xml
# Created : /data/darknet/python/20190529_detection_result/yolov3-tiny-ncs-without-last-maxpool-refined-anchors-3cls-extend-remove-maxpooling_10000/fliped_20190527120032139359_00000070751.xml
# Created : /data/darknet/python/20190529_detection_result/yolov3-tiny-ncs-without-last-maxpool-refined-anchors-3cls-extend-remove-maxpooling_10000/fliped_20190527120037285819_00000070752.xml
# Created : /data/darknet/python/20190529_detection_result/yolov3-tiny-ncs-without-last-maxpool-refined-anchors-3cls-extend-remove-maxpooling_10000/fliped_20190527120042541444_00000070753.xml
# Created : /data/darknet/python/20190529_detection_result/yolov3-tiny-ncs-without-last-maxpool-refined-anchors-3cls-extend-remove-maxpooling_10000/fliped_20190527120155028475_00000070766.xml
# Created : /data/darknet/python/20190529_detection_result/yolov3-tiny-ncs-without-last-maxpool-refined-anchors-3cls-extend-remove-maxpooling_10000/fliped_20190527120200899441_00000070767.xml
# Created : /data/darknet/python/20190529_detection_result/yolov3-tiny-ncs-without-last-maxpool-refined-anchors-3cls-extend-remove-maxpooling_10000/fliped_20190527120206174177_00000070768.xml
# Created : /data/darknet/python/20190529_detection_result/yolov3-tiny-ncs-without-last-maxpool-refined-anchors-3cls-extend-remove-maxpooling_10000/fliped_20190527120229628169_00000070772.xml
# Created : /data/darknet/python/20190529_detection_result/yolov3-tiny-ncs-without-last-maxpool-refined-anchors-3cls-extend-remove-maxpooling_10000/fliped_20190527120525462870_00000070823.xml
# Created : /data/darknet/python/20190529_detection_result/yolov3-tiny-ncs-without-last-maxpool-refined-anchors-3cls-extend-remove-maxpooling_10000/fliped_20190527120529472643_00000070826.xml
# Created : /data/darknet/python/20190529_detection_result/yolov3-tiny-ncs-without-last-maxpool-refined-anchors-3cls-extend-remove-maxpooling_10000/fliped_20190527120531113749_00000070827.xml
# Created : /data/darknet/python/20190529_detection_result/yolov3-tiny-ncs-without-last-maxpool-refined-anchors-3cls-extend-remove-maxpooling_10000/fliped_20190527115923652243_00000070738.xml
# Created : /data/darknet/python/20190529_detection_result/yolov3-tiny-ncs-without-last-maxpool-refined-anchors-3cls-extend-remove-maxpooling_10000/fliped_20190527120605730888_00000070853.xml
# Created : /data/darknet/python/20190529_detection_result/yolov3-tiny-ncs-without-last-maxpool-refined-anchors-3cls-extend-remove-maxpooling_10000/fliped_20190527120635335426_00000070878.xml
# Created : /data/darknet/python/20190529_detection_result/yolov3-tiny-ncs-without-last-maxpool-refined-anchors-3cls-extend-remove-maxpooling_10000/fliped_20190527120645543783_00000070888.xml
# Created : /data/darknet/python/20190529_detection_result/yolov3-tiny-ncs-without-last-maxpool-refined-anchors-3cls-extend-remove-maxpooling_10000/fliped_20190527120654834284_00000070897.xml
# Created : /data/darknet/python/20190529_detection_result/yolov3-tiny-ncs-without-last-maxpool-refined-anchors-3cls-extend-remove-maxpooling_10000/fliped_20190527120656794181_00000070899.xml
# Created : /data/darknet/python/20190529_detection_result/yolov3-tiny-ncs-without-last-maxpool-refined-anchors-3cls-extend-remove-maxpooling_10000/fliped_20190527120706269593_00000070908.xml
# Created : /data/darknet/python/20190529_detection_result/yolov3-tiny-ncs-without-last-maxpool-refined-anchors-3cls-extend-remove-maxpooling_10000/fliped_20190527120709719623_00000070911.xml
# Created : /data/darknet/python/20190529_detection_result/yolov3-tiny-ncs-without-last-maxpool-refined-anchors-3cls-extend-remove-maxpooling_10000/fliped_20190527120711759868_00000070913.xml
# Created : /data/darknet/python/20190529_detection_result/yolov3-tiny-ncs-without-last-maxpool-refined-anchors-3cls-extend-remove-maxpooling_10000/fliped_20190527120730111225_00000070928.xml
# Created : /data/darknet/python/20190529_detection_result/yolov3-tiny-ncs-without-last-maxpool-refined-anchors-3cls-extend-remove-maxpooling_10000/fliped_20190527120803511270_0000010.xml
# Created : /data/darknet/python/20190529_detection_result/yolov3-tiny-ncs-without-last-maxpool-refined-anchors-3cls-extend-remove-maxpooling_10000/fliped_20190527120808218116_0000011.xml
# Created : /data/darknet/python/20190529_detection_result/yolov3-tiny-ncs-without-last-maxpool-refined-anchors-3cls-extend-remove-maxpooling_10000/fliped_20190527120829294601_0001005.xml
# Created : /data/darknet/python/20190529_detection_result/yolov3-tiny-ncs-without-last-maxpool-refined-anchors-3cls-extend-remove-maxpooling_10000/fliped_20190527120857203671_0001017.xml
# Created : /data/darknet/python/20190529_detection_result/yolov3-tiny-ncs-without-last-maxpool-refined-anchors-3cls-extend-remove-maxpooling_10000/fliped_20190527121117473264_0002006.xml
# Created : /data/darknet/python/20190529_detection_result/yolov3-tiny-ncs-without-last-maxpool-refined-anchors-3cls-extend-remove-maxpooling_10000/fliped_20190527121157473559_0002008.xml
# Created : /data/darknet/python/20190529_detection_result/yolov3-tiny-ncs-without-last-maxpool-refined-anchors-3cls-extend-remove-maxpooling_10000/fliped_20190527120612825766_00000070858.xml
# Created : /data/darknet/python/20190529_detection_result/yolov3-tiny-ncs-without-last-maxpool-refined-anchors-3cls-extend-remove-maxpooling_10000/fliped_20190527121722336949_0002026.xml
# Created : /data/darknet/python/20190529_detection_result/yolov3-tiny-ncs-without-last-maxpool-refined-anchors-3cls-extend-remove-maxpooling_10000/fliped_20190527121858949300_0002031.xml
# Created : /data/darknet/python/20190529_detection_result/yolov3-tiny-ncs-without-last-maxpool-refined-anchors-3cls-extend-remove-maxpooling_10000/fliped_20190527121949687124_0002033.xml
# Created : /data/darknet/python/20190529_detection_result/yolov3-tiny-ncs-without-last-maxpool-refined-anchors-3cls-extend-remove-maxpooling_10000/fliped_20190527122016679159_0002034.xml
# ...
# Created : /data/darknet/python/20190529_detection_result/yolov3-tiny-ncs-without-last-maxpool-refined-anchors-3cls-extend-remove-maxpooling_new_new_40000/20190527160635510106_ge_shrink_scale_0.3_0_127.5_20190527120613736194_00000070859.xml
# Created : /data/darknet/python/20190529_detection_result/yolov3-tiny-ncs-without-last-maxpool-refined-anchors-3cls-extend-remove-maxpooling_new_new_40000/20190527160636008527_ge_shrink_scale_0.3_0_127.5_20190527120616535121_00000070861.xml
# Created : /data/darknet/python/20190529_detection_result/yolov3-tiny-ncs-without-last-maxpool-refined-anchors-3cls-extend-remove-maxpooling_new_new_40000/20190527160638978629_ge_shrink_scale_0.3_0_127.5_20190527120646612859_00000070889.xml
# Created : /data/darknet/python/20190529_detection_result/yolov3-tiny-ncs-without-last-maxpool-refined-anchors-3cls-extend-remove-maxpooling_new_new_40000/20190527160636373217_ge_shrink_scale_0.3_0_127.5_20190527120619005565_00000070863.xml
# Created : /data/darknet/python/20190529_detection_result/yolov3-tiny-ncs-without-last-maxpool-refined-anchors-3cls-extend-remove-maxpooling_new_new_40000/20190527160637788092_ge_shrink_scale_0.3_0_127.5_20190527120632291262_00000070875.xml
# Created : /data/darknet/python/20190529_detection_result/yolov3-tiny-ncs-without-last-maxpool-refined-anchors-3cls-extend-remove-maxpooling_new_new_40000/20190527160638188118_ge_shrink_scale_0.3_0_127.5_20190527120636376534_00000070879.xml
# Created : /data/darknet/python/20190529_detection_result/yolov3-tiny-ncs-without-last-maxpool-refined-anchors-3cls-extend-remove-maxpooling_new_new_40000/20190527160638507309_ge_shrink_scale_0.3_0_127.5_20190527120640166224_00000070883.xml
# Created : /data/darknet/python/20190529_detection_result/yolov3-tiny-ncs-without-last-maxpool-refined-anchors-3cls-extend-remove-maxpooling_new_new_40000/20190527160638895885_ge_shrink_scale_0.3_0_127.5_20190527120645543783_00000070888.xml
# Created : /data/darknet/python/20190529_detection_result/yolov3-tiny-ncs-without-last-maxpool-refined-anchors-3cls-extend-remove-maxpooling_new_new_40000/20190527160639428823_ge_shrink_scale_0.3_0_127.5_20190527120653400580_00000070896.xml
# Created : /data/darknet/python/20190529_detection_result/yolov3-tiny-ncs-without-last-maxpool-refined-anchors-3cls-extend-remove-maxpooling_new_new_40000/20190527160641996136_ge_shrink_scale_0.3_0_127.5_20190527120701617480_00000070904.xml
# Created : /data/darknet/python/20190529_detection_result/yolov3-tiny-ncs-without-last-maxpool-refined-anchors-3cls-extend-remove-maxpooling_new_new_40000/20190527160642126902_ge_shrink_scale_0.3_0_127.5_20190527120702732112_00000070905.xml
# Created : /data/darknet/python/20190529_detection_result/yolov3-tiny-ncs-without-last-maxpool-refined-anchors-3cls-extend-remove-maxpooling_new_new_40000/20190527160643067018_ge_shrink_scale_0.3_0_127.5_20190527120709719623_00000070911.xml
# Created : /data/darknet/python/20190529_detection_result/yolov3-tiny-ncs-without-last-maxpool-refined-anchors-3cls-extend-remove-maxpooling_new_new_40000/20190527160644104783_ge_shrink_scale_0.3_0_127.5_20190527120718992679_00000070919.xml
# Created : /data/darknet/python/20190529_detection_result/yolov3-tiny-ncs-without-last-maxpool-refined-anchors-3cls-extend-remove-maxpooling_new_new_40000/20190527160645383077_ge_shrink_scale_0.3_0_127.5_20190527120729118316_00000070927.xml
# Created : /data/darknet/python/20190529_detection_result/yolov3-tiny-ncs-without-last-maxpool-refined-anchors-3cls-extend-remove-maxpooling_new_new_40000/20190527160646026392_ge_shrink_scale_0.3_0_127.5_20190527120736631490_00000070933.xml
# Created : /data/darknet/python/20190529_detection_result/yolov3-tiny-ncs-without-last-maxpool-refined-anchors-3cls-extend-remove-maxpooling_new_new_40000/20190527160646327594_ge_shrink_scale_0.3_0_127.5_20190527120740792060_00000070936.xml
# Created : /data/darknet/python/20190529_detection_result/yolov3-tiny-ncs-without-last-maxpool-refined-anchors-3cls-extend-remove-maxpooling_new_new_40000/20190527160650367991_ge_shrink_scale_0.3_0_127.5_20190527120846758495_0001013.xml
# Created : /data/darknet/python/20190529_detection_result/yolov3-tiny-ncs-without-last-maxpool-refined-anchors-3cls-extend-remove-maxpooling_new_new_40000/20190527160650714059_ge_shrink_scale_0.3_0_127.5_20190527120858659004_0001021.xml
# Created : /data/darknet/python/20190529_detection_result/yolov3-tiny-ncs-without-last-maxpool-refined-anchors-3cls-extend-remove-maxpooling_new_new_40000/20190527160650783225_ge_shrink_scale_0.3_0_127.5_20190527120859919811_0001022.xml
# Created : /data/darknet/python/20190529_detection_result/yolov3-tiny-ncs-without-last-maxpool-refined-anchors-3cls-extend-remove-maxpooling_new_new_40000/20190527160650934812_ge_shrink_scale_0.3_0_127.5_20190527120940457891_0002001.xml
# Created : /data/darknet/python/20190529_detection_result/yolov3-tiny-ncs-without-last-maxpool-refined-anchors-3cls-extend-remove-maxpooling_new_new_40000/20190527160652753317_ge_shrink_scale_0.3_0_127.5_20190527121459582032_0002019.xml
# Created : /data/darknet/python/20190529_detection_result/yolov3-tiny-ncs-without-last-maxpool-refined-anchors-3cls-extend-remove-maxpooling_new_new_40000/20190527160653727066_ge_shrink_scale_0.3_0_127.5_20190527121722336949_0002026.xml
# Created : /data/darknet/python/20190529_detection_result/yolov3-tiny-ncs-without-last-maxpool-refined-anchors-3cls-extend-remove-maxpooling_new_new_40000/20190527160654656207_ge_shrink_scale_0.3_0_127.5_20190527122016679159_0002034.xml
# Created : /data/darknet/python/20190529_detection_result/yolov3-tiny-ncs-without-last-maxpool-refined-anchors-3cls-extend-remove-maxpooling_new_new_40000/20190527160655602985_ge_shrink_scale_0.3_0_127.5_croped_20190527113218100689_0000007.xml
# Created : /data/darknet/python/20190529_detection_result/yolov3-tiny-ncs-without-last-maxpool-refined-anchors-3cls-extend-remove-maxpooling_new_new_40000/20190527160657059131_ge_shrink_scale_0.3_0_127.5_croped_20190527113246770400_00000070009.xml
# Created : /data/darknet/python/20190529_detection_result/yolov3-tiny-ncs-without-last-maxpool-refined-anchors-3cls-extend-remove-maxpooling_new_new_40000/20190527160658293963_ge_shrink_scale_0.3_0_127.5_croped_20190527113306795973_00000070016.xml
# Created : /data/darknet/python/20190529_detection_result/yolov3-tiny-ncs-without-last-maxpool-refined-anchors-3cls-extend-remove-maxpooling_new_new_40000/20190527160616678598_ge_shrink_scale_0.3_0_127.5_20190527120127596473_00000070761.xml
# Created : /data/darknet/python/20190529_detection_result/yolov3-tiny-ncs-without-last-maxpool-refined-anchors-3cls-extend-remove-maxpooling_new_new_40000/croped_20190527114113032857_00000070507.xml
# Created : /data/darknet/python/20190529_detection_result/yolov3-tiny-ncs-without-last-maxpool-refined-anchors-3cls-extend-remove-maxpooling_new_new_40000/20190527160659176586_ge_shrink_scale_0.3_0_127.5_croped_20190527113321162257_00000070021.xml
# Created : /data/darknet/python/20190529_detection_result/yolov3-tiny-ncs-without-last-maxpool-refined-anchors-3cls-extend-remove-maxpooling_new_new_40000/20190527160659511635_ge_shrink_scale_0.3_0_127.5_croped_20190527113330335947_00000070024.xml
# Created : /data/darknet/python/20190529_detection_result/yolov3-tiny-ncs-without-last-maxpool-refined-anchors-3cls-extend-remove-maxpooling_new_new_40000/20190527160700277519_ge_shrink_scale_0.3_0_127.5_croped_20190527113348579984_00000070030.xml
# Created : /data/darknet/python/20190529_detection_result/yolov3-tiny-ncs-without-last-maxpool-refined-anchors-3cls-extend-remove-maxpooling_new_new_40000/20190527160700709540_ge_shrink_scale_0.3_0_127.5_croped_20190527113408893346_00000070037.xml
# Created : /data/darknet/python/20190529_detection_result/yolov3-tiny-ncs-without-last-maxpool-refined-anchors-3cls-extend-remove-maxpooling_new_new_40000/20190527160700774360_ge_shrink_scale_0.3_0_127.5_croped_20190527113411899587_00000070038.xml
# Created : /data/darknet/python/20190529_detection_result/yolov3-tiny-ncs-without-last-maxpool-refined-anchors-3cls-extend-remove-maxpooling_new_new_40000/20190527160701273486_ge_shrink_scale_0.3_0_127.5_croped_20190527113430446767_00000070045.xml
# Created : /data/darknet/python/20190529_detection_result/yolov3-tiny-ncs-without-last-maxpool-refined-anchors-3cls-extend-remove-maxpooling_new_new_40000/20190527160701963017_ge_shrink_scale_0.3_0_127.5_croped_20190527113504796994_00000070058.xml
# Created : /data/darknet/python/20190529_detection_result/yolov3-tiny-ncs-without-last-maxpool-refined-anchors-3cls-extend-remove-maxpooling_new_new_40000/20190527160702838117_ge_shrink_scale_0.3_0_127.5_croped_20190527113550519301_00000070076.xml
# Created : /data/darknet/python/20190529_detection_result/yolov3-tiny-ncs-without-last-maxpool-refined-anchors-3cls-extend-remove-maxpooling_new_new_40000/20190527160703403754_ge_shrink_scale_0.3_0_127.5_croped_20190527113611379968_00000070085.xml
# Created : /data/darknet/python/20190529_detection_result/yolov3-tiny-ncs-without-last-maxpool-refined-anchors-3cls-extend-remove-maxpooling_new_new_40000/20190527160703724971_ge_shrink_scale_0.3_0_127.5_croped_20190527113629864202_00000070092.xml
# Created : /data/darknet/python/20190529_detection_result/yolov3-tiny-ncs-without-last-maxpool-refined-anchors-3cls-extend-remove-maxpooling_new_new_40000/20190527160704768311_ge_shrink_scale_0.3_0_127.5_croped_20190527113708741983_00000070232.xml
# Created : /data/darknet/python/20190529_detection_result/yolov3-tiny-ncs-without-last-maxpool-refined-anchors-3cls-extend-remove-maxpooling_new_new_40000/20190527160704828846_ge_shrink_scale_0.3_0_127.5_croped_20190527113710424930_00000070233.xml
# Created : /data/darknet/python/20190529_detection_result/yolov3-tiny-ncs-without-last-maxpool-refined-anchors-3cls-extend-remove-maxpooling_new_new_40000/20190527160706137975_ge_shrink_scale_0.3_0_127.5_croped_20190527113741678494_00000070252.xml
# Created : /data/darknet/python/20190529_detection_result/yolov3-tiny-ncs-without-last-maxpool-refined-anchors-3cls-extend-remove-maxpooling_new_new_40000/20190527160706330275_ge_shrink_scale_0.3_0_127.5_croped_20190527113748181256_00000070256.xml
# Created : /data/darknet/python/20190529_detection_result/yolov3-tiny-ncs-without-last-maxpool-refined-anchors-3cls-extend-remove-maxpooling_new_new_40000/20190527160707411394_ge_shrink_scale_0.3_0_127.5_croped_20190527113813822759_00000070326.xml
# Created : /data/darknet/python/20190529_detection_result/yolov3-tiny-ncs-without-last-maxpool-refined-anchors-3cls-extend-remove-maxpooling_new_new_40000/20190527160707794976_ge_shrink_scale_0.3_0_127.5_croped_20190527113823704879_00000070334.xml
# Created : /data/darknet/python/20190529_detection_result/yolov3-tiny-ncs-without-last-maxpool-refined-anchors-3cls-extend-remove-maxpooling_new_new_40000/20190527160707926551_ge_shrink_scale_0.3_0_127.5_croped_20190527113828598559_00000070338.xml
# Created : /data/darknet/python/20190529_detection_result/yolov3-tiny-ncs-without-last-maxpool-refined-anchors-3cls-extend-remove-maxpooling_new_new_40000/20190527160708213985_ge_shrink_scale_0.3_0_127.5_croped_20190527113837517992_00000070345.xml
# Created : /data/darknet/python/20190529_detection_result/yolov3-tiny-ncs-without-last-maxpool-refined-anchors-3cls-extend-remove-maxpooling_new_new_40000/20190527160708926880_ge_shrink_scale_0.3_0_127.5_croped_20190527113856862331_00000070362.xml
# Created : /data/darknet/python/20190529_detection_result/yolov3-tiny-ncs-without-last-maxpool-refined-anchors-3cls-extend-remove-maxpooling_new_new_40000/20190527160709015221_ge_shrink_scale_0.3_0_127.5_croped_20190527113859263368_00000070364.xml
# Created : /data/darknet/python/20190529_detection_result/yolov3-tiny-ncs-without-last-maxpool-refined-anchors-3cls-extend-remove-maxpooling_new_new_40000/20190527160710960540_ge_shrink_scale_0.3_0_127.5_croped_20190527113941965944_00000070397.xml
# Created : /data/darknet/python/20190529_detection_result/yolov3-tiny-ncs-without-last-maxpool-refined-anchors-3cls-extend-remove-maxpooling_new_new_40000/20190527160712915836_ge_shrink_scale_0.3_0_127.5_croped_20190527114230105017_00000070514.xml
# Created : /data/darknet/python/20190529_detection_result/yolov3-tiny-ncs-without-last-maxpool-refined-anchors-3cls-extend-remove-maxpooling_new_new_40000/20190527160713921386_ge_shrink_scale_0.3_0_127.5_croped_20190527114429638868_00000070525.xml
# Created : /data/darknet/python/20190529_detection_result/yolov3-tiny-ncs-without-last-maxpool-refined-anchors-3cls-extend-remove-maxpooling_new_new_40000/20190527160714880276_ge_shrink_scale_0.3_0_127.5_croped_20190527114646838254_00000070539.xml
# Created : /data/darknet/python/20190529_detection_result/yolov3-tiny-ncs-without-last-maxpool-refined-anchors-3cls-extend-remove-maxpooling_new_new_40000/20190527160715915098_ge_shrink_scale_0.3_0_127.5_croped_20190527114852925725_00000070603.xml
# Created : /data/darknet/python/20190529_detection_result/yolov3-tiny-ncs-without-last-maxpool-refined-anchors-3cls-extend-remove-maxpooling_new_new_40000/20190527160716051875_ge_shrink_scale_0.3_0_127.5_croped_20190527114913429929_00000070605.xml
# Created : /data/darknet/python/20190529_detection_result/yolov3-tiny-ncs-without-last-maxpool-refined-anchors-3cls-extend-remove-maxpooling_new_new_40000/20190527160719456741_ge_shrink_scale_0.3_0_127.5_croped_20190527115455538320_00000070642.xml
# Created : /data/darknet/python/20190529_detection_result/yolov3-tiny-ncs-without-last-maxpool-refined-anchors-3cls-extend-remove-maxpooling_new_new_40000/20190527160721221405_ge_shrink_scale_0.3_0_127.5_croped_20190527115743409853_00000070719.xml
# Created : /data/darknet/python/20190529_detection_result/yolov3-tiny-ncs-without-last-maxpool-refined-anchors-3cls-extend-remove-maxpooling_new_new_40000/20190527160722054272_ge_shrink_scale_0.3_0_127.5_croped_20190527115857646916_00000070733.xml
# Created : /data/darknet/python/20190529_detection_result/yolov3-tiny-ncs-without-last-maxpool-refined-anchors-3cls-extend-remove-maxpooling_new_new_40000/20190527160723334969_ge_shrink_scale_0.3_0_127.5_croped_20190527120037285819_00000070752.xml
# Created : /data/darknet/python/20190529_detection_result/yolov3-tiny-ncs-without-last-maxpool-refined-anchors-3cls-extend-remove-maxpooling_new_new_40000/20190527160723497494_ge_shrink_scale_0.3_0_127.5_croped_20190527120047876073_00000070754.xml
# Created : /data/darknet/python/20190529_detection_result/yolov3-tiny-ncs-without-last-maxpool-refined-anchors-3cls-extend-remove-maxpooling_new_new_40000/20190527160723567670_ge_shrink_scale_0.3_0_127.5_croped_20190527120053057798_00000070755.xml
# Created : /data/darknet/python/20190529_detection_result/yolov3-tiny-ncs-without-last-maxpool-refined-anchors-3cls-extend-remove-maxpooling_new_new_40000/20190527160724187578_ge_shrink_scale_0.3_0_127.5_croped_20190527120155028475_00000070766.xml
# Created : /data/darknet/python/20190529_detection_result/yolov3-tiny-ncs-without-last-maxpool-refined-anchors-3cls-extend-remove-maxpooling_new_new_40000/20190527160724487948_ge_shrink_scale_0.3_0_127.5_croped_20190527120223799994_00000070771.xml
# Created : /data/darknet/python/20190529_detection_result/yolov3-tiny-ncs-without-last-maxpool-refined-anchors-3cls-extend-remove-maxpooling_new_new_40000/20190527160725280672_ge_shrink_scale_0.3_0_127.5_croped_20190527120339653098_00000070785.xml
# Created : /data/darknet/python/20190529_detection_result/yolov3-tiny-ncs-without-last-maxpool-refined-anchors-3cls-extend-remove-maxpooling_new_new_40000/croped_20190527113500078471_00000070056.xml
# Created : /data/darknet/python/20190529_detection_result/yolov3-tiny-ncs-without-last-maxpool-refined-anchors-3cls-extend-remove-maxpooling_new_new_40000/croped_20190527113529643056_00000070068.xml
# Created : /data/darknet/python/20190529_detection_result/yolov3-tiny-ncs-without-last-maxpool-refined-anchors-3cls-extend-remove-maxpooling_new_new_40000/20190527160726876461_ge_shrink_scale_0.3_0_127.5_croped_20190527120512055648_00000070813.xml
