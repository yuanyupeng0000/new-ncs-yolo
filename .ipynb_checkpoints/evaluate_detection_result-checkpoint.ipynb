# %%
import sys,os,datetime
import cv2
import xml.etree.ElementTree as ET
from PIL import Image
import numpy as np
import random
#from pathlib import Path

from ctypes import *
import math
#cv2_root = "/usr/local/lib-bk/python2.7/dist-packages/cv2"
#sys.path.insert(0,cv2_root)
#cv2_lib_avcodec = "/usr/lib/x86_64-linux-gnu/bkavcodec"
#sys.path.insert(0,cv2_lib_avcodec)
val_txt_file = "/media/yyp/DATA/Public_Datasets/ZENITH_DATASETS/2007_val_hiway.txt"
time_str = (datetime.datetime.now()).strftime("%Y%m%d")
f = open(val_txt_file, 'r')
data = f.readlines()
seed_xml_names = []
GENE_XML_DIR = '/media/yyp/DATA/EVALUATE/' + time_str + '_detection_result/'
#GENE_XML_DIR = '/data/darknet/python/' + time_str + '_detection_result_864/'
for line in data:
    #print line
    xml_name = line.replace('JPEGImages', 'Annotations')
    xml_name = line.replace('.jpg', '.xml')
    seed_xml_names.append(xml_name)
    
'''
data_file = '/data/darknet/cfg/coco.data'
cfg_file = '/data/darknet/cfg/yolov3-nob-288.cfg'
weights_file = '/data/weights/header_int_aaa_yolov3.weights'
'''

#weights_file = '/data/darknet/weights/yolov3-tiny-ncs-without-last-maxpool-refined-anchors_120000.weights'
seed_xml_names.sort()

# %%
def sample(probs):
    s = sum(probs)
    probs = [a/s for a in probs]
    r = random.uniform(0, 1)
    for i in range(len(probs)):
        r = r - probs[i]
        if r <= 0:
            return i
    return len(probs)-1

def c_array(ctype, values):
    arr = (ctype*len(values))()
    arr[:] = values
    return arr

class BOX(Structure):
    _fields_ = [("x", c_float),
                ("y", c_float),
                ("w", c_float),
                ("h", c_float)]

class DETECTION(Structure):
    _fields_ = [("bbox", BOX),
                ("classes", c_int),
                ("prob", POINTER(c_float)),
                ("mask", POINTER(c_float)),
                ("objectness", c_float),
                ("sort_class", c_int)]


class IMAGE(Structure):
    _fields_ = [("w", c_int),
                ("h", c_int),
                ("c", c_int),
                ("data", POINTER(c_float))]

class METADATA(Structure):
    _fields_ = [("classes", c_int),
                ("names", POINTER(c_char_p))]
    
def classify(net, meta, im):
    out = predict_image(net, im)
    res = []
    for i in range(meta.classes):
        res.append((meta.names[i], out[i]))
    res = sorted(res, key=lambda x: -x[1])
    return res

def detect(net, meta, image, thresh=.5, hier_thresh=.5, nms=.45):
    im = load_image(image, 0, 0)
    num = c_int(0)
    pnum = pointer(num)
    predict_image(net, im)
    dets = get_network_boxes(net, im.w, im.h, thresh, hier_thresh, None, 0, pnum)
    num = pnum[0]
    if (nms): do_nms_obj(dets, num, meta.classes, nms);

    res = []
    for j in range(num):
        for i in range(meta.classes):
            if dets[j].prob[i] > 0:
                b = dets[j].bbox
                res.append((meta.names[i], dets[j].prob[i], (b.x, b.y, b.w, b.h)))
    res = sorted(res, key=lambda x: -x[1])
    free_image(im)
    free_detections(dets, num)
    return res
#lib = CDLL("/home/pjreddie/documents/darknet/libdarknet.so", RTLD_GLOBAL)
lib = CDLL("/data/darknet/libdarknet.so", RTLD_GLOBAL)
lib.network_width.argtypes = [c_void_p]
lib.network_width.restype = c_int
lib.network_height.argtypes = [c_void_p]
lib.network_height.restype = c_int

predict = lib.network_predict
predict.argtypes = [c_void_p, POINTER(c_float)]
predict.restype = POINTER(c_float)

set_gpu = lib.cuda_set_device
set_gpu.argtypes = [c_int]

make_image = lib.make_image
make_image.argtypes = [c_int, c_int, c_int]
make_image.restype = IMAGE

get_network_boxes = lib.get_network_boxes
get_network_boxes.argtypes = [c_void_p, c_int, c_int, c_float, c_float, POINTER(c_int), c_int, POINTER(c_int)]
get_network_boxes.restype = POINTER(DETECTION)

make_network_boxes = lib.make_network_boxes
make_network_boxes.argtypes = [c_void_p]
make_network_boxes.restype = POINTER(DETECTION)

free_detections = lib.free_detections
free_detections.argtypes = [POINTER(DETECTION), c_int]

free_ptrs = lib.free_ptrs
free_ptrs.argtypes = [POINTER(c_void_p), c_int]

network_predict = lib.network_predict
network_predict.argtypes = [c_void_p, POINTER(c_float)]

reset_rnn = lib.reset_rnn
reset_rnn.argtypes = [c_void_p]

load_net = lib.load_network
load_net.argtypes = [c_char_p, c_char_p, c_int]
load_net.restype = c_void_p

do_nms_obj = lib.do_nms_obj
do_nms_obj.argtypes = [POINTER(DETECTION), c_int, c_int, c_float]

do_nms_sort = lib.do_nms_sort
do_nms_sort.argtypes = [POINTER(DETECTION), c_int, c_int, c_float]

free_image = lib.free_image
free_image.argtypes = [IMAGE]

letterbox_image = lib.letterbox_image
letterbox_image.argtypes = [IMAGE, c_int, c_int]
letterbox_image.restype = IMAGE

load_meta = lib.get_metadata
lib.get_metadata.argtypes = [c_char_p]
lib.get_metadata.restype = METADATA

load_image = lib.load_image_color
load_image.argtypes = [c_char_p, c_int, c_int]
load_image.restype = IMAGE

rgbgr_image = lib.rgbgr_image
rgbgr_image.argtypes = [IMAGE]

predict_image = lib.network_predict_image
predict_image.argtypes = [c_void_p, IMAGE]
predict_image.restype = POINTER(c_float)

# %%
#data_file = '/data/darknet/cfg/voc-veichle.data'
data_file = '/data/darknet/cfg/voc-vehicle-person.data'
#data_file = '/data/darknet/cfg/coco.data'

all_wieghts_dir = '/media/yyp/DATA/EVALUATE/'
weights = os.listdir(all_wieghts_dir)
weights.sort()
print(weights)
for weight in weights:
    print(weight)
    if(not weight.endswith('.weights')):
        continue
    cfg_file = all_wieghts_dir + weight[:-len(weight.split('_')[-1])] + 'test.cfg'
    print(cfg_file)
    generated_xml_dir = GENE_XML_DIR + weight.split('.weights')[0] + '/'
    #if(os.path.exists(generated_xml_dir)):
    #   continue
    #os.system('rm -rf ' + GENE_XML_DIR)
    os.system('mkdir -p ' + generated_xml_dir)
    weights_file = all_wieghts_dir + weight
    net = load_net(cfg_file, weights_file, 0)
    meta = load_meta(data_file)
    for image_file in data:
        image = image_file.split('/')[-1]
        image = image[:-1]
        if(os.path.exists(generated_xml_dir + image[:-4] + '.xml')):
            continue
        image_file = image_file[:-1]
        ret = image_file.endswith('.jpg')
        if ret == False:
            print('+++++++++++')
            continue
        #print('detect')
        r = detect(net, meta, image_file, 0.3, 0.5, 0.45)
        #print(len(r))

        origimg = cv2.imread(image_file)
        height = origimg.shape[0]
        width = origimg.shape[1]
        depth = origimg.shape[2]

        xml_str = "<annotation>\n\t\
        <folder>image</folder>\n\t\
        <filename>" + image + "</filename>\n\t\
        " + "<path>" + image_file + "</path>\n\t\
        <source>\n\t\t\
        <database>Unknown</database>\n\t\
        </source>\n\t\
        <size>\n\t\t\
        <width>" + str(width) + "</width>\n\t\t\
        <height>" + str(height) + "</height>\n\t\t\
        <depth>" + str(depth) + "</depth>\n\t\
        </size>\n\t\
        <segmented>0</segmented>"
        #print(xml_str)
        found_flag = False
        for i in range(len(r)):
            cls = r[i][0]
            #print(cls)
            if(cls not in ['bus','car','truck', 'motorbike','bicycle','person', 'B', 'C', 'T']):
            #if(cls not in ['person', 'motorbike','bicycle']):
                continue
            found_flag = True
            score = r[i][1]
            bbox = r[i][2]

            x1 = max(0, (bbox[0] - bbox[2]/2))
            y1 = max(0, (bbox[1] - bbox[3]/2))
            x2 = min(width, (bbox[0] + bbox[2]/2))
            y2 = min(height, (bbox[1] + bbox[3]/2))      

            p1 = (int(x1), int(y1))
            p2 = (int(x2), int(y2))

            obj_str = "\n\t\
            <object>\n\t\t\
            <name>" + cls + "</name>\n\t\t\
            <pose>Unspecified</pose>\n\t\t\
            <truncated>0</truncated>\n\t\t\
            <difficult>0</difficult>\n\t\t\
            <bndbox>\n\t\t\t\
            <xmin>" + str(int(x1)) + "</xmin>\n\t\t\t\
            <ymin>" + str(int(y1)) + "</ymin>\n\t\t\t\
            <xmax>" + str(int(x2)) + "</xmax>\n\t\t\t\
            <ymax>" + str(int(y2)) + "</ymax>\n\t\t\
            </bndbox>\n\t\
            </object>"

            xml_str += obj_str

            cv2.rectangle(origimg, p1, p2, (0,255,0))
            p3 = (max(p1[0], 15), max(p1[1], 15))
            title = "%s:%.2f" % (cls, score)
            cv2.putText(origimg, title, p3, cv2.FONT_ITALIC, 0.6, (0, 255, 0), 1)
        xml_str += "\n</annotation>"
        #print('found_flag {0}'.format(found_flag))
        if (not found_flag):
            continue
        fileObject = open(generated_xml_dir + image[:-4] + '.xml', 'w')  
        fileObject.write(xml_str)
        fileObject.close()
        #cv2.imwrite('/data/'+ image_file.split('/')[-1], origimg)
        print("Created : " + generated_xml_dir + image[:-4] + '.xml')
# Out:
# ['20190718_detection_result', 'bak', 'yolov3-tiny-ncs-without-last-maxpool-refined-anchors-6cls-extend-remove-maxpooling_new_150000.weights', 'yolov3-tiny-ncs-without-last-maxpool-refined-anchors-6cls-extend-remove-maxpooling_new_test.cfg', 'yolov3-tiny-ncs-without-last-maxpool-refined-anchors_112100.weights', 'yolov3-tiny-ncs-without-last-maxpool-refined-anchors_130000cars.weights', 'yolov3-tiny-ncs-without-last-maxpool-refined-anchors_150000cars.weights', 'yolov3-tiny-ncs-without-last-maxpool-refined-anchors_150000old.weights', 'yolov3-tiny-ncs-without-last-maxpool-refined-anchors_test.cfg', 'yolov3_nob_official_test.cfg']
# 20190718_detection_result
# bak
# yolov3-tiny-ncs-without-last-maxpool-refined-anchors-6cls-extend-remove-maxpooling_new_150000.weights
# /media/yyp/DATA/EVALUATE/yolov3-tiny-ncs-without-last-maxpool-refined-anchors-6cls-extend-remove-maxpooling_new_test.cfg
# yolov3-tiny-ncs-without-last-maxpool-refined-anchors-6cls-extend-remove-maxpooling_new_test.cfg
# yolov3-tiny-ncs-without-last-maxpool-refined-anchors_112100.weights
# /media/yyp/DATA/EVALUATE/yolov3-tiny-ncs-without-last-maxpool-refined-anchors_test.cfg
# Created : /media/yyp/DATA/EVALUATE/20190718_detection_result/yolov3-tiny-ncs-without-last-maxpool-refined-anchors_112100/00000002713.xml
# Created : /media/yyp/DATA/EVALUATE/20190718_detection_result/yolov3-tiny-ncs-without-last-maxpool-refined-anchors_112100/00000200018.xml
# Created : /media/yyp/DATA/EVALUATE/20190718_detection_result/yolov3-tiny-ncs-without-last-maxpool-refined-anchors_112100/00000200025.xml
# Created : /media/yyp/DATA/EVALUATE/20190718_detection_result/yolov3-tiny-ncs-without-last-maxpool-refined-anchors_112100/00000200042.xml
# Created : /media/yyp/DATA/EVALUATE/20190718_detection_result/yolov3-tiny-ncs-without-last-maxpool-refined-anchors_112100/00000200046.xml
# Created : /media/yyp/DATA/EVALUATE/20190718_detection_result/yolov3-tiny-ncs-without-last-maxpool-refined-anchors_112100/00000200048.xml
# Created : /media/yyp/DATA/EVALUATE/20190718_detection_result/yolov3-tiny-ncs-without-last-maxpool-refined-anchors_112100/00000200052.xml
# Created : /media/yyp/DATA/EVALUATE/20190718_detection_result/yolov3-tiny-ncs-without-last-maxpool-refined-anchors_112100/00000201199.xml
# Created : /media/yyp/DATA/EVALUATE/20190718_detection_result/yolov3-tiny-ncs-without-last-maxpool-refined-anchors_112100/00000200089.xml
# Created : /media/yyp/DATA/EVALUATE/20190718_detection_result/yolov3-tiny-ncs-without-last-maxpool-refined-anchors_112100/00000200203.xml
# Created : /media/yyp/DATA/EVALUATE/20190718_detection_result/yolov3-tiny-ncs-without-last-maxpool-refined-anchors_112100/00000200217.xml
# Created : /media/yyp/DATA/EVALUATE/20190718_detection_result/yolov3-tiny-ncs-without-last-maxpool-refined-anchors_112100/00000200302.xml
# Created : /media/yyp/DATA/EVALUATE/20190718_detection_result/yolov3-tiny-ncs-without-last-maxpool-refined-anchors_112100/00000200360.xml
# Created : /media/yyp/DATA/EVALUATE/20190718_detection_result/yolov3-tiny-ncs-without-last-maxpool-refined-anchors_112100/00000200401.xml
# Created : /media/yyp/DATA/EVALUATE/20190718_detection_result/yolov3-tiny-ncs-without-last-maxpool-refined-anchors_112100/00000200770.xml
# Created : /media/yyp/DATA/EVALUATE/20190718_detection_result/yolov3-tiny-ncs-without-last-maxpool-refined-anchors_112100/00000200971.xml
# Created : /media/yyp/DATA/EVALUATE/20190718_detection_result/yolov3-tiny-ncs-without-last-maxpool-refined-anchors_112100/00000201203.xml
# Created : /media/yyp/DATA/EVALUATE/20190718_detection_result/yolov3-tiny-ncs-without-last-maxpool-refined-anchors_112100/00000201207.xml
# Created : /media/yyp/DATA/EVALUATE/20190718_detection_result/yolov3-tiny-ncs-without-last-maxpool-refined-anchors_112100/00000201208.xml
# Created : /media/yyp/DATA/EVALUATE/20190718_detection_result/yolov3-tiny-ncs-without-last-maxpool-refined-anchors_112100/00000201211.xml
# Created : /media/yyp/DATA/EVALUATE/20190718_detection_result/yolov3-tiny-ncs-without-last-maxpool-refined-anchors_112100/00000201215.xml
# Created : /media/yyp/DATA/EVALUATE/20190718_detection_result/yolov3-tiny-ncs-without-last-maxpool-refined-anchors_112100/00000201222.xml
# Created : /media/yyp/DATA/EVALUATE/20190718_detection_result/yolov3-tiny-ncs-without-last-maxpool-refined-anchors_112100/00000201229.xml
# Created : /media/yyp/DATA/EVALUATE/20190718_detection_result/yolov3-tiny-ncs-without-last-maxpool-refined-anchors_112100/00000201249.xml
# Created : /media/yyp/DATA/EVALUATE/20190718_detection_result/yolov3-tiny-ncs-without-last-maxpool-refined-anchors_112100/00000201317.xml
# Created : /media/yyp/DATA/EVALUATE/20190718_detection_result/yolov3-tiny-ncs-without-last-maxpool-refined-anchors_112100/00000201334.xml
# Created : /media/yyp/DATA/EVALUATE/20190718_detection_result/yolov3-tiny-ncs-without-last-maxpool-refined-anchors_112100/00000201339.xml
# Created : /media/yyp/DATA/EVALUATE/20190718_detection_result/yolov3-tiny-ncs-without-last-maxpool-refined-anchors_112100/00000201345.xml
# Created : /media/yyp/DATA/EVALUATE/20190718_detection_result/yolov3-tiny-ncs-without-last-maxpool-refined-anchors_112100/00000201403.xml
# Created : /media/yyp/DATA/EVALUATE/20190718_detection_result/yolov3-tiny-ncs-without-last-maxpool-refined-anchors_112100/00000201428.xml
# Created : /media/yyp/DATA/EVALUATE/20190718_detection_result/yolov3-tiny-ncs-without-last-maxpool-refined-anchors_112100/00000201555.xml
# Created : /media/yyp/DATA/EVALUATE/20190718_detection_result/yolov3-tiny-ncs-without-last-maxpool-refined-anchors_112100/00000201561.xml
# Created : /media/yyp/DATA/EVALUATE/20190718_detection_result/yolov3-tiny-ncs-without-last-maxpool-refined-anchors_112100/00000201583.xml
# Created : /media/yyp/DATA/EVALUATE/20190718_detection_result/yolov3-tiny-ncs-without-last-maxpool-refined-anchors_112100/00000201584.xml
# Created : /media/yyp/DATA/EVALUATE/20190718_detection_result/yolov3-tiny-ncs-without-last-maxpool-refined-anchors_112100/00000201683.xml
# Created : /media/yyp/DATA/EVALUATE/20190718_detection_result/yolov3-tiny-ncs-without-last-maxpool-refined-anchors_112100/00000201686.xml
# Created : /media/yyp/DATA/EVALUATE/20190718_detection_result/yolov3-tiny-ncs-without-last-maxpool-refined-anchors_112100/00000201689.xml
# Created : /media/yyp/DATA/EVALUATE/20190718_detection_result/yolov3-tiny-ncs-without-last-maxpool-refined-anchors_112100/00000201695.xml
# Created : /media/yyp/DATA/EVALUATE/20190718_detection_result/yolov3-tiny-ncs-without-last-maxpool-refined-anchors_112100/00000201705.xml
# Created : /media/yyp/DATA/EVALUATE/20190718_detection_result/yolov3-tiny-ncs-without-last-maxpool-refined-anchors_112100/00000201714.xml
# Created : /media/yyp/DATA/EVALUATE/20190718_detection_result/yolov3-tiny-ncs-without-last-maxpool-refined-anchors_112100/00000201716.xml
# Created : /media/yyp/DATA/EVALUATE/20190718_detection_result/yolov3-tiny-ncs-without-last-maxpool-refined-anchors_112100/00000201720.xml
# Created : /media/yyp/DATA/EVALUATE/20190718_detection_result/yolov3-tiny-ncs-without-last-maxpool-refined-anchors_112100/00000201745.xml
# Created : /media/yyp/DATA/EVALUATE/20190718_detection_result/yolov3-tiny-ncs-without-last-maxpool-refined-anchors_112100/00000201746.xml
# Created : /media/yyp/DATA/EVALUATE/20190718_detection_result/yolov3-tiny-ncs-without-last-maxpool-refined-anchors_112100/00000201747.xml
# Created : /media/yyp/DATA/EVALUATE/20190718_detection_result/yolov3-tiny-ncs-without-last-maxpool-refined-anchors_112100/00000201817.xml
# Created : /media/yyp/DATA/EVALUATE/20190718_detection_result/yolov3-tiny-ncs-without-last-maxpool-refined-anchors_112100/00000201821.xml
# Created : /media/yyp/DATA/EVALUATE/20190718_detection_result/yolov3-tiny-ncs-without-last-maxpool-refined-anchors_112100/00000201878.xml
# Created : /media/yyp/DATA/EVALUATE/20190718_detection_result/yolov3-tiny-ncs-without-last-maxpool-refined-anchors_112100/00000201881.xml
# Created : /media/yyp/DATA/EVALUATE/20190718_detection_result/yolov3-tiny-ncs-without-last-maxpool-refined-anchors_112100/00000201882.xml
# Created : /media/yyp/DATA/EVALUATE/20190718_detection_result/yolov3-tiny-ncs-without-last-maxpool-refined-anchors_112100/00000201889.xml
# Created : /media/yyp/DATA/EVALUATE/20190718_detection_result/yolov3-tiny-ncs-without-last-maxpool-refined-anchors_112100/00000201900.xml
# Created : /media/yyp/DATA/EVALUATE/20190718_detection_result/yolov3-tiny-ncs-without-last-maxpool-refined-anchors_112100/00000201901.xml
# Created : /media/yyp/DATA/EVALUATE/20190718_detection_result/yolov3-tiny-ncs-without-last-maxpool-refined-anchors_112100/00000201908.xml
# Created : /media/yyp/DATA/EVALUATE/20190718_detection_result/yolov3-tiny-ncs-without-last-maxpool-refined-anchors_112100/00000201911.xml
# Created : /media/yyp/DATA/EVALUATE/20190718_detection_result/yolov3-tiny-ncs-without-last-maxpool-refined-anchors_112100/00000201937.xml
# Created : /media/yyp/DATA/EVALUATE/20190718_detection_result/yolov3-tiny-ncs-without-last-maxpool-refined-anchors_112100/00000201941.xml
# Created : /media/yyp/DATA/EVALUATE/20190718_detection_result/yolov3-tiny-ncs-without-last-maxpool-refined-anchors_112100/00000201983.xml
# Created : /media/yyp/DATA/EVALUATE/20190718_detection_result/yolov3-tiny-ncs-without-last-maxpool-refined-anchors_112100/00000201987.xml
# Created : /media/yyp/DATA/EVALUATE/20190718_detection_result/yolov3-tiny-ncs-without-last-maxpool-refined-anchors_112100/00000202007.xml
# Created : /media/yyp/DATA/EVALUATE/20190718_detection_result/yolov3-tiny-ncs-without-last-maxpool-refined-anchors_112100/00000202017.xml
# Created : /media/yyp/DATA/EVALUATE/20190718_detection_result/yolov3-tiny-ncs-without-last-maxpool-refined-anchors_112100/00000202021.xml
# Created : /media/yyp/DATA/EVALUATE/20190718_detection_result/yolov3-tiny-ncs-without-last-maxpool-refined-anchors_112100/00000202026.xml
# Created : /media/yyp/DATA/EVALUATE/20190718_detection_result/yolov3-tiny-ncs-without-last-maxpool-refined-anchors_112100/00000202032.xml
# Created : /media/yyp/DATA/EVALUATE/20190718_detection_result/yolov3-tiny-ncs-without-last-maxpool-refined-anchors_112100/00000202036.xml
# Created : /media/yyp/DATA/EVALUATE/20190718_detection_result/yolov3-tiny-ncs-without-last-maxpool-refined-anchors_112100/00000202038.xml
# Created : /media/yyp/DATA/EVALUATE/20190718_detection_result/yolov3-tiny-ncs-without-last-maxpool-refined-anchors_112100/00000202040.xml
# Created : /media/yyp/DATA/EVALUATE/20190718_detection_result/yolov3-tiny-ncs-without-last-maxpool-refined-anchors_112100/00000202059.xml
# Created : /media/yyp/DATA/EVALUATE/20190718_detection_result/yolov3-tiny-ncs-without-last-maxpool-refined-anchors_112100/00000202061.xml
# Created : /media/yyp/DATA/EVALUATE/20190718_detection_result/yolov3-tiny-ncs-without-last-maxpool-refined-anchors_112100/00000202109.xml
# Created : /media/yyp/DATA/EVALUATE/20190718_detection_result/yolov3-tiny-ncs-without-last-maxpool-refined-anchors_112100/00000202123.xml
# Created : /media/yyp/DATA/EVALUATE/20190718_detection_result/yolov3-tiny-ncs-without-last-maxpool-refined-anchors_112100/00000202130.xml
# Created : /media/yyp/DATA/EVALUATE/20190718_detection_result/yolov3-tiny-ncs-without-last-maxpool-refined-anchors_112100/00000202132.xml
# Created : /media/yyp/DATA/EVALUATE/20190718_detection_result/yolov3-tiny-ncs-without-last-maxpool-refined-anchors_112100/00000202138.xml
# Created : /media/yyp/DATA/EVALUATE/20190718_detection_result/yolov3-tiny-ncs-without-last-maxpool-refined-anchors_112100/00000202141.xml
# Created : /media/yyp/DATA/EVALUATE/20190718_detection_result/yolov3-tiny-ncs-without-last-maxpool-refined-anchors_112100/00000202153.xml
# Created : /media/yyp/DATA/EVALUATE/20190718_detection_result/yolov3-tiny-ncs-without-last-maxpool-refined-anchors_112100/00000202157.xml
# Created : /media/yyp/DATA/EVALUATE/20190718_detection_result/yolov3-tiny-ncs-without-last-maxpool-refined-anchors_112100/00000202163.xml
# Created : /media/yyp/DATA/EVALUATE/20190718_detection_result/yolov3-tiny-ncs-without-last-maxpool-refined-anchors_112100/00000202168.xml
# Created : /media/yyp/DATA/EVALUATE/20190718_detection_result/yolov3-tiny-ncs-without-last-maxpool-refined-anchors_112100/00000202172.xml
# Created : /media/yyp/DATA/EVALUATE/20190718_detection_result/yolov3-tiny-ncs-without-last-maxpool-refined-anchors_112100/00000202181.xml
# Created : /media/yyp/DATA/EVALUATE/20190718_detection_result/yolov3-tiny-ncs-without-last-maxpool-refined-anchors_112100/00000202182.xml
# Created : /media/yyp/DATA/EVALUATE/20190718_detection_result/yolov3-tiny-ncs-without-last-maxpool-refined-anchors_112100/00000202191.xml
# Created : /media/yyp/DATA/EVALUATE/20190718_detection_result/yolov3-tiny-ncs-without-last-maxpool-refined-anchors_112100/00000202202.xml
# Created : /media/yyp/DATA/EVALUATE/20190718_detection_result/yolov3-tiny-ncs-without-last-maxpool-refined-anchors_112100/00000202210.xml
# Created : /media/yyp/DATA/EVALUATE/20190718_detection_result/yolov3-tiny-ncs-without-last-maxpool-refined-anchors_112100/00000202217.xml
# Created : /media/yyp/DATA/EVALUATE/20190718_detection_result/yolov3-tiny-ncs-without-last-maxpool-refined-anchors_112100/00000202258.xml
# Created : /media/yyp/DATA/EVALUATE/20190718_detection_result/yolov3-tiny-ncs-without-last-maxpool-refined-anchors_112100/00000202259.xml
# Created : /media/yyp/DATA/EVALUATE/20190718_detection_result/yolov3-tiny-ncs-without-last-maxpool-refined-anchors_112100/00000202265.xml
# Created : /media/yyp/DATA/EVALUATE/20190718_detection_result/yolov3-tiny-ncs-without-last-maxpool-refined-anchors_112100/00000202269.xml
# Created : /media/yyp/DATA/EVALUATE/20190718_detection_result/yolov3-tiny-ncs-without-last-maxpool-refined-anchors_112100/00000202314.xml
# Created : /media/yyp/DATA/EVALUATE/20190718_detection_result/yolov3-tiny-ncs-without-last-maxpool-refined-anchors_112100/00000202318.xml
# Created : /media/yyp/DATA/EVALUATE/20190718_detection_result/yolov3-tiny-ncs-without-last-maxpool-refined-anchors_112100/00000202331.xml
# Created : /media/yyp/DATA/EVALUATE/20190718_detection_result/yolov3-tiny-ncs-without-last-maxpool-refined-anchors_112100/00000202338.xml
# Created : /media/yyp/DATA/EVALUATE/20190718_detection_result/yolov3-tiny-ncs-without-last-maxpool-refined-anchors_112100/00000202361.xml
# Created : /media/yyp/DATA/EVALUATE/20190718_detection_result/yolov3-tiny-ncs-without-last-maxpool-refined-anchors_112100/00000202393.xml
# Created : /media/yyp/DATA/EVALUATE/20190718_detection_result/yolov3-tiny-ncs-without-last-maxpool-refined-anchors_112100/00000202394.xml
# Created : /media/yyp/DATA/EVALUATE/20190718_detection_result/yolov3-tiny-ncs-without-last-maxpool-refined-anchors_112100/00000202412.xml
# Created : /media/yyp/DATA/EVALUATE/20190718_detection_result/yolov3-tiny-ncs-without-last-maxpool-refined-anchors_112100/00000202431.xml
# Created : /media/yyp/DATA/EVALUATE/20190718_detection_result/yolov3-tiny-ncs-without-last-maxpool-refined-anchors_112100/00000202487.xml
# Created : /media/yyp/DATA/EVALUATE/20190718_detection_result/yolov3-tiny-ncs-without-last-maxpool-refined-anchors_112100/00000202496.xml
# Created : /media/yyp/DATA/EVALUATE/20190718_detection_result/yolov3-tiny-ncs-without-last-maxpool-refined-anchors_112100/00000202503.xml
# Created : /media/yyp/DATA/EVALUATE/20190718_detection_result/yolov3-tiny-ncs-without-last-maxpool-refined-anchors_112100/00000202513.xml
# Created : /media/yyp/DATA/EVALUATE/20190718_detection_result/yolov3-tiny-ncs-without-last-maxpool-refined-anchors_112100/00000202527.xml
# Created : /media/yyp/DATA/EVALUATE/20190718_detection_result/yolov3-tiny-ncs-without-last-maxpool-refined-anchors_112100/00000202533.xml
# Created : /media/yyp/DATA/EVALUATE/20190718_detection_result/yolov3-tiny-ncs-without-last-maxpool-refined-anchors_112100/00000202534.xml
# Created : /media/yyp/DATA/EVALUATE/20190718_detection_result/yolov3-tiny-ncs-without-last-maxpool-refined-anchors_112100/00000202535.xml
# Created : /media/yyp/DATA/EVALUATE/20190718_detection_result/yolov3-tiny-ncs-without-last-maxpool-refined-anchors_112100/00000202563.xml
# Created : /media/yyp/DATA/EVALUATE/20190718_detection_result/yolov3-tiny-ncs-without-last-maxpool-refined-anchors_112100/00000202278.xml
# Created : /media/yyp/DATA/EVALUATE/20190718_detection_result/yolov3-tiny-ncs-without-last-maxpool-refined-anchors_112100/00000202370.xml
# Created : /media/yyp/DATA/EVALUATE/20190718_detection_result/yolov3-tiny-ncs-without-last-maxpool-refined-anchors_112100/00000202568.xml
# Created : /media/yyp/DATA/EVALUATE/20190718_detection_result/yolov3-tiny-ncs-without-last-maxpool-refined-anchors_112100/00000202570.xml
# Created : /media/yyp/DATA/EVALUATE/20190718_detection_result/yolov3-tiny-ncs-without-last-maxpool-refined-anchors_112100/00000202573.xml
# Created : /media/yyp/DATA/EVALUATE/20190718_detection_result/yolov3-tiny-ncs-without-last-maxpool-refined-anchors_112100/00000202584.xml
# Created : /media/yyp/DATA/EVALUATE/20190718_detection_result/yolov3-tiny-ncs-without-last-maxpool-refined-anchors_112100/00000202592.xml
# Created : /media/yyp/DATA/EVALUATE/20190718_detection_result/yolov3-tiny-ncs-without-last-maxpool-refined-anchors_112100/00000202594.xml
# Created : /media/yyp/DATA/EVALUATE/20190718_detection_result/yolov3-tiny-ncs-without-last-maxpool-refined-anchors_112100/00000202606.xml
# Created : /media/yyp/DATA/EVALUATE/20190718_detection_result/yolov3-tiny-ncs-without-last-maxpool-refined-anchors_112100/00000202607.xml
# Created : /media/yyp/DATA/EVALUATE/20190718_detection_result/yolov3-tiny-ncs-without-last-maxpool-refined-anchors_112100/00000202614.xml
# Created : /media/yyp/DATA/EVALUATE/20190718_detection_result/yolov3-tiny-ncs-without-last-maxpool-refined-anchors_112100/00000202617.xml
# Created : /media/yyp/DATA/EVALUATE/20190718_detection_result/yolov3-tiny-ncs-without-last-maxpool-refined-anchors_112100/00000202620.xml
# Created : /media/yyp/DATA/EVALUATE/20190718_detection_result/yolov3-tiny-ncs-without-last-maxpool-refined-anchors_112100/00000202634.xml
# Created : /media/yyp/DATA/EVALUATE/20190718_detection_result/yolov3-tiny-ncs-without-last-maxpool-refined-anchors_112100/00000202638.xml
# Created : /media/yyp/DATA/EVALUATE/20190718_detection_result/yolov3-tiny-ncs-without-last-maxpool-refined-anchors_112100/00000202650.xml
# Created : /media/yyp/DATA/EVALUATE/20190718_detection_result/yolov3-tiny-ncs-without-last-maxpool-refined-anchors_112100/00000202668.xml
# Created : /media/yyp/DATA/EVALUATE/20190718_detection_result/yolov3-tiny-ncs-without-last-maxpool-refined-anchors_112100/00000202698.xml
# Created : /media/yyp/DATA/EVALUATE/20190718_detection_result/yolov3-tiny-ncs-without-last-maxpool-refined-anchors_112100/00000202751.xml
# Created : /media/yyp/DATA/EVALUATE/20190718_detection_result/yolov3-tiny-ncs-without-last-maxpool-refined-anchors_112100/00000202761.xml
# Created : /media/yyp/DATA/EVALUATE/20190718_detection_result/yolov3-tiny-ncs-without-last-maxpool-refined-anchors_112100/00000202766.xml
# Created : /media/yyp/DATA/EVALUATE/20190718_detection_result/yolov3-tiny-ncs-without-last-maxpool-refined-anchors_112100/00000202775.xml
# Created : /media/yyp/DATA/EVALUATE/20190718_detection_result/yolov3-tiny-ncs-without-last-maxpool-refined-anchors_112100/00000202812.xml
# Created : /media/yyp/DATA/EVALUATE/20190718_detection_result/yolov3-tiny-ncs-without-last-maxpool-refined-anchors_112100/00000202869.xml
# Created : /media/yyp/DATA/EVALUATE/20190718_detection_result/yolov3-tiny-ncs-without-last-maxpool-refined-anchors_112100/00000202909.xml
# Created : /media/yyp/DATA/EVALUATE/20190718_detection_result/yolov3-tiny-ncs-without-last-maxpool-refined-anchors_112100/00000202950.xml
# Created : /media/yyp/DATA/EVALUATE/20190718_detection_result/yolov3-tiny-ncs-without-last-maxpool-refined-anchors_112100/00000202968.xml
# Created : /media/yyp/DATA/EVALUATE/20190718_detection_result/yolov3-tiny-ncs-without-last-maxpool-refined-anchors_112100/00000202972.xml
# Created : /media/yyp/DATA/EVALUATE/20190718_detection_result/yolov3-tiny-ncs-without-last-maxpool-refined-anchors_112100/00000202976.xml
# Created : /media/yyp/DATA/EVALUATE/20190718_detection_result/yolov3-tiny-ncs-without-last-maxpool-refined-anchors_112100/00000202989.xml
# Created : /media/yyp/DATA/EVALUATE/20190718_detection_result/yolov3-tiny-ncs-without-last-maxpool-refined-anchors_112100/00000202813.xml
# Created : /media/yyp/DATA/EVALUATE/20190718_detection_result/yolov3-tiny-ncs-without-last-maxpool-refined-anchors_112100/00000204588.xml
# Created : /media/yyp/DATA/EVALUATE/20190718_detection_result/yolov3-tiny-ncs-without-last-maxpool-refined-anchors_112100/00000206861.xml
# Created : /media/yyp/DATA/EVALUATE/20190718_detection_result/yolov3-tiny-ncs-without-last-maxpool-refined-anchors_112100/00000203007.xml
# Created : /media/yyp/DATA/EVALUATE/20190718_detection_result/yolov3-tiny-ncs-without-last-maxpool-refined-anchors_112100/00000203019.xml
# Created : /media/yyp/DATA/EVALUATE/20190718_detection_result/yolov3-tiny-ncs-without-last-maxpool-refined-anchors_112100/00000203048.xml
# Created : /media/yyp/DATA/EVALUATE/20190718_detection_result/yolov3-tiny-ncs-without-last-maxpool-refined-anchors_112100/00000203079.xml
# Created : /media/yyp/DATA/EVALUATE/20190718_detection_result/yolov3-tiny-ncs-without-last-maxpool-refined-anchors_112100/00000203109.xml
# Created : /media/yyp/DATA/EVALUATE/20190718_detection_result/yolov3-tiny-ncs-without-last-maxpool-refined-anchors_112100/00000203118.xml
# Created : /media/yyp/DATA/EVALUATE/20190718_detection_result/yolov3-tiny-ncs-without-last-maxpool-refined-anchors_112100/00000203120.xml
# Created : /media/yyp/DATA/EVALUATE/20190718_detection_result/yolov3-tiny-ncs-without-last-maxpool-refined-anchors_112100/00000203136.xml
# Created : /media/yyp/DATA/EVALUATE/20190718_detection_result/yolov3-tiny-ncs-without-last-maxpool-refined-anchors_112100/00000203163.xml
# Created : /media/yyp/DATA/EVALUATE/20190718_detection_result/yolov3-tiny-ncs-without-last-maxpool-refined-anchors_112100/00000203195.xml
# Created : /media/yyp/DATA/EVALUATE/20190718_detection_result/yolov3-tiny-ncs-without-last-maxpool-refined-anchors_112100/00000203258.xml
# Created : /media/yyp/DATA/EVALUATE/20190718_detection_result/yolov3-tiny-ncs-without-last-maxpool-refined-anchors_112100/00000203260.xml
# Created : /media/yyp/DATA/EVALUATE/20190718_detection_result/yolov3-tiny-ncs-without-last-maxpool-refined-anchors_112100/00000203282.xml
# Created : /media/yyp/DATA/EVALUATE/20190718_detection_result/yolov3-tiny-ncs-without-last-maxpool-refined-anchors_112100/00000203293.xml
# Created : /media/yyp/DATA/EVALUATE/20190718_detection_result/yolov3-tiny-ncs-without-last-maxpool-refined-anchors_112100/00000203294.xml
# Created : /media/yyp/DATA/EVALUATE/20190718_detection_result/yolov3-tiny-ncs-without-last-maxpool-refined-anchors_112100/00000203295.xml
# Created : /media/yyp/DATA/EVALUATE/20190718_detection_result/yolov3-tiny-ncs-without-last-maxpool-refined-anchors_112100/00000203299.xml
# Created : /media/yyp/DATA/EVALUATE/20190718_detection_result/yolov3-tiny-ncs-without-last-maxpool-refined-anchors_112100/00000203307.xml
# Created : /media/yyp/DATA/EVALUATE/20190718_detection_result/yolov3-tiny-ncs-without-last-maxpool-refined-anchors_112100/00000203314.xml
# Created : /media/yyp/DATA/EVALUATE/20190718_detection_result/yolov3-tiny-ncs-without-last-maxpool-refined-anchors_112100/00000203320.xml
# Created : /media/yyp/DATA/EVALUATE/20190718_detection_result/yolov3-tiny-ncs-without-last-maxpool-refined-anchors_112100/00000203343.xml
# Created : /media/yyp/DATA/EVALUATE/20190718_detection_result/yolov3-tiny-ncs-without-last-maxpool-refined-anchors_112100/00000203351.xml
# Created : /media/yyp/DATA/EVALUATE/20190718_detection_result/yolov3-tiny-ncs-without-last-maxpool-refined-anchors_112100/00000203410.xml
# Created : /media/yyp/DATA/EVALUATE/20190718_detection_result/yolov3-tiny-ncs-without-last-maxpool-refined-anchors_112100/00000203465.xml
# Created : /media/yyp/DATA/EVALUATE/20190718_detection_result/yolov3-tiny-ncs-without-last-maxpool-refined-anchors_112100/00000203504.xml
# Created : /media/yyp/DATA/EVALUATE/20190718_detection_result/yolov3-tiny-ncs-without-last-maxpool-refined-anchors_112100/00000203514.xml
# Created : /media/yyp/DATA/EVALUATE/20190718_detection_result/yolov3-tiny-ncs-without-last-maxpool-refined-anchors_112100/00000203540.xml
# Created : /media/yyp/DATA/EVALUATE/20190718_detection_result/yolov3-tiny-ncs-without-last-maxpool-refined-anchors_112100/00000203552.xml
# Created : /media/yyp/DATA/EVALUATE/20190718_detection_result/yolov3-tiny-ncs-without-last-maxpool-refined-anchors_112100/00000203557.xml
# Created : /media/yyp/DATA/EVALUATE/20190718_detection_result/yolov3-tiny-ncs-without-last-maxpool-refined-anchors_112100/00000203070.xml
# Created : /media/yyp/DATA/EVALUATE/20190718_detection_result/yolov3-tiny-ncs-without-last-maxpool-refined-anchors_112100/00000203509.xml
# Created : /media/yyp/DATA/EVALUATE/20190718_detection_result/yolov3-tiny-ncs-without-last-maxpool-refined-anchors_112100/00000203564.xml
# Created : /media/yyp/DATA/EVALUATE/20190718_detection_result/yolov3-tiny-ncs-without-last-maxpool-refined-anchors_112100/00000203654.xml
# Created : /media/yyp/DATA/EVALUATE/20190718_detection_result/yolov3-tiny-ncs-without-last-maxpool-refined-anchors_112100/00000203665.xml
# Created : /media/yyp/DATA/EVALUATE/20190718_detection_result/yolov3-tiny-ncs-without-last-maxpool-refined-anchors_112100/00000203718.xml
# Created : /media/yyp/DATA/EVALUATE/20190718_detection_result/yolov3-tiny-ncs-without-last-maxpool-refined-anchors_112100/00000203726.xml
# Created : /media/yyp/DATA/EVALUATE/20190718_detection_result/yolov3-tiny-ncs-without-last-maxpool-refined-anchors_112100/00000203756.xml
# Created : /media/yyp/DATA/EVALUATE/20190718_detection_result/yolov3-tiny-ncs-without-last-maxpool-refined-anchors_112100/00000203788.xml
# Created : /media/yyp/DATA/EVALUATE/20190718_detection_result/yolov3-tiny-ncs-without-last-maxpool-refined-anchors_112100/00000203795.xml
# Created : /media/yyp/DATA/EVALUATE/20190718_detection_result/yolov3-tiny-ncs-without-last-maxpool-refined-anchors_112100/00000203810.xml
# Created : /media/yyp/DATA/EVALUATE/20190718_detection_result/yolov3-tiny-ncs-without-last-maxpool-refined-anchors_112100/00000203820.xml
# Created : /media/yyp/DATA/EVALUATE/20190718_detection_result/yolov3-tiny-ncs-without-last-maxpool-refined-anchors_112100/00000203822.xml
# Created : /media/yyp/DATA/EVALUATE/20190718_detection_result/yolov3-tiny-ncs-without-last-maxpool-refined-anchors_112100/00000203827.xml
# Created : /media/yyp/DATA/EVALUATE/20190718_detection_result/yolov3-tiny-ncs-without-last-maxpool-refined-anchors_112100/00000203834.xml
# Created : /media/yyp/DATA/EVALUATE/20190718_detection_result/yolov3-tiny-ncs-without-last-maxpool-refined-anchors_112100/00000203835.xml
# Created : /media/yyp/DATA/EVALUATE/20190718_detection_result/yolov3-tiny-ncs-without-last-maxpool-refined-anchors_112100/00000203862.xml
# Created : /media/yyp/DATA/EVALUATE/20190718_detection_result/yolov3-tiny-ncs-without-last-maxpool-refined-anchors_112100/00000203863.xml
# Created : /media/yyp/DATA/EVALUATE/20190718_detection_result/yolov3-tiny-ncs-without-last-maxpool-refined-anchors_112100/00000203887.xml
# Created : /media/yyp/DATA/EVALUATE/20190718_detection_result/yolov3-tiny-ncs-without-last-maxpool-refined-anchors_112100/00000203893.xml
# Created : /media/yyp/DATA/EVALUATE/20190718_detection_result/yolov3-tiny-ncs-without-last-maxpool-refined-anchors_112100/00000203897.xml
# Created : /media/yyp/DATA/EVALUATE/20190718_detection_result/yolov3-tiny-ncs-without-last-maxpool-refined-anchors_112100/00000203899.xml
# Created : /media/yyp/DATA/EVALUATE/20190718_detection_result/yolov3-tiny-ncs-without-last-maxpool-refined-anchors_112100/00000203926.xml
# Created : /media/yyp/DATA/EVALUATE/20190718_detection_result/yolov3-tiny-ncs-without-last-maxpool-refined-anchors_112100/00000204085.xml
# Created : /media/yyp/DATA/EVALUATE/20190718_detection_result/yolov3-tiny-ncs-without-last-maxpool-refined-anchors_112100/00000204096.xml
# Created : /media/yyp/DATA/EVALUATE/20190718_detection_result/yolov3-tiny-ncs-without-last-maxpool-refined-anchors_112100/00000204106.xml
# Created : /media/yyp/DATA/EVALUATE/20190718_detection_result/yolov3-tiny-ncs-without-last-maxpool-refined-anchors_112100/00000204125.xml
# Created : /media/yyp/DATA/EVALUATE/20190718_detection_result/yolov3-tiny-ncs-without-last-maxpool-refined-anchors_112100/00000204129.xml
# Created : /media/yyp/DATA/EVALUATE/20190718_detection_result/yolov3-tiny-ncs-without-last-maxpool-refined-anchors_112100/00000204137.xml
# Created : /media/yyp/DATA/EVALUATE/20190718_detection_result/yolov3-tiny-ncs-without-last-maxpool-refined-anchors_112100/00000204151.xml
# Created : /media/yyp/DATA/EVALUATE/20190718_detection_result/yolov3-tiny-ncs-without-last-maxpool-refined-anchors_112100/00000204152.xml
# Created : /media/yyp/DATA/EVALUATE/20190718_detection_result/yolov3-tiny-ncs-without-last-maxpool-refined-anchors_112100/00000204158.xml
# Created : /media/yyp/DATA/EVALUATE/20190718_detection_result/yolov3-tiny-ncs-without-last-maxpool-refined-anchors_112100/00000204198.xml
# Created : /media/yyp/DATA/EVALUATE/20190718_detection_result/yolov3-tiny-ncs-without-last-maxpool-refined-anchors_112100/00000204201.xml
# Created : /media/yyp/DATA/EVALUATE/20190718_detection_result/yolov3-tiny-ncs-without-last-maxpool-refined-anchors_112100/00000204210.xml
# Created : /media/yyp/DATA/EVALUATE/20190718_detection_result/yolov3-tiny-ncs-without-last-maxpool-refined-anchors_112100/00000204228.xml
# Created : /media/yyp/DATA/EVALUATE/20190718_detection_result/yolov3-tiny-ncs-without-last-maxpool-refined-anchors_112100/00000204243.xml
# Created : /media/yyp/DATA/EVALUATE/20190718_detection_result/yolov3-tiny-ncs-without-last-maxpool-refined-anchors_112100/00000204251.xml
# Created : /media/yyp/DATA/EVALUATE/20190718_detection_result/yolov3-tiny-ncs-without-last-maxpool-refined-anchors_112100/00000204256.xml
# Created : /media/yyp/DATA/EVALUATE/20190718_detection_result/yolov3-tiny-ncs-without-last-maxpool-refined-anchors_112100/00000204257.xml
# Created : /media/yyp/DATA/EVALUATE/20190718_detection_result/yolov3-tiny-ncs-without-last-maxpool-refined-anchors_112100/00000204274.xml
# Created : /media/yyp/DATA/EVALUATE/20190718_detection_result/yolov3-tiny-ncs-without-last-maxpool-refined-anchors_112100/00000204297.xml
# Created : /media/yyp/DATA/EVALUATE/20190718_detection_result/yolov3-tiny-ncs-without-last-maxpool-refined-anchors_112100/00000204299.xml
# Created : /media/yyp/DATA/EVALUATE/20190718_detection_result/yolov3-tiny-ncs-without-last-maxpool-refined-anchors_112100/00000204301.xml
# Created : /media/yyp/DATA/EVALUATE/20190718_detection_result/yolov3-tiny-ncs-without-last-maxpool-refined-anchors_112100/00000204338.xml
# Created : /media/yyp/DATA/EVALUATE/20190718_detection_result/yolov3-tiny-ncs-without-last-maxpool-refined-anchors_112100/00000204364.xml
# Created : /media/yyp/DATA/EVALUATE/20190718_detection_result/yolov3-tiny-ncs-without-last-maxpool-refined-anchors_112100/00000204413.xml
# Created : /media/yyp/DATA/EVALUATE/20190718_detection_result/yolov3-tiny-ncs-without-last-maxpool-refined-anchors_112100/00000204432.xml
# Created : /media/yyp/DATA/EVALUATE/20190718_detection_result/yolov3-tiny-ncs-without-last-maxpool-refined-anchors_112100/00000204438.xml
# Created : /media/yyp/DATA/EVALUATE/20190718_detection_result/yolov3-tiny-ncs-without-last-maxpool-refined-anchors_112100/00000204452.xml
# Created : /media/yyp/DATA/EVALUATE/20190718_detection_result/yolov3-tiny-ncs-without-last-maxpool-refined-anchors_112100/00000204531.xml
# Created : /media/yyp/DATA/EVALUATE/20190718_detection_result/yolov3-tiny-ncs-without-last-maxpool-refined-anchors_112100/00000204535.xml
# Created : /media/yyp/DATA/EVALUATE/20190718_detection_result/yolov3-tiny-ncs-without-last-maxpool-refined-anchors_112100/00000204607.xml
# Created : /media/yyp/DATA/EVALUATE/20190718_detection_result/yolov3-tiny-ncs-without-last-maxpool-refined-anchors_112100/00000204612.xml
# Created : /media/yyp/DATA/EVALUATE/20190718_detection_result/yolov3-tiny-ncs-without-last-maxpool-refined-anchors_112100/00000204303.xml
# Created : /media/yyp/DATA/EVALUATE/20190718_detection_result/yolov3-tiny-ncs-without-last-maxpool-refined-anchors_112100/00000204436.xml
# Created : /media/yyp/DATA/EVALUATE/20190718_detection_result/yolov3-tiny-ncs-without-last-maxpool-refined-anchors_112100/00000204634.xml
# Created : /media/yyp/DATA/EVALUATE/20190718_detection_result/yolov3-tiny-ncs-without-last-maxpool-refined-anchors_112100/00000204652.xml
# Created : /media/yyp/DATA/EVALUATE/20190718_detection_result/yolov3-tiny-ncs-without-last-maxpool-refined-anchors_112100/00000204706.xml
# Created : /media/yyp/DATA/EVALUATE/20190718_detection_result/yolov3-tiny-ncs-without-last-maxpool-refined-anchors_112100/00000204709.xml
# Created : /media/yyp/DATA/EVALUATE/20190718_detection_result/yolov3-tiny-ncs-without-last-maxpool-refined-anchors_112100/00000204747.xml
# Created : /media/yyp/DATA/EVALUATE/20190718_detection_result/yolov3-tiny-ncs-without-last-maxpool-refined-anchors_112100/00000204751.xml
# Created : /media/yyp/DATA/EVALUATE/20190718_detection_result/yolov3-tiny-ncs-without-last-maxpool-refined-anchors_112100/00000204760.xml
# Created : /media/yyp/DATA/EVALUATE/20190718_detection_result/yolov3-tiny-ncs-without-last-maxpool-refined-anchors_112100/00000204792.xml
# Created : /media/yyp/DATA/EVALUATE/20190718_detection_result/yolov3-tiny-ncs-without-last-maxpool-refined-anchors_112100/00000204809.xml
# Created : /media/yyp/DATA/EVALUATE/20190718_detection_result/yolov3-tiny-ncs-without-last-maxpool-refined-anchors_112100/00000204816.xml
# Created : /media/yyp/DATA/EVALUATE/20190718_detection_result/yolov3-tiny-ncs-without-last-maxpool-refined-anchors_112100/00000204818.xml
# Created : /media/yyp/DATA/EVALUATE/20190718_detection_result/yolov3-tiny-ncs-without-last-maxpool-refined-anchors_112100/00000204821.xml
# Created : /media/yyp/DATA/EVALUATE/20190718_detection_result/yolov3-tiny-ncs-without-last-maxpool-refined-anchors_112100/00000204843.xml
# Created : /media/yyp/DATA/EVALUATE/20190718_detection_result/yolov3-tiny-ncs-without-last-maxpool-refined-anchors_112100/00000204846.xml
# Created : /media/yyp/DATA/EVALUATE/20190718_detection_result/yolov3-tiny-ncs-without-last-maxpool-refined-anchors_112100/00000204849.xml
# Created : /media/yyp/DATA/EVALUATE/20190718_detection_result/yolov3-tiny-ncs-without-last-maxpool-refined-anchors_112100/00000204851.xml
# Created : /media/yyp/DATA/EVALUATE/20190718_detection_result/yolov3-tiny-ncs-without-last-maxpool-refined-anchors_112100/00000204863.xml
# Created : /media/yyp/DATA/EVALUATE/20190718_detection_result/yolov3-tiny-ncs-without-last-maxpool-refined-anchors_112100/00000204864.xml
# Created : /media/yyp/DATA/EVALUATE/20190718_detection_result/yolov3-tiny-ncs-without-last-maxpool-refined-anchors_112100/00000204868.xml
# Created : /media/yyp/DATA/EVALUATE/20190718_detection_result/yolov3-tiny-ncs-without-last-maxpool-refined-anchors_112100/00000204890.xml
# Created : /media/yyp/DATA/EVALUATE/20190718_detection_result/yolov3-tiny-ncs-without-last-maxpool-refined-anchors_112100/00000204891.xml
# Created : /media/yyp/DATA/EVALUATE/20190718_detection_result/yolov3-tiny-ncs-without-last-maxpool-refined-anchors_112100/00000204938.xml
# Created : /media/yyp/DATA/EVALUATE/20190718_detection_result/yolov3-tiny-ncs-without-last-maxpool-refined-anchors_112100/00000204944.xml
# Created : /media/yyp/DATA/EVALUATE/20190718_detection_result/yolov3-tiny-ncs-without-last-maxpool-refined-anchors_112100/00000204954.xml
# Created : /media/yyp/DATA/EVALUATE/20190718_detection_result/yolov3-tiny-ncs-without-last-maxpool-refined-anchors_112100/00000204955.xml
# Created : /media/yyp/DATA/EVALUATE/20190718_detection_result/yolov3-tiny-ncs-without-last-maxpool-refined-anchors_112100/00000204956.xml
# Created : /media/yyp/DATA/EVALUATE/20190718_detection_result/yolov3-tiny-ncs-without-last-maxpool-refined-anchors_112100/00000204997.xml
# Created : /media/yyp/DATA/EVALUATE/20190718_detection_result/yolov3-tiny-ncs-without-last-maxpool-refined-anchors_112100/00000204811.xml
# Created : /media/yyp/DATA/EVALUATE/20190718_detection_result/yolov3-tiny-ncs-without-last-maxpool-refined-anchors_112100/00000204829.xml
# Created : /media/yyp/DATA/EVALUATE/20190718_detection_result/yolov3-tiny-ncs-without-last-maxpool-refined-anchors_112100/00000205057.xml
# Created : /media/yyp/DATA/EVALUATE/20190718_detection_result/yolov3-tiny-ncs-without-last-maxpool-refined-anchors_112100/00000205086.xml
# Created : /media/yyp/DATA/EVALUATE/20190718_detection_result/yolov3-tiny-ncs-without-last-maxpool-refined-anchors_112100/00000205087.xml
# Created : /media/yyp/DATA/EVALUATE/20190718_detection_result/yolov3-tiny-ncs-without-last-maxpool-refined-anchors_112100/00000205137.xml
# Created : /media/yyp/DATA/EVALUATE/20190718_detection_result/yolov3-tiny-ncs-without-last-maxpool-refined-anchors_112100/00000205159.xml
# Created : /media/yyp/DATA/EVALUATE/20190718_detection_result/yolov3-tiny-ncs-without-last-maxpool-refined-anchors_112100/00000205173.xml
# Created : /media/yyp/DATA/EVALUATE/20190718_detection_result/yolov3-tiny-ncs-without-last-maxpool-refined-anchors_112100/00000205180.xml
# Created : /media/yyp/DATA/EVALUATE/20190718_detection_result/yolov3-tiny-ncs-without-last-maxpool-refined-anchors_112100/00000205184.xml
# Created : /media/yyp/DATA/EVALUATE/20190718_detection_result/yolov3-tiny-ncs-without-last-maxpool-refined-anchors_112100/00000205185.xml
# Created : /media/yyp/DATA/EVALUATE/20190718_detection_result/yolov3-tiny-ncs-without-last-maxpool-refined-anchors_112100/00000205199.xml
# Created : /media/yyp/DATA/EVALUATE/20190718_detection_result/yolov3-tiny-ncs-without-last-maxpool-refined-anchors_112100/00000205235.xml
# Created : /media/yyp/DATA/EVALUATE/20190718_detection_result/yolov3-tiny-ncs-without-last-maxpool-refined-anchors_112100/00000205263.xml
# Created : /media/yyp/DATA/EVALUATE/20190718_detection_result/yolov3-tiny-ncs-without-last-maxpool-refined-anchors_112100/00000205278.xml
# Created : /media/yyp/DATA/EVALUATE/20190718_detection_result/yolov3-tiny-ncs-without-last-maxpool-refined-anchors_112100/00000205284.xml
# Created : /media/yyp/DATA/EVALUATE/20190718_detection_result/yolov3-tiny-ncs-without-last-maxpool-refined-anchors_112100/00000205297.xml
# Created : /media/yyp/DATA/EVALUATE/20190718_detection_result/yolov3-tiny-ncs-without-last-maxpool-refined-anchors_112100/00000205531.xml
# Created : /media/yyp/DATA/EVALUATE/20190718_detection_result/yolov3-tiny-ncs-without-last-maxpool-refined-anchors_112100/00000205534.xml
# Created : /media/yyp/DATA/EVALUATE/20190718_detection_result/yolov3-tiny-ncs-without-last-maxpool-refined-anchors_112100/00000205536.xml
# Created : /media/yyp/DATA/EVALUATE/20190718_detection_result/yolov3-tiny-ncs-without-last-maxpool-refined-anchors_112100/00000205543.xml
# Created : /media/yyp/DATA/EVALUATE/20190718_detection_result/yolov3-tiny-ncs-without-last-maxpool-refined-anchors_112100/00000205575.xml
# Created : /media/yyp/DATA/EVALUATE/20190718_detection_result/yolov3-tiny-ncs-without-last-maxpool-refined-anchors_112100/00000205615.xml
# Created : /media/yyp/DATA/EVALUATE/20190718_detection_result/yolov3-tiny-ncs-without-last-maxpool-refined-anchors_112100/00000205596.xml
# Created : /media/yyp/DATA/EVALUATE/20190718_detection_result/yolov3-tiny-ncs-without-last-maxpool-refined-anchors_112100/00000205776.xml
# Created : /media/yyp/DATA/EVALUATE/20190718_detection_result/yolov3-tiny-ncs-without-last-maxpool-refined-anchors_112100/00000205790.xml
# Created : /media/yyp/DATA/EVALUATE/20190718_detection_result/yolov3-tiny-ncs-without-last-maxpool-refined-anchors_112100/00000205833.xml
# Created : /media/yyp/DATA/EVALUATE/20190718_detection_result/yolov3-tiny-ncs-without-last-maxpool-refined-anchors_112100/00000205850.xml
# Created : /media/yyp/DATA/EVALUATE/20190718_detection_result/yolov3-tiny-ncs-without-last-maxpool-refined-anchors_112100/00000205857.xml
# Created : /media/yyp/DATA/EVALUATE/20190718_detection_result/yolov3-tiny-ncs-without-last-maxpool-refined-anchors_112100/00000205860.xml
# Created : /media/yyp/DATA/EVALUATE/20190718_detection_result/yolov3-tiny-ncs-without-last-maxpool-refined-anchors_112100/00000205863.xml
# Created : /media/yyp/DATA/EVALUATE/20190718_detection_result/yolov3-tiny-ncs-without-last-maxpool-refined-anchors_112100/00000205895.xml
# Created : /media/yyp/DATA/EVALUATE/20190718_detection_result/yolov3-tiny-ncs-without-last-maxpool-refined-anchors_112100/00000205902.xml
# Created : /media/yyp/DATA/EVALUATE/20190718_detection_result/yolov3-tiny-ncs-without-last-maxpool-refined-anchors_112100/00000205914.xml
# Created : /media/yyp/DATA/EVALUATE/20190718_detection_result/yolov3-tiny-ncs-without-last-maxpool-refined-anchors_112100/00000205926.xml
# Created : /media/yyp/DATA/EVALUATE/20190718_detection_result/yolov3-tiny-ncs-without-last-maxpool-refined-anchors_112100/00000205929.xml
# Created : /media/yyp/DATA/EVALUATE/20190718_detection_result/yolov3-tiny-ncs-without-last-maxpool-refined-anchors_112100/00000205930.xml
# Created : /media/yyp/DATA/EVALUATE/20190718_detection_result/yolov3-tiny-ncs-without-last-maxpool-refined-anchors_112100/00000205971.xml
# Created : /media/yyp/DATA/EVALUATE/20190718_detection_result/yolov3-tiny-ncs-without-last-maxpool-refined-anchors_112100/00000205976.xml
# Created : /media/yyp/DATA/EVALUATE/20190718_detection_result/yolov3-tiny-ncs-without-last-maxpool-refined-anchors_112100/00000205977.xml
# Created : /media/yyp/DATA/EVALUATE/20190718_detection_result/yolov3-tiny-ncs-without-last-maxpool-refined-anchors_112100/00000205978.xml
# Created : /media/yyp/DATA/EVALUATE/20190718_detection_result/yolov3-tiny-ncs-without-last-maxpool-refined-anchors_112100/00000205983.xml
# Created : /media/yyp/DATA/EVALUATE/20190718_detection_result/yolov3-tiny-ncs-without-last-maxpool-refined-anchors_112100/00000205993.xml
# Created : /media/yyp/DATA/EVALUATE/20190718_detection_result/yolov3-tiny-ncs-without-last-maxpool-refined-anchors_112100/00000206028.xml
# Created : /media/yyp/DATA/EVALUATE/20190718_detection_result/yolov3-tiny-ncs-without-last-maxpool-refined-anchors_112100/00000206045.xml
# Created : /media/yyp/DATA/EVALUATE/20190718_detection_result/yolov3-tiny-ncs-without-last-maxpool-refined-anchors_112100/00000206086.xml
# Created : /media/yyp/DATA/EVALUATE/20190718_detection_result/yolov3-tiny-ncs-without-last-maxpool-refined-anchors_112100/00000206126.xml
# Created : /media/yyp/DATA/EVALUATE/20190718_detection_result/yolov3-tiny-ncs-without-last-maxpool-refined-anchors_112100/00000206172.xml
# Created : /media/yyp/DATA/EVALUATE/20190718_detection_result/yolov3-tiny-ncs-without-last-maxpool-refined-anchors_112100/00000206177.xml
# Created : /media/yyp/DATA/EVALUATE/20190718_detection_result/yolov3-tiny-ncs-without-last-maxpool-refined-anchors_112100/00000206189.xml
# Created : /media/yyp/DATA/EVALUATE/20190718_detection_result/yolov3-tiny-ncs-without-last-maxpool-refined-anchors_112100/00000206204.xml
# Created : /media/yyp/DATA/EVALUATE/20190718_detection_result/yolov3-tiny-ncs-without-last-maxpool-refined-anchors_112100/00000206274.xml
# Created : /media/yyp/DATA/EVALUATE/20190718_detection_result/yolov3-tiny-ncs-without-last-maxpool-refined-anchors_112100/00000206277.xml
# Created : /media/yyp/DATA/EVALUATE/20190718_detection_result/yolov3-tiny-ncs-without-last-maxpool-refined-anchors_112100/00000206278.xml
# Created : /media/yyp/DATA/EVALUATE/20190718_detection_result/yolov3-tiny-ncs-without-last-maxpool-refined-anchors_112100/00000206283.xml
# Created : /media/yyp/DATA/EVALUATE/20190718_detection_result/yolov3-tiny-ncs-without-last-maxpool-refined-anchors_112100/00000206294.xml
# Created : /media/yyp/DATA/EVALUATE/20190718_detection_result/yolov3-tiny-ncs-without-last-maxpool-refined-anchors_112100/00000205886.xml
# Created : /media/yyp/DATA/EVALUATE/20190718_detection_result/yolov3-tiny-ncs-without-last-maxpool-refined-anchors_112100/00000205922.xml
# Created : /media/yyp/DATA/EVALUATE/20190718_detection_result/yolov3-tiny-ncs-without-last-maxpool-refined-anchors_112100/00000206048.xml
# Created : /media/yyp/DATA/EVALUATE/20190718_detection_result/yolov3-tiny-ncs-without-last-maxpool-refined-anchors_112100/00000206311.xml
# Created : /media/yyp/DATA/EVALUATE/20190718_detection_result/yolov3-tiny-ncs-without-last-maxpool-refined-anchors_112100/00000206321.xml
# Created : /media/yyp/DATA/EVALUATE/20190718_detection_result/yolov3-tiny-ncs-without-last-maxpool-refined-anchors_112100/00000206324.xml
# Created : /media/yyp/DATA/EVALUATE/20190718_detection_result/yolov3-tiny-ncs-without-last-maxpool-refined-anchors_112100/00000206329.xml
# Created : /media/yyp/DATA/EVALUATE/20190718_detection_result/yolov3-tiny-ncs-without-last-maxpool-refined-anchors_112100/00000206339.xml
# Created : /media/yyp/DATA/EVALUATE/20190718_detection_result/yolov3-tiny-ncs-without-last-maxpool-refined-anchors_112100/00000206342.xml
# Created : /media/yyp/DATA/EVALUATE/20190718_detection_result/yolov3-tiny-ncs-without-last-maxpool-refined-anchors_112100/00000206346.xml
# Created : /media/yyp/DATA/EVALUATE/20190718_detection_result/yolov3-tiny-ncs-without-last-maxpool-refined-anchors_112100/00000206356.xml
# Created : /media/yyp/DATA/EVALUATE/20190718_detection_result/yolov3-tiny-ncs-without-last-maxpool-refined-anchors_112100/00000206357.xml
# Created : /media/yyp/DATA/EVALUATE/20190718_detection_result/yolov3-tiny-ncs-without-last-maxpool-refined-anchors_112100/00000206391.xml
# Created : /media/yyp/DATA/EVALUATE/20190718_detection_result/yolov3-tiny-ncs-without-last-maxpool-refined-anchors_112100/00000206404.xml
# Created : /media/yyp/DATA/EVALUATE/20190718_detection_result/yolov3-tiny-ncs-without-last-maxpool-refined-anchors_112100/00000206407.xml
# Created : /media/yyp/DATA/EVALUATE/20190718_detection_result/yolov3-tiny-ncs-without-last-maxpool-refined-anchors_112100/00000206574.xml
# Created : /media/yyp/DATA/EVALUATE/20190718_detection_result/yolov3-tiny-ncs-without-last-maxpool-refined-anchors_112100/00000206630.xml
# Created : /media/yyp/DATA/EVALUATE/20190718_detection_result/yolov3-tiny-ncs-without-last-maxpool-refined-anchors_112100/00000206694.xml
# Created : /media/yyp/DATA/EVALUATE/20190718_detection_result/yolov3-tiny-ncs-without-last-maxpool-refined-anchors_112100/00000206696.xml
# Created : /media/yyp/DATA/EVALUATE/20190718_detection_result/yolov3-tiny-ncs-without-last-maxpool-refined-anchors_112100/00000206697.xml
# Created : /media/yyp/DATA/EVALUATE/20190718_detection_result/yolov3-tiny-ncs-without-last-maxpool-refined-anchors_112100/00000206699.xml
# Created : /media/yyp/DATA/EVALUATE/20190718_detection_result/yolov3-tiny-ncs-without-last-maxpool-refined-anchors_112100/00000206700.xml
# Created : /media/yyp/DATA/EVALUATE/20190718_detection_result/yolov3-tiny-ncs-without-last-maxpool-refined-anchors_112100/00000206754.xml
# Created : /media/yyp/DATA/EVALUATE/20190718_detection_result/yolov3-tiny-ncs-without-last-maxpool-refined-anchors_112100/00000206793.xml
# Created : /media/yyp/DATA/EVALUATE/20190718_detection_result/yolov3-tiny-ncs-without-last-maxpool-refined-anchors_112100/00000206803.xml
# Created : /media/yyp/DATA/EVALUATE/20190718_detection_result/yolov3-tiny-ncs-without-last-maxpool-refined-anchors_112100/00000206809.xml
# Created : /media/yyp/DATA/EVALUATE/20190718_detection_result/yolov3-tiny-ncs-without-last-maxpool-refined-anchors_112100/00000206829.xml
# Created : /media/yyp/DATA/EVALUATE/20190718_detection_result/yolov3-tiny-ncs-without-last-maxpool-refined-anchors_112100/00000206713.xml
# Created : /media/yyp/DATA/EVALUATE/20190718_detection_result/yolov3-tiny-ncs-without-last-maxpool-refined-anchors_112100/00000206895.xml
# Created : /media/yyp/DATA/EVALUATE/20190718_detection_result/yolov3-tiny-ncs-without-last-maxpool-refined-anchors_112100/00000206919.xml
# Created : /media/yyp/DATA/EVALUATE/20190718_detection_result/yolov3-tiny-ncs-without-last-maxpool-refined-anchors_112100/00000206924.xml
# Created : /media/yyp/DATA/EVALUATE/20190718_detection_result/yolov3-tiny-ncs-without-last-maxpool-refined-anchors_112100/00000206927.xml
# Created : /media/yyp/DATA/EVALUATE/20190718_detection_result/yolov3-tiny-ncs-without-last-maxpool-refined-anchors_112100/00000206947.xml
# ...
# Created : /media/yyp/DATA/EVALUATE/20190718_detection_result/yolov3-tiny-ncs-without-last-maxpool-refined-anchors_150000old/ge_shrink_scale_0_0.2_0020013.xml
# Created : /media/yyp/DATA/EVALUATE/20190718_detection_result/yolov3-tiny-ncs-without-last-maxpool-refined-anchors_150000old/ge_shrink_scale_0_0.2_0020045.xml
# Created : /media/yyp/DATA/EVALUATE/20190718_detection_result/yolov3-tiny-ncs-without-last-maxpool-refined-anchors_150000old/ge_shrink_scale_0_0.2_0020046.xml
# Created : /media/yyp/DATA/EVALUATE/20190718_detection_result/yolov3-tiny-ncs-without-last-maxpool-refined-anchors_150000old/ge_shrink_scale_0_0.2_0020065.xml
# Created : /media/yyp/DATA/EVALUATE/20190718_detection_result/yolov3-tiny-ncs-without-last-maxpool-refined-anchors_150000old/ge_shrink_scale_0_0.2_0020067.xml
# Created : /media/yyp/DATA/EVALUATE/20190718_detection_result/yolov3-tiny-ncs-without-last-maxpool-refined-anchors_150000old/ge_shrink_scale_0_0_0020106.xml
# Created : /media/yyp/DATA/EVALUATE/20190718_detection_result/yolov3-tiny-ncs-without-last-maxpool-refined-anchors_150000old/ge_shrink_scale_0_0_0020135.xml
# Created : /media/yyp/DATA/EVALUATE/20190718_detection_result/yolov3-tiny-ncs-without-last-maxpool-refined-anchors_150000old/ge_shrink_scale_0_0.2_0020093.xml
# Created : /media/yyp/DATA/EVALUATE/20190718_detection_result/yolov3-tiny-ncs-without-last-maxpool-refined-anchors_150000old/ge_shrink_scale_0_0.2_0020111.xml
# Created : /media/yyp/DATA/EVALUATE/20190718_detection_result/yolov3-tiny-ncs-without-last-maxpool-refined-anchors_150000old/ge_shrink_scale_0_0.2_0020113.xml
# Created : /media/yyp/DATA/EVALUATE/20190718_detection_result/yolov3-tiny-ncs-without-last-maxpool-refined-anchors_150000old/ge_shrink_scale_0_0.2_0020114.xml
# Created : /media/yyp/DATA/EVALUATE/20190718_detection_result/yolov3-tiny-ncs-without-last-maxpool-refined-anchors_150000old/ge_shrink_scale_0_0.2_0020148.xml
# Created : /media/yyp/DATA/EVALUATE/20190718_detection_result/yolov3-tiny-ncs-without-last-maxpool-refined-anchors_150000old/ge_shrink_scale_0_0.3_127.5_00000434404.xml
# Created : /media/yyp/DATA/EVALUATE/20190718_detection_result/yolov3-tiny-ncs-without-last-maxpool-refined-anchors_150000old/ge_shrink_scale_0_0.3_255_00000002713.xml
# Created : /media/yyp/DATA/EVALUATE/20190718_detection_result/yolov3-tiny-ncs-without-last-maxpool-refined-anchors_150000old/ge_shrink_scale_0_0.3_25_0011000.xml
# Created : /media/yyp/DATA/EVALUATE/20190718_detection_result/yolov3-tiny-ncs-without-last-maxpool-refined-anchors_150000old/ge_shrink_scale_0_0.3_25_0011008.xml
# Created : /media/yyp/DATA/EVALUATE/20190718_detection_result/yolov3-tiny-ncs-without-last-maxpool-refined-anchors_150000old/ge_shrink_scale_0_0.3_25_0011015.xml
# Created : /media/yyp/DATA/EVALUATE/20190718_detection_result/yolov3-tiny-ncs-without-last-maxpool-refined-anchors_150000old/ge_shrink_scale_0_0.3_25_0011033.xml
# Created : /media/yyp/DATA/EVALUATE/20190718_detection_result/yolov3-tiny-ncs-without-last-maxpool-refined-anchors_150000old/ge_shrink_scale_0_0.3_25_0011036.xml
# Created : /media/yyp/DATA/EVALUATE/20190718_detection_result/yolov3-tiny-ncs-without-last-maxpool-refined-anchors_150000old/ge_shrink_scale_0_0.3_25_0011048.xml
# Created : /media/yyp/DATA/EVALUATE/20190718_detection_result/yolov3-tiny-ncs-without-last-maxpool-refined-anchors_150000old/ge_shrink_scale_0_0.3_25_0011049.xml
# Created : /media/yyp/DATA/EVALUATE/20190718_detection_result/yolov3-tiny-ncs-without-last-maxpool-refined-anchors_150000old/ge_shrink_scale_0_0_00000300249.xml
# Created : /media/yyp/DATA/EVALUATE/20190718_detection_result/yolov3-tiny-ncs-without-last-maxpool-refined-anchors_150000old/ge_shrink_scale_0_0_00000300301.xml
# Created : /media/yyp/DATA/EVALUATE/20190718_detection_result/yolov3-tiny-ncs-without-last-maxpool-refined-anchors_150000old/ge_shrink_scale_0_0.3_255_0010000.xml
# Created : /media/yyp/DATA/EVALUATE/20190718_detection_result/yolov3-tiny-ncs-without-last-maxpool-refined-anchors_150000old/ge_shrink_scale_0_0.3_255_0010009.xml
# Created : /media/yyp/DATA/EVALUATE/20190718_detection_result/yolov3-tiny-ncs-without-last-maxpool-refined-anchors_150000old/ge_shrink_scale_0_0.3_255_0011006.xml
# Created : /media/yyp/DATA/EVALUATE/20190718_detection_result/yolov3-tiny-ncs-without-last-maxpool-refined-anchors_150000old/ge_shrink_scale_0_0.3_255_0011017.xml
# Created : /media/yyp/DATA/EVALUATE/20190718_detection_result/yolov3-tiny-ncs-without-last-maxpool-refined-anchors_150000old/ge_shrink_scale_0_0.3_255_0011045.xml
# Created : /media/yyp/DATA/EVALUATE/20190718_detection_result/yolov3-tiny-ncs-without-last-maxpool-refined-anchors_150000old/ge_shrink_scale_0.02_0.02_00000300254.xml
# Created : /media/yyp/DATA/EVALUATE/20190718_detection_result/yolov3-tiny-ncs-without-last-maxpool-refined-anchors_150000old/ge_shrink_scale_0.1_0_0010014.xml
# Created : /media/yyp/DATA/EVALUATE/20190718_detection_result/yolov3-tiny-ncs-without-last-maxpool-refined-anchors_150000old/ge_shrink_scale_0.1_0_0010053.xml
# Created : /media/yyp/DATA/EVALUATE/20190718_detection_result/yolov3-tiny-ncs-without-last-maxpool-refined-anchors_150000old/ge_shrink_scale_0.1_0_0011009.xml
# Created : /media/yyp/DATA/EVALUATE/20190718_detection_result/yolov3-tiny-ncs-without-last-maxpool-refined-anchors_150000old/ge_shrink_scale_0.1_0_0011035.xml
# Created : /media/yyp/DATA/EVALUATE/20190718_detection_result/yolov3-tiny-ncs-without-last-maxpool-refined-anchors_150000old/ge_shrink_scale_0.1_0_0011037.xml
# Created : /media/yyp/DATA/EVALUATE/20190718_detection_result/yolov3-tiny-ncs-without-last-maxpool-refined-anchors_150000old/ge_shrink_scale_0.1_0_0011040.xml
# Created : /media/yyp/DATA/EVALUATE/20190718_detection_result/yolov3-tiny-ncs-without-last-maxpool-refined-anchors_150000old/ge_shrink_scale_0.1_0_0011051.xml
# Created : /media/yyp/DATA/EVALUATE/20190718_detection_result/yolov3-tiny-ncs-without-last-maxpool-refined-anchors_150000old/ge_shrink_scale_0.1_0_0020003.xml
# Created : /media/yyp/DATA/EVALUATE/20190718_detection_result/yolov3-tiny-ncs-without-last-maxpool-refined-anchors_150000old/ge_shrink_scale_0.1_0_0020015.xml
# Created : /media/yyp/DATA/EVALUATE/20190718_detection_result/yolov3-tiny-ncs-without-last-maxpool-refined-anchors_150000old/ge_shrink_scale_0.1_0_0020025.xml
# Created : /media/yyp/DATA/EVALUATE/20190718_detection_result/yolov3-tiny-ncs-without-last-maxpool-refined-anchors_150000old/ge_shrink_scale_0.1_0_0020027.xml
# Created : /media/yyp/DATA/EVALUATE/20190718_detection_result/yolov3-tiny-ncs-without-last-maxpool-refined-anchors_150000old/ge_shrink_scale_0.1_0_0020028.xml
# Created : /media/yyp/DATA/EVALUATE/20190718_detection_result/yolov3-tiny-ncs-without-last-maxpool-refined-anchors_150000old/ge_shrink_scale_0.1_0_0020031.xml
# Created : /media/yyp/DATA/EVALUATE/20190718_detection_result/yolov3-tiny-ncs-without-last-maxpool-refined-anchors_150000old/ge_shrink_scale_0.1_0_0020033.xml
# Created : /media/yyp/DATA/EVALUATE/20190718_detection_result/yolov3-tiny-ncs-without-last-maxpool-refined-anchors_150000old/ge_shrink_scale_0.1_0_0020041.xml
# Created : /media/yyp/DATA/EVALUATE/20190718_detection_result/yolov3-tiny-ncs-without-last-maxpool-refined-anchors_150000old/ge_shrink_scale_0.1_0_0020048.xml
# Created : /media/yyp/DATA/EVALUATE/20190718_detection_result/yolov3-tiny-ncs-without-last-maxpool-refined-anchors_150000old/ge_shrink_scale_0.1_0_0020072.xml
# Created : /media/yyp/DATA/EVALUATE/20190718_detection_result/yolov3-tiny-ncs-without-last-maxpool-refined-anchors_150000old/ge_shrink_scale_0.1_0_0020076.xml
# Created : /media/yyp/DATA/EVALUATE/20190718_detection_result/yolov3-tiny-ncs-without-last-maxpool-refined-anchors_150000old/ge_shrink_scale_0.1_0_0020078.xml
# Created : /media/yyp/DATA/EVALUATE/20190718_detection_result/yolov3-tiny-ncs-without-last-maxpool-refined-anchors_150000old/ge_shrink_scale_0.1_0_0020085.xml
# Created : /media/yyp/DATA/EVALUATE/20190718_detection_result/yolov3-tiny-ncs-without-last-maxpool-refined-anchors_150000old/ge_shrink_scale_0.1_0_0020126.xml
# Created : /media/yyp/DATA/EVALUATE/20190718_detection_result/yolov3-tiny-ncs-without-last-maxpool-refined-anchors_150000old/ge_shrink_scale_0.1_0_0020138.xml
# Created : /media/yyp/DATA/EVALUATE/20190718_detection_result/yolov3-tiny-ncs-without-last-maxpool-refined-anchors_150000old/ge_shrink_scale_0.1_0_0020140.xml
# Created : /media/yyp/DATA/EVALUATE/20190718_detection_result/yolov3-tiny-ncs-without-last-maxpool-refined-anchors_150000old/ge_shrink_scale_0.1_0_0020148.xml
# Created : /media/yyp/DATA/EVALUATE/20190718_detection_result/yolov3-tiny-ncs-without-last-maxpool-refined-anchors_150000old/ge_shrink_scale_0.1_0_0020149.xml
# Created : /media/yyp/DATA/EVALUATE/20190718_detection_result/yolov3-tiny-ncs-without-last-maxpool-refined-anchors_150000old/ge_shrink_scale_0.1_0.2_00000300299.xml
# Created : /media/yyp/DATA/EVALUATE/20190718_detection_result/yolov3-tiny-ncs-without-last-maxpool-refined-anchors_150000old/ge_shrink_scale_0.1_0_00000300301.xml
# Created : /media/yyp/DATA/EVALUATE/20190718_detection_result/yolov3-tiny-ncs-without-last-maxpool-refined-anchors_150000old/ge_shrink_scale_0.2_0_00000300252.xml
# Created : /media/yyp/DATA/EVALUATE/20190718_detection_result/yolov3-tiny-ncs-without-last-maxpool-refined-anchors_150000old/ge_shrink_scale_0.2_0_0010000.xml
# Created : /media/yyp/DATA/EVALUATE/20190718_detection_result/yolov3-tiny-ncs-without-last-maxpool-refined-anchors_150000old/ge_shrink_scale_0.2_0_0010020.xml
# Created : /media/yyp/DATA/EVALUATE/20190718_detection_result/yolov3-tiny-ncs-without-last-maxpool-refined-anchors_150000old/ge_shrink_scale_0.2_0_0010033.xml
# Created : /media/yyp/DATA/EVALUATE/20190718_detection_result/yolov3-tiny-ncs-without-last-maxpool-refined-anchors_150000old/ge_shrink_scale_0.2_0_0010049.xml
# Created : /media/yyp/DATA/EVALUATE/20190718_detection_result/yolov3-tiny-ncs-without-last-maxpool-refined-anchors_150000old/ge_shrink_scale_0.2_0_0011000.xml
# Created : /media/yyp/DATA/EVALUATE/20190718_detection_result/yolov3-tiny-ncs-without-last-maxpool-refined-anchors_150000old/ge_shrink_scale_0.2_0_0011028.xml
# Created : /media/yyp/DATA/EVALUATE/20190718_detection_result/yolov3-tiny-ncs-without-last-maxpool-refined-anchors_150000old/ge_shrink_scale_0.2_0_0011040.xml
# Created : /media/yyp/DATA/EVALUATE/20190718_detection_result/yolov3-tiny-ncs-without-last-maxpool-refined-anchors_150000old/ge_shrink_scale_0.2_0_0011048.xml
# Created : /media/yyp/DATA/EVALUATE/20190718_detection_result/yolov3-tiny-ncs-without-last-maxpool-refined-anchors_150000old/ge_shrink_scale_0.2_0_0011051.xml
# Created : /media/yyp/DATA/EVALUATE/20190718_detection_result/yolov3-tiny-ncs-without-last-maxpool-refined-anchors_150000old/ge_shrink_scale_0.2_0_0020003.xml
# Created : /media/yyp/DATA/EVALUATE/20190718_detection_result/yolov3-tiny-ncs-without-last-maxpool-refined-anchors_150000old/ge_shrink_scale_0.2_0_0020035.xml
# Created : /media/yyp/DATA/EVALUATE/20190718_detection_result/yolov3-tiny-ncs-without-last-maxpool-refined-anchors_150000old/ge_shrink_scale_0.2_0_0020041.xml
# Created : /media/yyp/DATA/EVALUATE/20190718_detection_result/yolov3-tiny-ncs-without-last-maxpool-refined-anchors_150000old/ge_shrink_scale_0.2_0_0020051.xml
# Created : /media/yyp/DATA/EVALUATE/20190718_detection_result/yolov3-tiny-ncs-without-last-maxpool-refined-anchors_150000old/ge_shrink_scale_0.2_0_0020053.xml
# Created : /media/yyp/DATA/EVALUATE/20190718_detection_result/yolov3-tiny-ncs-without-last-maxpool-refined-anchors_150000old/ge_shrink_scale_0.2_0_0020071.xml
# Created : /media/yyp/DATA/EVALUATE/20190718_detection_result/yolov3-tiny-ncs-without-last-maxpool-refined-anchors_150000old/ge_shrink_scale_0.2_0_0020078.xml
# Created : /media/yyp/DATA/EVALUATE/20190718_detection_result/yolov3-tiny-ncs-without-last-maxpool-refined-anchors_150000old/ge_shrink_scale_0.2_0_0020079.xml
# Created : /media/yyp/DATA/EVALUATE/20190718_detection_result/yolov3-tiny-ncs-without-last-maxpool-refined-anchors_150000old/ge_shrink_scale_0.2_0_0020098.xml
# Created : /media/yyp/DATA/EVALUATE/20190718_detection_result/yolov3-tiny-ncs-without-last-maxpool-refined-anchors_150000old/ge_shrink_scale_0.2_0_0020099.xml
# Created : /media/yyp/DATA/EVALUATE/20190718_detection_result/yolov3-tiny-ncs-without-last-maxpool-refined-anchors_150000old/ge_shrink_scale_0.2_0_0020062.xml
# Created : /media/yyp/DATA/EVALUATE/20190718_detection_result/yolov3-tiny-ncs-without-last-maxpool-refined-anchors_150000old/ge_shrink_scale_0.2_0_0020077.xml
# Created : /media/yyp/DATA/EVALUATE/20190718_detection_result/yolov3-tiny-ncs-without-last-maxpool-refined-anchors_150000old/ge_shrink_scale_0.4_0_0011033.xml
# Created : /media/yyp/DATA/EVALUATE/20190718_detection_result/yolov3-tiny-ncs-without-last-maxpool-refined-anchors_150000old/ge_shrink_scale_0.2_0_0020114.xml
# Created : /media/yyp/DATA/EVALUATE/20190718_detection_result/yolov3-tiny-ncs-without-last-maxpool-refined-anchors_150000old/ge_shrink_scale_0.2_0_0020115.xml
# Created : /media/yyp/DATA/EVALUATE/20190718_detection_result/yolov3-tiny-ncs-without-last-maxpool-refined-anchors_150000old/ge_shrink_scale_0.2_0_0020141.xml
# Created : /media/yyp/DATA/EVALUATE/20190718_detection_result/yolov3-tiny-ncs-without-last-maxpool-refined-anchors_150000old/ge_shrink_scale_0.3_0_127.5_00000434448.xml
# Created : /media/yyp/DATA/EVALUATE/20190718_detection_result/yolov3-tiny-ncs-without-last-maxpool-refined-anchors_150000old/ge_shrink_scale_0.4_0_00000003320.xml
# Created : /media/yyp/DATA/EVALUATE/20190718_detection_result/yolov3-tiny-ncs-without-last-maxpool-refined-anchors_150000old/ge_shrink_scale_0.4_0_0010033.xml
# Created : /media/yyp/DATA/EVALUATE/20190718_detection_result/yolov3-tiny-ncs-without-last-maxpool-refined-anchors_150000old/ge_shrink_scale_0.4_0_0011003.xml
# Created : /media/yyp/DATA/EVALUATE/20190718_detection_result/yolov3-tiny-ncs-without-last-maxpool-refined-anchors_150000old/ge_shrink_scale_0.4_0_0011005.xml
# Created : /media/yyp/DATA/EVALUATE/20190718_detection_result/yolov3-tiny-ncs-without-last-maxpool-refined-anchors_150000old/ge_shrink_scale_0.4_0_0011016.xml
# Created : /media/yyp/DATA/EVALUATE/20190718_detection_result/yolov3-tiny-ncs-without-last-maxpool-refined-anchors_150000old/ge_shrink_scale_0.4_0_0011019.xml
# Created : /media/yyp/DATA/EVALUATE/20190718_detection_result/yolov3-tiny-ncs-without-last-maxpool-refined-anchors_150000old/ge_shrink_scale_0.4_0_0011021.xml
# Created : /media/yyp/DATA/EVALUATE/20190718_detection_result/yolov3-tiny-ncs-without-last-maxpool-refined-anchors_150000old/ge_shrink_scale_0.4_0_0011024.xml
# Created : /media/yyp/DATA/EVALUATE/20190718_detection_result/yolov3-tiny-ncs-without-last-maxpool-refined-anchors_150000old/ge_shrink_scale_0.4_0_25_00000002830.xml
# Created : /media/yyp/DATA/EVALUATE/20190718_detection_result/yolov3-tiny-ncs-without-last-maxpool-refined-anchors_150000old/ge_shrink_scale_0.4_0_25_0010020.xml
# Created : /media/yyp/DATA/EVALUATE/20190718_detection_result/yolov3-tiny-ncs-without-last-maxpool-refined-anchors_150000old/ge_shrink_scale_0.4_0_25_0010031.xml
# Created : /media/yyp/DATA/EVALUATE/20190718_detection_result/yolov3-tiny-ncs-without-last-maxpool-refined-anchors_150000old/ge_shrink_scale_0.4_0_25_0010049.xml
# Created : /media/yyp/DATA/EVALUATE/20190718_detection_result/yolov3-tiny-ncs-without-last-maxpool-refined-anchors_150000old/ge_shrink_scale_0.4_0_25_0011010.xml
# Created : /media/yyp/DATA/EVALUATE/20190718_detection_result/yolov3-tiny-ncs-without-last-maxpool-refined-anchors_150000old/ge_shrink_scale_0.4_0_25_0011020.xml
# Created : /media/yyp/DATA/EVALUATE/20190718_detection_result/yolov3-tiny-ncs-without-last-maxpool-refined-anchors_150000old/ge_shrink_scale_0.4_0_25_00000002731.xml
# Created : /media/yyp/DATA/EVALUATE/20190718_detection_result/yolov3-tiny-ncs-without-last-maxpool-refined-anchors_150000old/ge_shrink_scale_0.4_0_25_0011046.xml
# yolov3-tiny-ncs-without-last-maxpool-refined-anchors_test.cfg
# yolov3_nob_official_test.cfg
