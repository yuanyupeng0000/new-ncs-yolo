# %%
import sys,os,datetime
import cv2
import xml.etree.ElementTree as ET
from PIL import Image
import numpy as np
import random
#from pathlib import Path

from ctypes import *
import math
#cv2_root = "/usr/local/lib-bk/python2.7/dist-packages/cv2"
#sys.path.insert(0,cv2_root)
#cv2_lib_avcodec = "/usr/lib/x86_64-linux-gnu/bkavcodec"
#sys.path.insert(0,cv2_lib_avcodec)
val_txt_file = "/media/yyp/DATA/Public_Datasets/ZENITH_DATASETS/2007_val.txt"
time_str = (datetime.datetime.now()).strftime("%Y%m%d")
f = open(val_txt_file, 'r')
data = f.readlines()
seed_xml_names = []
GENE_XML_DIR = '/media/yyp/DATA/EVALUATE/' + time_str + '_detection_result/'
#GENE_XML_DIR = '/data/darknet/python/' + time_str + '_detection_result_864/'
for line in data:
    #print line
    xml_name = line.replace('JPEGImages', 'Annotations')
    xml_name = line.replace('.jpg', '.xml')
    seed_xml_names.append(xml_name)
    
'''
data_file = '/data/darknet/cfg/coco.data'
cfg_file = '/data/darknet/cfg/yolov3-nob-288.cfg'
weights_file = '/data/weights/header_int_aaa_yolov3.weights'
'''

#weights_file = '/data/darknet/weights/yolov3-tiny-ncs-without-last-maxpool-refined-anchors_120000.weights'
seed_xml_names.sort()

# %%
def sample(probs):
    s = sum(probs)
    probs = [a/s for a in probs]
    r = random.uniform(0, 1)
    for i in range(len(probs)):
        r = r - probs[i]
        if r <= 0:
            return i
    return len(probs)-1

def c_array(ctype, values):
    arr = (ctype*len(values))()
    arr[:] = values
    return arr

class BOX(Structure):
    _fields_ = [("x", c_float),
                ("y", c_float),
                ("w", c_float),
                ("h", c_float)]

class DETECTION(Structure):
    _fields_ = [("bbox", BOX),
                ("classes", c_int),
                ("prob", POINTER(c_float)),
                ("mask", POINTER(c_float)),
                ("objectness", c_float),
                ("sort_class", c_int)]


class IMAGE(Structure):
    _fields_ = [("w", c_int),
                ("h", c_int),
                ("c", c_int),
                ("data", POINTER(c_float))]

class METADATA(Structure):
    _fields_ = [("classes", c_int),
                ("names", POINTER(c_char_p))]
    
def classify(net, meta, im):
    out = predict_image(net, im)
    res = []
    for i in range(meta.classes):
        res.append((meta.names[i], out[i]))
    res = sorted(res, key=lambda x: -x[1])
    return res

def detect(net, meta, image, thresh=.5, hier_thresh=.5, nms=.45):
    im = load_image(image, 0, 0)
    num = c_int(0)
    pnum = pointer(num)
    predict_image(net, im)
    dets = get_network_boxes(net, im.w, im.h, thresh, hier_thresh, None, 0, pnum)
    num = pnum[0]
    if (nms): do_nms_obj(dets, num, meta.classes, nms);

    res = []
    for j in range(num):
        for i in range(meta.classes):
            if dets[j].prob[i] > 0:
                b = dets[j].bbox
                res.append((meta.names[i], dets[j].prob[i], (b.x, b.y, b.w, b.h)))
    res = sorted(res, key=lambda x: -x[1])
    free_image(im)
    free_detections(dets, num)
    return res
#lib = CDLL("/home/pjreddie/documents/darknet/libdarknet.so", RTLD_GLOBAL)
lib = CDLL("/data/darknet/libdarknet.so", RTLD_GLOBAL)
lib.network_width.argtypes = [c_void_p]
lib.network_width.restype = c_int
lib.network_height.argtypes = [c_void_p]
lib.network_height.restype = c_int

predict = lib.network_predict
predict.argtypes = [c_void_p, POINTER(c_float)]
predict.restype = POINTER(c_float)

set_gpu = lib.cuda_set_device
set_gpu.argtypes = [c_int]

make_image = lib.make_image
make_image.argtypes = [c_int, c_int, c_int]
make_image.restype = IMAGE

get_network_boxes = lib.get_network_boxes
get_network_boxes.argtypes = [c_void_p, c_int, c_int, c_float, c_float, POINTER(c_int), c_int, POINTER(c_int)]
get_network_boxes.restype = POINTER(DETECTION)

make_network_boxes = lib.make_network_boxes
make_network_boxes.argtypes = [c_void_p]
make_network_boxes.restype = POINTER(DETECTION)

free_detections = lib.free_detections
free_detections.argtypes = [POINTER(DETECTION), c_int]

free_ptrs = lib.free_ptrs
free_ptrs.argtypes = [POINTER(c_void_p), c_int]

network_predict = lib.network_predict
network_predict.argtypes = [c_void_p, POINTER(c_float)]

reset_rnn = lib.reset_rnn
reset_rnn.argtypes = [c_void_p]

load_net = lib.load_network
load_net.argtypes = [c_char_p, c_char_p, c_int]
load_net.restype = c_void_p

do_nms_obj = lib.do_nms_obj
do_nms_obj.argtypes = [POINTER(DETECTION), c_int, c_int, c_float]

do_nms_sort = lib.do_nms_sort
do_nms_sort.argtypes = [POINTER(DETECTION), c_int, c_int, c_float]

free_image = lib.free_image
free_image.argtypes = [IMAGE]

letterbox_image = lib.letterbox_image
letterbox_image.argtypes = [IMAGE, c_int, c_int]
letterbox_image.restype = IMAGE

load_meta = lib.get_metadata
lib.get_metadata.argtypes = [c_char_p]
lib.get_metadata.restype = METADATA

load_image = lib.load_image_color
load_image.argtypes = [c_char_p, c_int, c_int]
load_image.restype = IMAGE

rgbgr_image = lib.rgbgr_image
rgbgr_image.argtypes = [IMAGE]

predict_image = lib.network_predict_image
predict_image.argtypes = [c_void_p, IMAGE]
predict_image.restype = POINTER(c_float)

# %%
#data_file = '/data/darknet/cfg/voc-veichle.data'
data_file = '/data/darknet/cfg/voc-vehicle-person.data'

all_wieghts_dir = '/media/yyp/DATA/EVALUATE/'
weights = os.listdir(all_wieghts_dir)
weights.sort()
for weight in weights:
    if(not weight.endswith('.weights')):
        continue
    cfg_file = all_wieghts_dir + weight[:-len(weight.split('_')[-1])] + 'test.cfg'
    print(cfg_file)
    generated_xml_dir = GENE_XML_DIR + weight.split('.weights')[0] + '/'
    #if(os.path.exists(generated_xml_dir)):
    #   continue
    #os.system('rm -rf ' + GENE_XML_DIR)
    os.system('mkdir -p ' + generated_xml_dir)
    weights_file = all_wieghts_dir + weight
    net = load_net(cfg_file, weights_file, 0)
    meta = load_meta(data_file)
    for image_file in data:
        image = image_file.split('/')[-1]
        image = image[:-1]
        if(os.path.exists(generated_xml_dir + image[:-4] + '.xml')):
            continue
        image_file = image_file[:-1]
        ret = image_file.endswith('.jpg')
        if ret == False:
            print('+++++++++++')
            continue
        #print('detect')
        r = detect(net, meta, image_file, 0.3, 0.5, 0.45)
        #print(len(r))

        origimg = cv2.imread(image_file)
        height = origimg.shape[0]
        width = origimg.shape[1]
        depth = origimg.shape[2]

        xml_str = "<annotation>\n\t\
        <folder>image</folder>\n\t\
        <filename>" + image + "</filename>\n\t\
        " + "<path>" + image_file + "</path>\n\t\
        <source>\n\t\t\
        <database>Unknown</database>\n\t\
        </source>\n\t\
        <size>\n\t\t\
        <width>" + str(width) + "</width>\n\t\t\
        <height>" + str(height) + "</height>\n\t\t\
        <depth>" + str(depth) + "</depth>\n\t\
        </size>\n\t\
        <segmented>0</segmented>"
        #print(xml_str)
        found_flag = False
        for i in range(len(r)):
            cls = r[i][0]
            #print(cls)
            if(cls not in ['bus','car','truck', 'motorbike','bicycle','person', 'B', 'C', 'T']):
            #if(cls not in ['person', 'motorbike','bicycle']):
                continue
            found_flag = True
            score = r[i][1]
            bbox = r[i][2]

            x1 = max(0, (bbox[0] - bbox[2]/2))
            y1 = max(0, (bbox[1] - bbox[3]/2))
            x2 = min(width, (bbox[0] + bbox[2]/2))
            y2 = min(height, (bbox[1] + bbox[3]/2))      

            p1 = (int(x1), int(y1))
            p2 = (int(x2), int(y2))

            obj_str = "\n\t\
            <object>\n\t\t\
            <name>" + cls + "</name>\n\t\t\
            <pose>Unspecified</pose>\n\t\t\
            <truncated>0</truncated>\n\t\t\
            <difficult>0</difficult>\n\t\t\
            <bndbox>\n\t\t\t\
            <xmin>" + str(int(x1)) + "</xmin>\n\t\t\t\
            <ymin>" + str(int(y1)) + "</ymin>\n\t\t\t\
            <xmax>" + str(int(x2)) + "</xmax>\n\t\t\t\
            <ymax>" + str(int(y2)) + "</ymax>\n\t\t\
            </bndbox>\n\t\
            </object>"

            xml_str += obj_str

            cv2.rectangle(origimg, p1, p2, (0,255,0))
            p3 = (max(p1[0], 15), max(p1[1], 15))
            title = "%s:%.2f" % (cls, score)
            cv2.putText(origimg, title, p3, cv2.FONT_ITALIC, 0.6, (0, 255, 0), 1)
        xml_str += "\n</annotation>"
        #print('found_flag {0}'.format(found_flag))
        if (not found_flag):
            continue
        fileObject = open(generated_xml_dir + image[:-4] + '.xml', 'w')  
        fileObject.write(xml_str)
        fileObject.close()
        #cv2.imwrite('/data/'+ image_file.split('/')[-1], origimg)
        print("Created : " + generated_xml_dir + image[:-4] + '.xml')
# Out:
# /media/yyp/DATA/EVALUATE/yolov3-tiny-ncs-without-last-maxpool-refined-anchors-6cls-extend-remove-maxpooling_new_test.cfg
# Created : /media/yyp/DATA/EVALUATE/20190712_detection_result/yolov3-tiny-ncs-without-last-maxpool-refined-anchors-6cls-extend-remove-maxpooling_new_150000/00000200576.xml
# Created : /media/yyp/DATA/EVALUATE/20190712_detection_result/yolov3-tiny-ncs-without-last-maxpool-refined-anchors-6cls-extend-remove-maxpooling_new_150000/ge_shrink_scale_0.4_0_25_00000002015.xml
# Created : /media/yyp/DATA/EVALUATE/20190712_detection_result/yolov3-tiny-ncs-without-last-maxpool-refined-anchors-6cls-extend-remove-maxpooling_new_150000/00000305255.xml
# Created : /media/yyp/DATA/EVALUATE/20190712_detection_result/yolov3-tiny-ncs-without-last-maxpool-refined-anchors-6cls-extend-remove-maxpooling_new_150000/ge_shrink_scale_0.4_0_00000003317.xml
# Created : /media/yyp/DATA/EVALUATE/20190712_detection_result/yolov3-tiny-ncs-without-last-maxpool-refined-anchors-6cls-extend-remove-maxpooling_new_150000/ge_shrink_scale_0_0.3_25_00000002821.xml
# Created : /media/yyp/DATA/EVALUATE/20190712_detection_result/yolov3-tiny-ncs-without-last-maxpool-refined-anchors-6cls-extend-remove-maxpooling_new_150000/00000202880.xml
# Created : /media/yyp/DATA/EVALUATE/20190712_detection_result/yolov3-tiny-ncs-without-last-maxpool-refined-anchors-6cls-extend-remove-maxpooling_new_150000/20190115162644810943_00000450180.xml
# Created : /media/yyp/DATA/EVALUATE/20190712_detection_result/yolov3-tiny-ncs-without-last-maxpool-refined-anchors-6cls-extend-remove-maxpooling_new_150000/ge_shrink_scale_0.4_0_25_00000002375.xml
# Created : /media/yyp/DATA/EVALUATE/20190712_detection_result/yolov3-tiny-ncs-without-last-maxpool-refined-anchors-6cls-extend-remove-maxpooling_new_150000/ge_shrink_scale_0.4_0_0010054.xml
# Created : /media/yyp/DATA/EVALUATE/20190712_detection_result/yolov3-tiny-ncs-without-last-maxpool-refined-anchors-6cls-extend-remove-maxpooling_new_150000/ge_shrink_scale_0.4_0_00000003737.xml
# Created : /media/yyp/DATA/EVALUATE/20190712_detection_result/yolov3-tiny-ncs-without-last-maxpool-refined-anchors-6cls-extend-remove-maxpooling_new_150000/00000217915.xml
# Created : /media/yyp/DATA/EVALUATE/20190712_detection_result/yolov3-tiny-ncs-without-last-maxpool-refined-anchors-6cls-extend-remove-maxpooling_new_150000/00000403221.xml
# Created : /media/yyp/DATA/EVALUATE/20190712_detection_result/yolov3-tiny-ncs-without-last-maxpool-refined-anchors-6cls-extend-remove-maxpooling_new_150000/ge_shrink_scale_0.4_0_25_00000003368.xml
# Created : /media/yyp/DATA/EVALUATE/20190712_detection_result/yolov3-tiny-ncs-without-last-maxpool-refined-anchors-6cls-extend-remove-maxpooling_new_150000/00000000352.xml
# Created : /media/yyp/DATA/EVALUATE/20190712_detection_result/yolov3-tiny-ncs-without-last-maxpool-refined-anchors-6cls-extend-remove-maxpooling_new_150000/ge_shrink_scale_0_0.3_25_00000001487.xml
# Created : /media/yyp/DATA/EVALUATE/20190712_detection_result/yolov3-tiny-ncs-without-last-maxpool-refined-anchors-6cls-extend-remove-maxpooling_new_150000/ge_shrink_scale_0.4_0_00000003899.xml
# Created : /media/yyp/DATA/EVALUATE/20190712_detection_result/yolov3-tiny-ncs-without-last-maxpool-refined-anchors-6cls-extend-remove-maxpooling_new_150000/00000411336.xml
# Created : /media/yyp/DATA/EVALUATE/20190712_detection_result/yolov3-tiny-ncs-without-last-maxpool-refined-anchors-6cls-extend-remove-maxpooling_new_150000/20190115163159121006_00000450202.xml
# Created : /media/yyp/DATA/EVALUATE/20190712_detection_result/yolov3-tiny-ncs-without-last-maxpool-refined-anchors-6cls-extend-remove-maxpooling_new_150000/ge_shrink_scale_0_0.3_25_00000001885.xml
# Created : /media/yyp/DATA/EVALUATE/20190712_detection_result/yolov3-tiny-ncs-without-last-maxpool-refined-anchors-6cls-extend-remove-maxpooling_new_150000/ge_shrink_scale_0_0.3_25_00000001536.xml
# Created : /media/yyp/DATA/EVALUATE/20190712_detection_result/yolov3-tiny-ncs-without-last-maxpool-refined-anchors-6cls-extend-remove-maxpooling_new_150000/00000211575.xml
# Created : /media/yyp/DATA/EVALUATE/20190712_detection_result/yolov3-tiny-ncs-without-last-maxpool-refined-anchors-6cls-extend-remove-maxpooling_new_150000/00000204036.xml
# Created : /media/yyp/DATA/EVALUATE/20190712_detection_result/yolov3-tiny-ncs-without-last-maxpool-refined-anchors-6cls-extend-remove-maxpooling_new_150000/00000000909.xml
# Created : /media/yyp/DATA/EVALUATE/20190712_detection_result/yolov3-tiny-ncs-without-last-maxpool-refined-anchors-6cls-extend-remove-maxpooling_new_150000/00000000915.xml
# Created : /media/yyp/DATA/EVALUATE/20190712_detection_result/yolov3-tiny-ncs-without-last-maxpool-refined-anchors-6cls-extend-remove-maxpooling_new_150000/20190111115127687011_00000434809.xml
# Created : /media/yyp/DATA/EVALUATE/20190712_detection_result/yolov3-tiny-ncs-without-last-maxpool-refined-anchors-6cls-extend-remove-maxpooling_new_150000/00000002979.xml
# Created : /media/yyp/DATA/EVALUATE/20190712_detection_result/yolov3-tiny-ncs-without-last-maxpool-refined-anchors-6cls-extend-remove-maxpooling_new_150000/00000002981.xml
# Created : /media/yyp/DATA/EVALUATE/20190712_detection_result/yolov3-tiny-ncs-without-last-maxpool-refined-anchors-6cls-extend-remove-maxpooling_new_150000/ge_shrink_scale_0.4_0_0005037.xml
# Created : /media/yyp/DATA/EVALUATE/20190712_detection_result/yolov3-tiny-ncs-without-last-maxpool-refined-anchors-6cls-extend-remove-maxpooling_new_150000/ge_shrink_scale_0.4_0_00000000531.xml
# Created : /media/yyp/DATA/EVALUATE/20190712_detection_result/yolov3-tiny-ncs-without-last-maxpool-refined-anchors-6cls-extend-remove-maxpooling_new_150000/ge_shrink_scale_0.4_0_00000001021.xml
# Created : /media/yyp/DATA/EVALUATE/20190712_detection_result/yolov3-tiny-ncs-without-last-maxpool-refined-anchors-6cls-extend-remove-maxpooling_new_150000/ge_shrink_scale_0_0.3_25_00000002940.xml
# Created : /media/yyp/DATA/EVALUATE/20190712_detection_result/yolov3-tiny-ncs-without-last-maxpool-refined-anchors-6cls-extend-remove-maxpooling_new_150000/00000205770.xml
# Created : /media/yyp/DATA/EVALUATE/20190712_detection_result/yolov3-tiny-ncs-without-last-maxpool-refined-anchors-6cls-extend-remove-maxpooling_new_150000/ge_shrink_scale_0.4_0_25_00000003531.xml
# Created : /media/yyp/DATA/EVALUATE/20190712_detection_result/yolov3-tiny-ncs-without-last-maxpool-refined-anchors-6cls-extend-remove-maxpooling_new_150000/00000205923.xml
# Created : /media/yyp/DATA/EVALUATE/20190712_detection_result/yolov3-tiny-ncs-without-last-maxpool-refined-anchors-6cls-extend-remove-maxpooling_new_150000/00000002516.xml
# Created : /media/yyp/DATA/EVALUATE/20190712_detection_result/yolov3-tiny-ncs-without-last-maxpool-refined-anchors-6cls-extend-remove-maxpooling_new_150000/00000213699.xml
# Created : /media/yyp/DATA/EVALUATE/20190712_detection_result/yolov3-tiny-ncs-without-last-maxpool-refined-anchors-6cls-extend-remove-maxpooling_new_150000/20190115162217438190_00000450000.xml
# Created : /media/yyp/DATA/EVALUATE/20190712_detection_result/yolov3-tiny-ncs-without-last-maxpool-refined-anchors-6cls-extend-remove-maxpooling_new_150000/20190115162218627616_00000450002.xml
# Created : /media/yyp/DATA/EVALUATE/20190712_detection_result/yolov3-tiny-ncs-without-last-maxpool-refined-anchors-6cls-extend-remove-maxpooling_new_150000/00000218754.xml
# Created : /media/yyp/DATA/EVALUATE/20190712_detection_result/yolov3-tiny-ncs-without-last-maxpool-refined-anchors-6cls-extend-remove-maxpooling_new_150000/20190115162908835439_00000450177.xml
# Created : /media/yyp/DATA/EVALUATE/20190712_detection_result/yolov3-tiny-ncs-without-last-maxpool-refined-anchors-6cls-extend-remove-maxpooling_new_150000/00000214052.xml
# Created : /media/yyp/DATA/EVALUATE/20190712_detection_result/yolov3-tiny-ncs-without-last-maxpool-refined-anchors-6cls-extend-remove-maxpooling_new_150000/ge_shrink_scale_0.4_0_25_00000001618.xml
# Created : /media/yyp/DATA/EVALUATE/20190712_detection_result/yolov3-tiny-ncs-without-last-maxpool-refined-anchors-6cls-extend-remove-maxpooling_new_150000/ge_shrink_scale_0.4_0_25_00000002584.xml
# Created : /media/yyp/DATA/EVALUATE/20190712_detection_result/yolov3-tiny-ncs-without-last-maxpool-refined-anchors-6cls-extend-remove-maxpooling_new_150000/ge_shrink_scale_0_0.3_25_00000000213.xml
# Created : /media/yyp/DATA/EVALUATE/20190712_detection_result/yolov3-tiny-ncs-without-last-maxpool-refined-anchors-6cls-extend-remove-maxpooling_new_150000/00000403402.xml
# Created : /media/yyp/DATA/EVALUATE/20190712_detection_result/yolov3-tiny-ncs-without-last-maxpool-refined-anchors-6cls-extend-remove-maxpooling_new_150000/00000410465.xml
# Created : /media/yyp/DATA/EVALUATE/20190712_detection_result/yolov3-tiny-ncs-without-last-maxpool-refined-anchors-6cls-extend-remove-maxpooling_new_150000/ge_shrink_scale_0.4_0_00000003501.xml
# Created : /media/yyp/DATA/EVALUATE/20190712_detection_result/yolov3-tiny-ncs-without-last-maxpool-refined-anchors-6cls-extend-remove-maxpooling_new_150000/ge_shrink_scale_0.4_0_00000003513.xml
# Created : /media/yyp/DATA/EVALUATE/20190712_detection_result/yolov3-tiny-ncs-without-last-maxpool-refined-anchors-6cls-extend-remove-maxpooling_new_150000/ge_shrink_scale_0.4_0_00000003519.xml
# Created : /media/yyp/DATA/EVALUATE/20190712_detection_result/yolov3-tiny-ncs-without-last-maxpool-refined-anchors-6cls-extend-remove-maxpooling_new_150000/00000205690.xml
# Created : /media/yyp/DATA/EVALUATE/20190712_detection_result/yolov3-tiny-ncs-without-last-maxpool-refined-anchors-6cls-extend-remove-maxpooling_new_150000/00000205333.xml
# Created : /media/yyp/DATA/EVALUATE/20190712_detection_result/yolov3-tiny-ncs-without-last-maxpool-refined-anchors-6cls-extend-remove-maxpooling_new_150000/00000402205.xml
# Created : /media/yyp/DATA/EVALUATE/20190712_detection_result/yolov3-tiny-ncs-without-last-maxpool-refined-anchors-6cls-extend-remove-maxpooling_new_150000/ge_shrink_scale_0.4_0_25_00000001328.xml
# Created : /media/yyp/DATA/EVALUATE/20190712_detection_result/yolov3-tiny-ncs-without-last-maxpool-refined-anchors-6cls-extend-remove-maxpooling_new_150000/ge_shrink_scale_0_0.3_25_00000003033.xml
# Created : /media/yyp/DATA/EVALUATE/20190712_detection_result/yolov3-tiny-ncs-without-last-maxpool-refined-anchors-6cls-extend-remove-maxpooling_new_150000/00000411474.xml
# Created : /media/yyp/DATA/EVALUATE/20190712_detection_result/yolov3-tiny-ncs-without-last-maxpool-refined-anchors-6cls-extend-remove-maxpooling_new_150000/00000200144.xml
# Created : /media/yyp/DATA/EVALUATE/20190712_detection_result/yolov3-tiny-ncs-without-last-maxpool-refined-anchors-6cls-extend-remove-maxpooling_new_150000/ge_shrink_scale_0_0.3_255_00000003610.xml
# Created : /media/yyp/DATA/EVALUATE/20190712_detection_result/yolov3-tiny-ncs-without-last-maxpool-refined-anchors-6cls-extend-remove-maxpooling_new_150000/ge_shrink_scale_0.4_0_25_00000001849.xml
# Created : /media/yyp/DATA/EVALUATE/20190712_detection_result/yolov3-tiny-ncs-without-last-maxpool-refined-anchors-6cls-extend-remove-maxpooling_new_150000/ge_shrink_scale_0_0.3_25_00000003382.xml
# Created : /media/yyp/DATA/EVALUATE/20190712_detection_result/yolov3-tiny-ncs-without-last-maxpool-refined-anchors-6cls-extend-remove-maxpooling_new_150000/00000001440.xml
# Created : /media/yyp/DATA/EVALUATE/20190712_detection_result/yolov3-tiny-ncs-without-last-maxpool-refined-anchors-6cls-extend-remove-maxpooling_new_150000/20181206134541_00000900030.xml
# Created : /media/yyp/DATA/EVALUATE/20190712_detection_result/yolov3-tiny-ncs-without-last-maxpool-refined-anchors-6cls-extend-remove-maxpooling_new_150000/ge_shrink_scale_0_0.3_255_00000000540.xml
# Created : /media/yyp/DATA/EVALUATE/20190712_detection_result/yolov3-tiny-ncs-without-last-maxpool-refined-anchors-6cls-extend-remove-maxpooling_new_150000/20190105214246208827_00000420390.xml
# Created : /media/yyp/DATA/EVALUATE/20190712_detection_result/yolov3-tiny-ncs-without-last-maxpool-refined-anchors-6cls-extend-remove-maxpooling_new_150000/ge_shrink_scale_0_0.3_25_00000001180.xml
# Created : /media/yyp/DATA/EVALUATE/20190712_detection_result/yolov3-tiny-ncs-without-last-maxpool-refined-anchors-6cls-extend-remove-maxpooling_new_150000/00000403102.xml
# Created : /media/yyp/DATA/EVALUATE/20190712_detection_result/yolov3-tiny-ncs-without-last-maxpool-refined-anchors-6cls-extend-remove-maxpooling_new_150000/00000002380.xml
# Created : /media/yyp/DATA/EVALUATE/20190712_detection_result/yolov3-tiny-ncs-without-last-maxpool-refined-anchors-6cls-extend-remove-maxpooling_new_150000/00000205535.xml
# Created : /media/yyp/DATA/EVALUATE/20190712_detection_result/yolov3-tiny-ncs-without-last-maxpool-refined-anchors-6cls-extend-remove-maxpooling_new_150000/ge_shrink_scale_0_0.3_25_00000001016.xml
# Created : /media/yyp/DATA/EVALUATE/20190712_detection_result/yolov3-tiny-ncs-without-last-maxpool-refined-anchors-6cls-extend-remove-maxpooling_new_150000/00000003122.xml
# Created : /media/yyp/DATA/EVALUATE/20190712_detection_result/yolov3-tiny-ncs-without-last-maxpool-refined-anchors-6cls-extend-remove-maxpooling_new_150000/ge_shrink_scale_0.4_0_00000001860.xml
# Created : /media/yyp/DATA/EVALUATE/20190712_detection_result/yolov3-tiny-ncs-without-last-maxpool-refined-anchors-6cls-extend-remove-maxpooling_new_150000/ge_shrink_scale_0.4_0_25_0000019.xml
# Created : /media/yyp/DATA/EVALUATE/20190712_detection_result/yolov3-tiny-ncs-without-last-maxpool-refined-anchors-6cls-extend-remove-maxpooling_new_150000/00000002874.xml
# Created : /media/yyp/DATA/EVALUATE/20190712_detection_result/yolov3-tiny-ncs-without-last-maxpool-refined-anchors-6cls-extend-remove-maxpooling_new_150000/00000003287.xml
# Created : /media/yyp/DATA/EVALUATE/20190712_detection_result/yolov3-tiny-ncs-without-last-maxpool-refined-anchors-6cls-extend-remove-maxpooling_new_150000/ge_shrink_scale_0_0.3_255_0005029.xml
# Created : /media/yyp/DATA/EVALUATE/20190712_detection_result/yolov3-tiny-ncs-without-last-maxpool-refined-anchors-6cls-extend-remove-maxpooling_new_150000/ge_shrink_scale_0.4_0_25_00000001239.xml
# Created : /media/yyp/DATA/EVALUATE/20190712_detection_result/yolov3-tiny-ncs-without-last-maxpool-refined-anchors-6cls-extend-remove-maxpooling_new_150000/ge_shrink_scale_0.4_0_00000002918.xml
# Created : /media/yyp/DATA/EVALUATE/20190712_detection_result/yolov3-tiny-ncs-without-last-maxpool-refined-anchors-6cls-extend-remove-maxpooling_new_150000/ge_shrink_scale_0.4_0_00000002919.xml
# Created : /media/yyp/DATA/EVALUATE/20190712_detection_result/yolov3-tiny-ncs-without-last-maxpool-refined-anchors-6cls-extend-remove-maxpooling_new_150000/00000402032.xml
# Created : /media/yyp/DATA/EVALUATE/20190712_detection_result/yolov3-tiny-ncs-without-last-maxpool-refined-anchors-6cls-extend-remove-maxpooling_new_150000/00000401102.xml
# Created : /media/yyp/DATA/EVALUATE/20190712_detection_result/yolov3-tiny-ncs-without-last-maxpool-refined-anchors-6cls-extend-remove-maxpooling_new_150000/20190115163039234068_00000450093.xml
# Created : /media/yyp/DATA/EVALUATE/20190712_detection_result/yolov3-tiny-ncs-without-last-maxpool-refined-anchors-6cls-extend-remove-maxpooling_new_150000/00000213144.xml
# Created : /media/yyp/DATA/EVALUATE/20190712_detection_result/yolov3-tiny-ncs-without-last-maxpool-refined-anchors-6cls-extend-remove-maxpooling_new_150000/00000411006.xml
# Created : /media/yyp/DATA/EVALUATE/20190712_detection_result/yolov3-tiny-ncs-without-last-maxpool-refined-anchors-6cls-extend-remove-maxpooling_new_150000/00000218084.xml
# Created : /media/yyp/DATA/EVALUATE/20190712_detection_result/yolov3-tiny-ncs-without-last-maxpool-refined-anchors-6cls-extend-remove-maxpooling_new_150000/00000201631.xml
# Created : /media/yyp/DATA/EVALUATE/20190712_detection_result/yolov3-tiny-ncs-without-last-maxpool-refined-anchors-6cls-extend-remove-maxpooling_new_150000/ge_shrink_scale_0.4_0_25_00000003008.xml
# Created : /media/yyp/DATA/EVALUATE/20190712_detection_result/yolov3-tiny-ncs-without-last-maxpool-refined-anchors-6cls-extend-remove-maxpooling_new_150000/ge_shrink_scale_0.4_0_25_00000003023.xml
# Created : /media/yyp/DATA/EVALUATE/20190712_detection_result/yolov3-tiny-ncs-without-last-maxpool-refined-anchors-6cls-extend-remove-maxpooling_new_150000/ge_shrink_scale_0_0.3_255_00000002555.xml
# Created : /media/yyp/DATA/EVALUATE/20190712_detection_result/yolov3-tiny-ncs-without-last-maxpool-refined-anchors-6cls-extend-remove-maxpooling_new_150000/ge_shrink_scale_0.4_0_25_00000001415.xml
# Created : /media/yyp/DATA/EVALUATE/20190712_detection_result/yolov3-tiny-ncs-without-last-maxpool-refined-anchors-6cls-extend-remove-maxpooling_new_150000/20190105144932712917_00000420385.xml
# Created : /media/yyp/DATA/EVALUATE/20190712_detection_result/yolov3-tiny-ncs-without-last-maxpool-refined-anchors-6cls-extend-remove-maxpooling_new_150000/00000400110.xml
# Created : /media/yyp/DATA/EVALUATE/20190712_detection_result/yolov3-tiny-ncs-without-last-maxpool-refined-anchors-6cls-extend-remove-maxpooling_new_150000/ge_shrink_scale_0_0.3_255_00000000349.xml
# Created : /media/yyp/DATA/EVALUATE/20190712_detection_result/yolov3-tiny-ncs-without-last-maxpool-refined-anchors-6cls-extend-remove-maxpooling_new_150000/00000200237.xml
# Created : /media/yyp/DATA/EVALUATE/20190712_detection_result/yolov3-tiny-ncs-without-last-maxpool-refined-anchors-6cls-extend-remove-maxpooling_new_150000/00000216674.xml
# Created : /media/yyp/DATA/EVALUATE/20190712_detection_result/yolov3-tiny-ncs-without-last-maxpool-refined-anchors-6cls-extend-remove-maxpooling_new_150000/00000003316.xml
# Created : /media/yyp/DATA/EVALUATE/20190712_detection_result/yolov3-tiny-ncs-without-last-maxpool-refined-anchors-6cls-extend-remove-maxpooling_new_150000/00000000275.xml
# Created : /media/yyp/DATA/EVALUATE/20190712_detection_result/yolov3-tiny-ncs-without-last-maxpool-refined-anchors-6cls-extend-remove-maxpooling_new_150000/ge_shrink_scale_0.4_0_25_0009031.xml
# Created : /media/yyp/DATA/EVALUATE/20190712_detection_result/yolov3-tiny-ncs-without-last-maxpool-refined-anchors-6cls-extend-remove-maxpooling_new_150000/ge_shrink_scale_0_0.3_25_00000002488.xml
# Created : /media/yyp/DATA/EVALUATE/20190712_detection_result/yolov3-tiny-ncs-without-last-maxpool-refined-anchors-6cls-extend-remove-maxpooling_new_150000/ge_shrink_scale_0.4_0_00000002808.xml
# Created : /media/yyp/DATA/EVALUATE/20190712_detection_result/yolov3-tiny-ncs-without-last-maxpool-refined-anchors-6cls-extend-remove-maxpooling_new_150000/00000403453.xml
# Created : /media/yyp/DATA/EVALUATE/20190712_detection_result/yolov3-tiny-ncs-without-last-maxpool-refined-anchors-6cls-extend-remove-maxpooling_new_150000/20190115163718189543_00000450022.xml
# Created : /media/yyp/DATA/EVALUATE/20190712_detection_result/yolov3-tiny-ncs-without-last-maxpool-refined-anchors-6cls-extend-remove-maxpooling_new_150000/ge_shrink_scale_0.4_0_25_00000002241.xml
# Created : /media/yyp/DATA/EVALUATE/20190712_detection_result/yolov3-tiny-ncs-without-last-maxpool-refined-anchors-6cls-extend-remove-maxpooling_new_150000/00000207755.xml
# Created : /media/yyp/DATA/EVALUATE/20190712_detection_result/yolov3-tiny-ncs-without-last-maxpool-refined-anchors-6cls-extend-remove-maxpooling_new_150000/20181206134849_00000900085.xml
# Created : /media/yyp/DATA/EVALUATE/20190712_detection_result/yolov3-tiny-ncs-without-last-maxpool-refined-anchors-6cls-extend-remove-maxpooling_new_150000/ge_shrink_scale_0_0.3_255_00000003752.xml
# Created : /media/yyp/DATA/EVALUATE/20190712_detection_result/yolov3-tiny-ncs-without-last-maxpool-refined-anchors-6cls-extend-remove-maxpooling_new_150000/20190113102128233779_00000440032.xml
# Created : /media/yyp/DATA/EVALUATE/20190712_detection_result/yolov3-tiny-ncs-without-last-maxpool-refined-anchors-6cls-extend-remove-maxpooling_new_150000/ge_shrink_scale_0_0.3_255_00000002228.xml
# Created : /media/yyp/DATA/EVALUATE/20190712_detection_result/yolov3-tiny-ncs-without-last-maxpool-refined-anchors-6cls-extend-remove-maxpooling_new_150000/00000402272.xml
# Created : /media/yyp/DATA/EVALUATE/20190712_detection_result/yolov3-tiny-ncs-without-last-maxpool-refined-anchors-6cls-extend-remove-maxpooling_new_150000/00000402275.xml
# Created : /media/yyp/DATA/EVALUATE/20190712_detection_result/yolov3-tiny-ncs-without-last-maxpool-refined-anchors-6cls-extend-remove-maxpooling_new_150000/00000303195.xml
# Created : /media/yyp/DATA/EVALUATE/20190712_detection_result/yolov3-tiny-ncs-without-last-maxpool-refined-anchors-6cls-extend-remove-maxpooling_new_150000/ge_shrink_scale_0_0.3_25_00000003334.xml
# Created : /media/yyp/DATA/EVALUATE/20190712_detection_result/yolov3-tiny-ncs-without-last-maxpool-refined-anchors-6cls-extend-remove-maxpooling_new_150000/ge_shrink_scale_0.4_0_25_00000003314.xml
# Created : /media/yyp/DATA/EVALUATE/20190712_detection_result/yolov3-tiny-ncs-without-last-maxpool-refined-anchors-6cls-extend-remove-maxpooling_new_150000/00000400312.xml
# Created : /media/yyp/DATA/EVALUATE/20190712_detection_result/yolov3-tiny-ncs-without-last-maxpool-refined-anchors-6cls-extend-remove-maxpooling_new_150000/ge_shrink_scale_0_0.3_255_0009092.xml
# Created : /media/yyp/DATA/EVALUATE/20190712_detection_result/yolov3-tiny-ncs-without-last-maxpool-refined-anchors-6cls-extend-remove-maxpooling_new_150000/00000400697.xml
# Created : /media/yyp/DATA/EVALUATE/20190712_detection_result/yolov3-tiny-ncs-without-last-maxpool-refined-anchors-6cls-extend-remove-maxpooling_new_150000/00000411395.xml
# Created : /media/yyp/DATA/EVALUATE/20190712_detection_result/yolov3-tiny-ncs-without-last-maxpool-refined-anchors-6cls-extend-remove-maxpooling_new_150000/ge_shrink_scale_0.4_0_00000004157.xml
# Created : /media/yyp/DATA/EVALUATE/20190712_detection_result/yolov3-tiny-ncs-without-last-maxpool-refined-anchors-6cls-extend-remove-maxpooling_new_150000/20190115162300816566_00000450070.xml
# Created : /media/yyp/DATA/EVALUATE/20190712_detection_result/yolov3-tiny-ncs-without-last-maxpool-refined-anchors-6cls-extend-remove-maxpooling_new_150000/20190105164015785584_00000420990.xml
# Created : /media/yyp/DATA/EVALUATE/20190712_detection_result/yolov3-tiny-ncs-without-last-maxpool-refined-anchors-6cls-extend-remove-maxpooling_new_150000/00000411570.xml
# Created : /media/yyp/DATA/EVALUATE/20190712_detection_result/yolov3-tiny-ncs-without-last-maxpool-refined-anchors-6cls-extend-remove-maxpooling_new_150000/00000411582.xml
# Created : /media/yyp/DATA/EVALUATE/20190712_detection_result/yolov3-tiny-ncs-without-last-maxpool-refined-anchors-6cls-extend-remove-maxpooling_new_150000/ge_shrink_scale_0.4_0_25_00000000800.xml
# Created : /media/yyp/DATA/EVALUATE/20190712_detection_result/yolov3-tiny-ncs-without-last-maxpool-refined-anchors-6cls-extend-remove-maxpooling_new_150000/00000001756.xml
# Created : /media/yyp/DATA/EVALUATE/20190712_detection_result/yolov3-tiny-ncs-without-last-maxpool-refined-anchors-6cls-extend-remove-maxpooling_new_150000/00000205378.xml
# Created : /media/yyp/DATA/EVALUATE/20190712_detection_result/yolov3-tiny-ncs-without-last-maxpool-refined-anchors-6cls-extend-remove-maxpooling_new_150000/ge_shrink_scale_0_0.3_255_00000000407.xml
# Created : /media/yyp/DATA/EVALUATE/20190712_detection_result/yolov3-tiny-ncs-without-last-maxpool-refined-anchors-6cls-extend-remove-maxpooling_new_150000/00000002918.xml
# Created : /media/yyp/DATA/EVALUATE/20190712_detection_result/yolov3-tiny-ncs-without-last-maxpool-refined-anchors-6cls-extend-remove-maxpooling_new_150000/ge_shrink_scale_0.4_0_25_00000002723.xml
# Created : /media/yyp/DATA/EVALUATE/20190712_detection_result/yolov3-tiny-ncs-without-last-maxpool-refined-anchors-6cls-extend-remove-maxpooling_new_150000/ge_shrink_scale_0_0.3_255_00000001525.xml
# Created : /media/yyp/DATA/EVALUATE/20190712_detection_result/yolov3-tiny-ncs-without-last-maxpool-refined-anchors-6cls-extend-remove-maxpooling_new_150000/00000002560.xml
# Created : /media/yyp/DATA/EVALUATE/20190712_detection_result/yolov3-tiny-ncs-without-last-maxpool-refined-anchors-6cls-extend-remove-maxpooling_new_150000/00000217691.xml
# Created : /media/yyp/DATA/EVALUATE/20190712_detection_result/yolov3-tiny-ncs-without-last-maxpool-refined-anchors-6cls-extend-remove-maxpooling_new_150000/00000402433.xml
# Created : /media/yyp/DATA/EVALUATE/20190712_detection_result/yolov3-tiny-ncs-without-last-maxpool-refined-anchors-6cls-extend-remove-maxpooling_new_150000/00000205127.xml
# Created : /media/yyp/DATA/EVALUATE/20190712_detection_result/yolov3-tiny-ncs-without-last-maxpool-refined-anchors-6cls-extend-remove-maxpooling_new_150000/ge_shrink_scale_0_0.3_255_00000002582.xml
# Created : /media/yyp/DATA/EVALUATE/20190712_detection_result/yolov3-tiny-ncs-without-last-maxpool-refined-anchors-6cls-extend-remove-maxpooling_new_150000/00000201238.xml
# Created : /media/yyp/DATA/EVALUATE/20190712_detection_result/yolov3-tiny-ncs-without-last-maxpool-refined-anchors-6cls-extend-remove-maxpooling_new_150000/ge_shrink_scale_0.4_0_25_00000003661.xml
# Created : /media/yyp/DATA/EVALUATE/20190712_detection_result/yolov3-tiny-ncs-without-last-maxpool-refined-anchors-6cls-extend-remove-maxpooling_new_150000/ge_shrink_scale_0.4_0_25_00000001066.xml
# Created : /media/yyp/DATA/EVALUATE/20190712_detection_result/yolov3-tiny-ncs-without-last-maxpool-refined-anchors-6cls-extend-remove-maxpooling_new_150000/ge_shrink_scale_0_0.3_255_00000000321.xml
# Created : /media/yyp/DATA/EVALUATE/20190712_detection_result/yolov3-tiny-ncs-without-last-maxpool-refined-anchors-6cls-extend-remove-maxpooling_new_150000/ge_shrink_scale_0_0.3_25_00000001062.xml
# Created : /media/yyp/DATA/EVALUATE/20190712_detection_result/yolov3-tiny-ncs-without-last-maxpool-refined-anchors-6cls-extend-remove-maxpooling_new_150000/00000400855.xml
# Created : /media/yyp/DATA/EVALUATE/20190712_detection_result/yolov3-tiny-ncs-without-last-maxpool-refined-anchors-6cls-extend-remove-maxpooling_new_150000/0017023.xml
# Created : /media/yyp/DATA/EVALUATE/20190712_detection_result/yolov3-tiny-ncs-without-last-maxpool-refined-anchors-6cls-extend-remove-maxpooling_new_150000/0017046.xml
# Created : /media/yyp/DATA/EVALUATE/20190712_detection_result/yolov3-tiny-ncs-without-last-maxpool-refined-anchors-6cls-extend-remove-maxpooling_new_150000/ge_shrink_scale_0_0.3_25_00000000585.xml
# Created : /media/yyp/DATA/EVALUATE/20190712_detection_result/yolov3-tiny-ncs-without-last-maxpool-refined-anchors-6cls-extend-remove-maxpooling_new_150000/00000301048.xml
# Created : /media/yyp/DATA/EVALUATE/20190712_detection_result/yolov3-tiny-ncs-without-last-maxpool-refined-anchors-6cls-extend-remove-maxpooling_new_150000/00000211760.xml
# Created : /media/yyp/DATA/EVALUATE/20190712_detection_result/yolov3-tiny-ncs-without-last-maxpool-refined-anchors-6cls-extend-remove-maxpooling_new_150000/ge_shrink_scale_0.4_0_00000000485.xml
# Created : /media/yyp/DATA/EVALUATE/20190712_detection_result/yolov3-tiny-ncs-without-last-maxpool-refined-anchors-6cls-extend-remove-maxpooling_new_150000/00000305325.xml
# Created : /media/yyp/DATA/EVALUATE/20190712_detection_result/yolov3-tiny-ncs-without-last-maxpool-refined-anchors-6cls-extend-remove-maxpooling_new_150000/00000219900.xml
# Created : /media/yyp/DATA/EVALUATE/20190712_detection_result/yolov3-tiny-ncs-without-last-maxpool-refined-anchors-6cls-extend-remove-maxpooling_new_150000/00000210952.xml
# Created : /media/yyp/DATA/EVALUATE/20190712_detection_result/yolov3-tiny-ncs-without-last-maxpool-refined-anchors-6cls-extend-remove-maxpooling_new_150000/00000004136.xml
# Created : /media/yyp/DATA/EVALUATE/20190712_detection_result/yolov3-tiny-ncs-without-last-maxpool-refined-anchors-6cls-extend-remove-maxpooling_new_150000/00000004148.xml
# Created : /media/yyp/DATA/EVALUATE/20190712_detection_result/yolov3-tiny-ncs-without-last-maxpool-refined-anchors-6cls-extend-remove-maxpooling_new_150000/20190113123302838201_00000438177.xml
# Created : /media/yyp/DATA/EVALUATE/20190712_detection_result/yolov3-tiny-ncs-without-last-maxpool-refined-anchors-6cls-extend-remove-maxpooling_new_150000/00000218254.xml
# Created : /media/yyp/DATA/EVALUATE/20190712_detection_result/yolov3-tiny-ncs-without-last-maxpool-refined-anchors-6cls-extend-remove-maxpooling_new_150000/ge_shrink_scale_0.4_0_00000001457.xml
# Created : /media/yyp/DATA/EVALUATE/20190712_detection_result/yolov3-tiny-ncs-without-last-maxpool-refined-anchors-6cls-extend-remove-maxpooling_new_150000/00000401264.xml
# Created : /media/yyp/DATA/EVALUATE/20190712_detection_result/yolov3-tiny-ncs-without-last-maxpool-refined-anchors-6cls-extend-remove-maxpooling_new_150000/00000210726.xml
# Created : /media/yyp/DATA/EVALUATE/20190712_detection_result/yolov3-tiny-ncs-without-last-maxpool-refined-anchors-6cls-extend-remove-maxpooling_new_150000/00000201560.xml
# Created : /media/yyp/DATA/EVALUATE/20190712_detection_result/yolov3-tiny-ncs-without-last-maxpool-refined-anchors-6cls-extend-remove-maxpooling_new_150000/00000401915.xml
# Created : /media/yyp/DATA/EVALUATE/20190712_detection_result/yolov3-tiny-ncs-without-last-maxpool-refined-anchors-6cls-extend-remove-maxpooling_new_150000/ge_shrink_scale_0.4_0_00000001985.xml
# Created : /media/yyp/DATA/EVALUATE/20190712_detection_result/yolov3-tiny-ncs-without-last-maxpool-refined-anchors-6cls-extend-remove-maxpooling_new_150000/00000403039.xml
# Created : /media/yyp/DATA/EVALUATE/20190712_detection_result/yolov3-tiny-ncs-without-last-maxpool-refined-anchors-6cls-extend-remove-maxpooling_new_150000/ge_shrink_scale_0.4_0_25_00000002893.xml
# Created : /media/yyp/DATA/EVALUATE/20190712_detection_result/yolov3-tiny-ncs-without-last-maxpool-refined-anchors-6cls-extend-remove-maxpooling_new_150000/ge_shrink_scale_0.4_0_00000002396.xml
# Created : /media/yyp/DATA/EVALUATE/20190712_detection_result/yolov3-tiny-ncs-without-last-maxpool-refined-anchors-6cls-extend-remove-maxpooling_new_150000/00000201801.xml
# Created : /media/yyp/DATA/EVALUATE/20190712_detection_result/yolov3-tiny-ncs-without-last-maxpool-refined-anchors-6cls-extend-remove-maxpooling_new_150000/00000410507.xml
# Created : /media/yyp/DATA/EVALUATE/20190712_detection_result/yolov3-tiny-ncs-without-last-maxpool-refined-anchors-6cls-extend-remove-maxpooling_new_150000/20190115162309119502_00000450085.xml
# Created : /media/yyp/DATA/EVALUATE/20190712_detection_result/yolov3-tiny-ncs-without-last-maxpool-refined-anchors-6cls-extend-remove-maxpooling_new_150000/ge_shrink_scale_0.4_0_00000001214.xml
# Created : /media/yyp/DATA/EVALUATE/20190712_detection_result/yolov3-tiny-ncs-without-last-maxpool-refined-anchors-6cls-extend-remove-maxpooling_new_150000/00000201130.xml
# Created : /media/yyp/DATA/EVALUATE/20190712_detection_result/yolov3-tiny-ncs-without-last-maxpool-refined-anchors-6cls-extend-remove-maxpooling_new_150000/00000201139.xml
# Created : /media/yyp/DATA/EVALUATE/20190712_detection_result/yolov3-tiny-ncs-without-last-maxpool-refined-anchors-6cls-extend-remove-maxpooling_new_150000/00000411157.xml
# Created : /media/yyp/DATA/EVALUATE/20190712_detection_result/yolov3-tiny-ncs-without-last-maxpool-refined-anchors-6cls-extend-remove-maxpooling_new_150000/20181206134411_00000900010.xml
# Created : /media/yyp/DATA/EVALUATE/20190712_detection_result/yolov3-tiny-ncs-without-last-maxpool-refined-anchors-6cls-extend-remove-maxpooling_new_150000/ge_shrink_scale_0.4_0_25_00000003986.xml
# Created : /media/yyp/DATA/EVALUATE/20190712_detection_result/yolov3-tiny-ncs-without-last-maxpool-refined-anchors-6cls-extend-remove-maxpooling_new_150000/00000403334.xml
# Created : /media/yyp/DATA/EVALUATE/20190712_detection_result/yolov3-tiny-ncs-without-last-maxpool-refined-anchors-6cls-extend-remove-maxpooling_new_150000/00000403337.xml
# Created : /media/yyp/DATA/EVALUATE/20190712_detection_result/yolov3-tiny-ncs-without-last-maxpool-refined-anchors-6cls-extend-remove-maxpooling_new_150000/00000403357.xml
# Created : /media/yyp/DATA/EVALUATE/20190712_detection_result/yolov3-tiny-ncs-without-last-maxpool-refined-anchors-6cls-extend-remove-maxpooling_new_150000/00000401164.xml
# Created : /media/yyp/DATA/EVALUATE/20190712_detection_result/yolov3-tiny-ncs-without-last-maxpool-refined-anchors-6cls-extend-remove-maxpooling_new_150000/00000201457.xml
# Created : /media/yyp/DATA/EVALUATE/20190712_detection_result/yolov3-tiny-ncs-without-last-maxpool-refined-anchors-6cls-extend-remove-maxpooling_new_150000/00000201459.xml
# Created : /media/yyp/DATA/EVALUATE/20190712_detection_result/yolov3-tiny-ncs-without-last-maxpool-refined-anchors-6cls-extend-remove-maxpooling_new_150000/00000201469.xml
# Created : /media/yyp/DATA/EVALUATE/20190712_detection_result/yolov3-tiny-ncs-without-last-maxpool-refined-anchors-6cls-extend-remove-maxpooling_new_150000/ge_shrink_scale_0.4_0_25_00000001374.xml
# Created : /media/yyp/DATA/EVALUATE/20190712_detection_result/yolov3-tiny-ncs-without-last-maxpool-refined-anchors-6cls-extend-remove-maxpooling_new_150000/00000402156.xml
# Created : /media/yyp/DATA/EVALUATE/20190712_detection_result/yolov3-tiny-ncs-without-last-maxpool-refined-anchors-6cls-extend-remove-maxpooling_new_150000/20190113102049556431_00000440079.xml
# Created : /media/yyp/DATA/EVALUATE/20190712_detection_result/yolov3-tiny-ncs-without-last-maxpool-refined-anchors-6cls-extend-remove-maxpooling_new_150000/ge_shrink_scale_0_0.3_255_00000003566.xml
# Created : /media/yyp/DATA/EVALUATE/20190712_detection_result/yolov3-tiny-ncs-without-last-maxpool-refined-anchors-6cls-extend-remove-maxpooling_new_150000/00000401708.xml
# Created : /media/yyp/DATA/EVALUATE/20190712_detection_result/yolov3-tiny-ncs-without-last-maxpool-refined-anchors-6cls-extend-remove-maxpooling_new_150000/00000401712.xml
# Created : /media/yyp/DATA/EVALUATE/20190712_detection_result/yolov3-tiny-ncs-without-last-maxpool-refined-anchors-6cls-extend-remove-maxpooling_new_150000/ge_shrink_scale_0_0.3_255_00000002498.xml
# Created : /media/yyp/DATA/EVALUATE/20190712_detection_result/yolov3-tiny-ncs-without-last-maxpool-refined-anchors-6cls-extend-remove-maxpooling_new_150000/ge_shrink_scale_0_0.3_25_00000003202.xml
# Created : /media/yyp/DATA/EVALUATE/20190712_detection_result/yolov3-tiny-ncs-without-last-maxpool-refined-anchors-6cls-extend-remove-maxpooling_new_150000/ge_shrink_scale_0.4_0_00000000732.xml
# Created : /media/yyp/DATA/EVALUATE/20190712_detection_result/yolov3-tiny-ncs-without-last-maxpool-refined-anchors-6cls-extend-remove-maxpooling_new_150000/20190115162502396432_00000450032.xml
# Created : /media/yyp/DATA/EVALUATE/20190712_detection_result/yolov3-tiny-ncs-without-last-maxpool-refined-anchors-6cls-extend-remove-maxpooling_new_150000/ge_shrink_scale_0_0.3_25_00000003074.xml
# Created : /media/yyp/DATA/EVALUATE/20190712_detection_result/yolov3-tiny-ncs-without-last-maxpool-refined-anchors-6cls-extend-remove-maxpooling_new_150000/00000200829.xml
# Created : /media/yyp/DATA/EVALUATE/20190712_detection_result/yolov3-tiny-ncs-without-last-maxpool-refined-anchors-6cls-extend-remove-maxpooling_new_150000/20190115162725900858_00000450030.xml
# Created : /media/yyp/DATA/EVALUATE/20190712_detection_result/yolov3-tiny-ncs-without-last-maxpool-refined-anchors-6cls-extend-remove-maxpooling_new_150000/ge_shrink_scale_0.4_0_00000004102.xml
# Created : /media/yyp/DATA/EVALUATE/20190712_detection_result/yolov3-tiny-ncs-without-last-maxpool-refined-anchors-6cls-extend-remove-maxpooling_new_150000/ge_shrink_scale_0_0.3_25_0006044.xml
# Created : /media/yyp/DATA/EVALUATE/20190712_detection_result/yolov3-tiny-ncs-without-last-maxpool-refined-anchors-6cls-extend-remove-maxpooling_new_150000/ge_shrink_scale_0_0.3_255_00000000174.xml
# Created : /media/yyp/DATA/EVALUATE/20190712_detection_result/yolov3-tiny-ncs-without-last-maxpool-refined-anchors-6cls-extend-remove-maxpooling_new_150000/ge_shrink_scale_0.4_0_25_00000000433.xml
# Created : /media/yyp/DATA/EVALUATE/20190712_detection_result/yolov3-tiny-ncs-without-last-maxpool-refined-anchors-6cls-extend-remove-maxpooling_new_150000/ge_shrink_scale_0.4_0_25_0006071.xml
# Created : /media/yyp/DATA/EVALUATE/20190712_detection_result/yolov3-tiny-ncs-without-last-maxpool-refined-anchors-6cls-extend-remove-maxpooling_new_150000/00000410104.xml
# Created : /media/yyp/DATA/EVALUATE/20190712_detection_result/yolov3-tiny-ncs-without-last-maxpool-refined-anchors-6cls-extend-remove-maxpooling_new_150000/00000200515.xml
# Created : /media/yyp/DATA/EVALUATE/20190712_detection_result/yolov3-tiny-ncs-without-last-maxpool-refined-anchors-6cls-extend-remove-maxpooling_new_150000/00000200419.xml
# Created : /media/yyp/DATA/EVALUATE/20190712_detection_result/yolov3-tiny-ncs-without-last-maxpool-refined-anchors-6cls-extend-remove-maxpooling_new_150000/00000200284.xml
# Created : /media/yyp/DATA/EVALUATE/20190712_detection_result/yolov3-tiny-ncs-without-last-maxpool-refined-anchors-6cls-extend-remove-maxpooling_new_150000/ge_shrink_scale_0_0.3_255_00000003676.xml
# Created : /media/yyp/DATA/EVALUATE/20190712_detection_result/yolov3-tiny-ncs-without-last-maxpool-refined-anchors-6cls-extend-remove-maxpooling_new_150000/ge_shrink_scale_0_0.3_255_00000001749.xml
# Created : /media/yyp/DATA/EVALUATE/20190712_detection_result/yolov3-tiny-ncs-without-last-maxpool-refined-anchors-6cls-extend-remove-maxpooling_new_150000/ge_shrink_scale_0_0.3_255_00000001758.xml
# Created : /media/yyp/DATA/EVALUATE/20190712_detection_result/yolov3-tiny-ncs-without-last-maxpool-refined-anchors-6cls-extend-remove-maxpooling_new_150000/ge_shrink_scale_0.4_0_00000000413.xml
# Created : /media/yyp/DATA/EVALUATE/20190712_detection_result/yolov3-tiny-ncs-without-last-maxpool-refined-anchors-6cls-extend-remove-maxpooling_new_150000/00000216779.xml
# Created : /media/yyp/DATA/EVALUATE/20190712_detection_result/yolov3-tiny-ncs-without-last-maxpool-refined-anchors-6cls-extend-remove-maxpooling_new_150000/ge_shrink_scale_0_0.3_25_00000004170.xml
# Created : /media/yyp/DATA/EVALUATE/20190712_detection_result/yolov3-tiny-ncs-without-last-maxpool-refined-anchors-6cls-extend-remove-maxpooling_new_150000/00000302658.xml
# Created : /media/yyp/DATA/EVALUATE/20190712_detection_result/yolov3-tiny-ncs-without-last-maxpool-refined-anchors-6cls-extend-remove-maxpooling_new_150000/ge_shrink_scale_0_0.3_25_00000003659.xml
# Created : /media/yyp/DATA/EVALUATE/20190712_detection_result/yolov3-tiny-ncs-without-last-maxpool-refined-anchors-6cls-extend-remove-maxpooling_new_150000/00000402010.xml
# Created : /media/yyp/DATA/EVALUATE/20190712_detection_result/yolov3-tiny-ncs-without-last-maxpool-refined-anchors-6cls-extend-remove-maxpooling_new_150000/00000402025.xml
# Created : /media/yyp/DATA/EVALUATE/20190712_detection_result/yolov3-tiny-ncs-without-last-maxpool-refined-anchors-6cls-extend-remove-maxpooling_new_150000/ge_shrink_scale_0.4_0_00000001523.xml
# Created : /media/yyp/DATA/EVALUATE/20190712_detection_result/yolov3-tiny-ncs-without-last-maxpool-refined-anchors-6cls-extend-remove-maxpooling_new_150000/0005049.xml
# Created : /media/yyp/DATA/EVALUATE/20190712_detection_result/yolov3-tiny-ncs-without-last-maxpool-refined-anchors-6cls-extend-remove-maxpooling_new_150000/0006013.xml
# Created : /media/yyp/DATA/EVALUATE/20190712_detection_result/yolov3-tiny-ncs-without-last-maxpool-refined-anchors-6cls-extend-remove-maxpooling_new_150000/00000411448.xml
# Created : /media/yyp/DATA/EVALUATE/20190712_detection_result/yolov3-tiny-ncs-without-last-maxpool-refined-anchors-6cls-extend-remove-maxpooling_new_150000/ge_shrink_scale_0_0.3_25_0008014.xml
# Created : /media/yyp/DATA/EVALUATE/20190712_detection_result/yolov3-tiny-ncs-without-last-maxpool-refined-anchors-6cls-extend-remove-maxpooling_new_150000/00000213089.xml
# Created : /media/yyp/DATA/EVALUATE/20190712_detection_result/yolov3-tiny-ncs-without-last-maxpool-refined-anchors-6cls-extend-remove-maxpooling_new_150000/00000200188.xml
# Created : /media/yyp/DATA/EVALUATE/20190712_detection_result/yolov3-tiny-ncs-without-last-maxpool-refined-anchors-6cls-extend-remove-maxpooling_new_150000/ge_shrink_scale_0.4_0_25_00000003326.xml
# Created : /media/yyp/DATA/EVALUATE/20190712_detection_result/yolov3-tiny-ncs-without-last-maxpool-refined-anchors-6cls-extend-remove-maxpooling_new_150000/00000304242.xml
# Created : /media/yyp/DATA/EVALUATE/20190712_detection_result/yolov3-tiny-ncs-without-last-maxpool-refined-anchors-6cls-extend-remove-maxpooling_new_150000/ge_shrink_scale_0.4_0_00000000088.xml
# Created : /media/yyp/DATA/EVALUATE/20190712_detection_result/yolov3-tiny-ncs-without-last-maxpool-refined-anchors-6cls-extend-remove-maxpooling_new_150000/00000000953.xml
# Created : /media/yyp/DATA/EVALUATE/20190712_detection_result/yolov3-tiny-ncs-without-last-maxpool-refined-anchors-6cls-extend-remove-maxpooling_new_150000/20181206135410_00000900100.xml
# Created : /media/yyp/DATA/EVALUATE/20190712_detection_result/yolov3-tiny-ncs-without-last-maxpool-refined-anchors-6cls-extend-remove-maxpooling_new_150000/00000002112.xml
# Created : /media/yyp/DATA/EVALUATE/20190712_detection_result/yolov3-tiny-ncs-without-last-maxpool-refined-anchors-6cls-extend-remove-maxpooling_new_150000/00000002119.xml
# Created : /media/yyp/DATA/EVALUATE/20190712_detection_result/yolov3-tiny-ncs-without-last-maxpool-refined-anchors-6cls-extend-remove-maxpooling_new_150000/00000210443.xml
# Created : /media/yyp/DATA/EVALUATE/20190712_detection_result/yolov3-tiny-ncs-without-last-maxpool-refined-anchors-6cls-extend-remove-maxpooling_new_150000/00000210451.xml
# Created : /media/yyp/DATA/EVALUATE/20190712_detection_result/yolov3-tiny-ncs-without-last-maxpool-refined-anchors-6cls-extend-remove-maxpooling_new_150000/00000002896.xml
# Created : /media/yyp/DATA/EVALUATE/20190712_detection_result/yolov3-tiny-ncs-without-last-maxpool-refined-anchors-6cls-extend-remove-maxpooling_new_150000/ge_shrink_scale_0_0.3_255_00000002757.xml
# Created : /media/yyp/DATA/EVALUATE/20190712_detection_result/yolov3-tiny-ncs-without-last-maxpool-refined-anchors-6cls-extend-remove-maxpooling_new_150000/00000403504.xml
# Created : /media/yyp/DATA/EVALUATE/20190712_detection_result/yolov3-tiny-ncs-without-last-maxpool-refined-anchors-6cls-extend-remove-maxpooling_new_150000/00000213230.xml
# Created : /media/yyp/DATA/EVALUATE/20190712_detection_result/yolov3-tiny-ncs-without-last-maxpool-refined-anchors-6cls-extend-remove-maxpooling_new_150000/ge_shrink_scale_0_0.3_25_00000004111.xml
# Created : /media/yyp/DATA/EVALUATE/20190712_detection_result/yolov3-tiny-ncs-without-last-maxpool-refined-anchors-6cls-extend-remove-maxpooling_new_150000/ge_shrink_scale_0_0.3_25_00000004114.xml
# Created : /media/yyp/DATA/EVALUATE/20190712_detection_result/yolov3-tiny-ncs-without-last-maxpool-refined-anchors-6cls-extend-remove-maxpooling_new_150000/ge_shrink_scale_0.4_0_0000225.xml
# Created : /media/yyp/DATA/EVALUATE/20190712_detection_result/yolov3-tiny-ncs-without-last-maxpool-refined-anchors-6cls-extend-remove-maxpooling_new_150000/0008011.xml
# Created : /media/yyp/DATA/EVALUATE/20190712_detection_result/yolov3-tiny-ncs-without-last-maxpool-refined-anchors-6cls-extend-remove-maxpooling_new_150000/ge_shrink_scale_0_0.3_25_00000000648.xml
# Created : /media/yyp/DATA/EVALUATE/20190712_detection_result/yolov3-tiny-ncs-without-last-maxpool-refined-anchors-6cls-extend-remove-maxpooling_new_150000/ge_shrink_scale_0_0.3_25_00000003544.xml
# Created : /media/yyp/DATA/EVALUATE/20190712_detection_result/yolov3-tiny-ncs-without-last-maxpool-refined-anchors-6cls-extend-remove-maxpooling_new_150000/ge_shrink_scale_0.4_0_00000003296.xml
# Created : /media/yyp/DATA/EVALUATE/20190712_detection_result/yolov3-tiny-ncs-without-last-maxpool-refined-anchors-6cls-extend-remove-maxpooling_new_150000/ge_shrink_scale_0.4_0_25_00000001253.xml
# Created : /media/yyp/DATA/EVALUATE/20190712_detection_result/yolov3-tiny-ncs-without-last-maxpool-refined-anchors-6cls-extend-remove-maxpooling_new_150000/ge_shrink_scale_0_0.3_25_00000000230.xml
# Created : /media/yyp/DATA/EVALUATE/20190712_detection_result/yolov3-tiny-ncs-without-last-maxpool-refined-anchors-6cls-extend-remove-maxpooling_new_150000/20190115163044167524_00000450100.xml
# Created : /media/yyp/DATA/EVALUATE/20190712_detection_result/yolov3-tiny-ncs-without-last-maxpool-refined-anchors-6cls-extend-remove-maxpooling_new_150000/00000001791.xml
# Created : /media/yyp/DATA/EVALUATE/20190712_detection_result/yolov3-tiny-ncs-without-last-maxpool-refined-anchors-6cls-extend-remove-maxpooling_new_150000/ge_shrink_scale_0.4_0_00000001681.xml
# Created : /media/yyp/DATA/EVALUATE/20190712_detection_result/yolov3-tiny-ncs-without-last-maxpool-refined-anchors-6cls-extend-remove-maxpooling_new_150000/ge_shrink_scale_0_0.3_255_0000006.xml
