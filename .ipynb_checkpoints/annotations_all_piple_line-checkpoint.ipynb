# %%
import os,datetime
import cv2
import xml.etree.ElementTree as ET
from PIL import Image
import numpy as np
import random
from pathlib import Path

time_str = (datetime.datetime.now()).strftime("%Y%m%d")
pre_fix = '/media/yyp/DATA/Public_Datasets/ZENITH_DATASETS/VOCdevkit_Rider/VOC2007/'
xml_dir = pre_fix + '/Annotations/'
image_dir = pre_fix + '/JPEGImages/'

generated_image_dir = pre_fix + '/images/'
generated_xml_dir = pre_fix + '/xmls/'

#os.system('mkdir -p ' + xml_dir)
#os.system('mkdir -p ' + image_dir)
os.system('mkdir -p ' + generated_image_dir)
os.system('mkdir -p ' + generated_xml_dir)

SEED_XML_DIR = xml_dir
SEED_IMG_DIR = image_dir
GENE_IMG_DIR = generated_image_dir
GENE_XML_DIR = generated_xml_dir


# RT:RightTop 
# LB:LeftBottom 
# bbox: [xmin, xax, ymin, ymax]
def IOU(bbox_a, bbox_b):
    '''
    W = min(A.RT.x, B.RT.x) - max(A.LB.x, B.LB.x) 
    H = min(A.RT.y, B.RT.y) - max(A.LB.y, B.LB.y) 
    if W <= 0 or H <= 0: 
        return 0 
    SA = (A.RT.x - A.LB.x) * (A.RT.y - A.LB.y) 
    SB = (B.RT.x - B.LB.x) * (B.RT.y - B.LB.y) 
    cross = W * H return cross/(SA + SB - cross)
    '''
    W = min(bbox_a[1], bbox_b[1]) - max(bbox_a[0], bbox_b[0]) 
    H = min(bbox_a[3], bbox_b[3]) - max(bbox_a[2], bbox_b[2]) 
    if W <= 0 or H <= 0: 
        return 0
    SA = (bbox_a[1] - bbox_a[0]) * (bbox_a[3] - bbox_a[2]) 
    SB = (bbox_b[1] - bbox_b[0]) * (bbox_b[3] - bbox_b[2])  
    cross = W * H 
    return cross/(SA + SB - cross)

def get_bbox_from_xmlobj(obj_element):
    xmlbox = obj_element.find('bndbox')
    return [float(xmlbox.find('xmin').text), float(xmlbox.find('xmax').text), 
            float(xmlbox.find('ymin').text), float(xmlbox.find('ymax').text)]

def get_obj_from_xml(xml_name):
    in_file = open(xml_name)
    tree=ET.parse(in_file)
    root = tree.getroot()
    return [obj for obj in root.iter('object')]

def get_obj_from_image_file(file, bbox):
    img = cv2.imread(file)
    img_obj = img[int(bbox[2]):int(bbox[3]), int(bbox[0]):int(bbox[1])]
   #print(img_obj.shape)
    return img_obj

def get_bboxes_from_etree(etree):
    root = etree.getroot()  
    objects = root.findall('object')
    bboxes = []
    for obj in objects:
        xmlbox = obj.find('bndbox')
        b = [float(xmlbox.find('xmin').text), float(xmlbox.find('xmax').text), float(xmlbox.find('ymin').text), float(xmlbox.find('ymax').text)]
        bboxes.append(b)
    return bboxes
def past_to_background_from_image_file(file, bboxes, background_img_array, extend_spaces=0):
    
    img = cv2.imread(file)
    #img = img - 50
    if(img.shape != background_img_array.shape):
       #print('shape not match')
        return
    #print(img.shape)
    #print(img)
    img_objs = []
    for bbox in bboxes:
        img_obj = img[int(bbox[2]):int(bbox[3]), int(bbox[0]):int(bbox[1])]
        img_objs.append(img_obj)
    i = 0
    for bbox in bboxes:
        background_img_array[int(bbox[2]):int(bbox[3]), int(bbox[0]):int(bbox[1])] = img_objs[i]
        i = i+1
    cv2.imwrite(GENE_IMG_DIR+file.split('/')[-1], background_img_array)
    return 
def generate_new_xmlobj(xmlobj_old, new_position, new_size):
    element_object = ET.Element('object')
    tag_name = ET.SubElement(element_object, 'name')
    tag_name.text = xmlobj_old.find('name').text

    tag_difficult = ET.SubElement(element_object, 'difficult')
    tag_difficult.text = xmlobj_old.find('difficult').text

    element_bndbox = ET.SubElement(element_object, 'bndbox')
    tag_xmin = ET.SubElement(element_bndbox, 'xmin')
    tag_ymin = ET.SubElement(element_bndbox, 'ymin')
    tag_xmax = ET.SubElement(element_bndbox, 'xmax')
    tag_ymax = ET.SubElement(element_bndbox, 'ymax')
    tag_xmin.text = str(new_position[0])
    tag_ymin.text = str(new_position[1])
    tag_xmax.text = str(new_position[0] + new_size[1])
    tag_ymax.text = str(new_position[1] + new_size[0])
    return element_object

def generate_new_xmlobj_simple(xmlobj_old, new_bbox):
    element_object = ET.Element('object')
    tag_name = ET.SubElement(element_object, 'name')
    tag_name.text = xmlobj_old.find('name').text
    tag_difficult = ET.SubElement(element_object, 'difficult')
    tag_difficult.text = xmlobj_old.find('difficult').text
    element_bndbox = ET.SubElement(element_object, 'bndbox')
    tag_xmin = ET.SubElement(element_bndbox, 'xmin')
    tag_ymin = ET.SubElement(element_bndbox, 'ymin')
    tag_xmax = ET.SubElement(element_bndbox, 'xmax')
    tag_ymax = ET.SubElement(element_bndbox, 'ymax')
    tag_xmin.text = str(int(new_bbox[0]))
    tag_ymin.text = str(int(new_bbox[2]))
    tag_xmax.text = str(int(new_bbox[1]))
    tag_ymax.text = str(int(new_bbox[3]))
    return element_object
    
def past_and_insert(img_obj, img_array, new_position, obj_element, etree):
    new_xmlobj = generate_new_xmlobj(obj_element, new_position, img_obj.shape[:2])
    new_xml_etree = insert_to_xml(new_xmlobj, etree)
    new_pil_img = past_obj_to_background(img_obj, img_array, new_position)
    return new_pil_img, new_xml_etree
    

def insert_to_xml(xml_obj, xml_etree):
    root = xml_etree.getroot()
    root.append(xml_obj)
    return xml_etree
    
def past_obj_to_background(img_obj, img_array, position = (200, 200)):
    img = Image.fromarray(img_array)
    img_obj = Image.fromarray(img_obj)
    img.paste(img_obj, position)
    return img
    
def get_cls_from_xmlobj(obj_element):    
    return obj_element.find('name').text

def generate_new_position(img_size, img_obj_size):
    array_x = np.arange(int(img_size[1] - img_obj_size[1]))
    array_y = np.arange(int(img_size[0] - img_obj_size[0]))
    random_x = random.sample(list(array_x), 1)[0]
    random_y = random.sample(list(array_y), 1)[0]
    new_position = (random_x, random_y)
    #print(new_position)
    return new_position

def generate_new_bbox(img_size, img_obj_size):
    array_x = np.arange(int(img_size[1] - img_obj_size[1]))
    array_y = np.arange(int(img_size[0] - img_obj_size[0]))
    random_x = random.sample(list(array_x), 1)[0]
    random_y = random.sample(list(array_y), 1)[0]
    new_position = (random_x, random_y)
    new_bbox = [random_x, random_x + img_obj_size[1], random_y, random_y + img_obj_size[0]]
    #print(new_bbox)
    return new_bbox
def generate_union_bbox(matrix1, matrix2): #xin,xmax,ymin,ymax
    img_obj_shape = (int(max(matrix1[3], matrix2[3])-min(matrix1[2], matrix2[2])), 
                int(max(matrix1[1], matrix2[1])-min(matrix1[0], matrix2[0])))
    return img_obj_shape

def generate_union_bbox_shape(matrix_list): #xin,xmax,ymin,ymax
    matrix_array = np.array(matrix_list)
    img_obj_shape = (int(max(matrix_array[:,3]) - min(matrix_array[:,2])),
                     int(max(matrix_array[:,1]) - min(matrix_array[:,0])))
    return img_obj_shape

def get_union_bbox_left_top(matrix_list): #xin,xmax,ymin,ymax
    matrix_array = np.array(matrix_list)
    left_top = (int(min(matrix_array[:,0])),
                     int(min(matrix_array[:,2])))
    return left_top
def generate_union_bbox_(matrix_list):
    img_obj_shape = generate_union_bbox_shape(matrix_list)
    left_top = get_union_bbox_left_top(matrix_list)
    union_bbox = [int(left_top[0]), 
                  int(left_top[0]+int(img_obj_shape[1])),
                  int(left_top[1]),
                  int(left_top[1]+int(img_obj_shape[0]))]
    return union_bbox

def generate_new_bbox_within_distance(img_size, img_obj_size, old_bbox, scale=2.5):
    array_x = np.arange(int(img_size[1] - img_obj_size[1]))
    #array_y = np.arange(int(img_size[0] - img_obj_size[0])/3, int(img_size[0] - img_obj_size[0])/3*2)
    array_y = np.arange(max(0, int((old_bbox[3]+old_bbox[2])/2 - scale*img_obj_size[0])),
                        min(int((old_bbox[3]+old_bbox[2])/2 + scale*img_obj_size[0]), int(img_size[0] - img_obj_size[0])))
    random_x = random.sample(list(array_x), 1)[0]
    random_y = random.sample(list(array_y), 1)[0]
    new_position = (random_x, random_y)
    new_bbox = [random_x, random_x + img_obj_size[1], random_y, random_y + img_obj_size[0]]
    #print(new_bbox)
    return new_bbox

def check_before_insert(img_size, img_obj_size, etree, union_bbox):
    new_bbox = generate_new_bbox_within_distance(img_size, img_obj_size, union_bbox)
    bboxes = get_bboxes_from_etree(etree)
    retry_times = 0
    while(not check_bbox(new_bbox, bboxes)):
       #print('new_bbox not suitable, retry...')
        retry_times = retry_times + 1
        if(retry_times > 100):
            return (False, False)
        new_bbox = generate_new_bbox_within_distance(img_size, img_obj_size, union_bbox)
    return (new_bbox[0], new_bbox[2])
    
def inset_obj_to_an_image_and_xml(img_obj, img, obj_element, etree):
    new_bbox = generate_new_bbox(img.shape[:2], img_obj.shape[:2])
    bboxes = get_bboxes_from_etree(etree)
    retry_times = 0
    while(not check_bbox(new_bbox, bboxes)):
       #print('new_bbox not suitable, retry...')
        retry_times = retry_times + 1
        if(retry_times > 50):
            return False, False
        new_bbox = generate_new_bbox(img.shape[:2], img_obj.shape[:2])
    #print('new_bbox succussful')
    new_pil_img, new_xml_etree = past_and_insert(img_obj, img, (new_bbox[0], new_bbox[2]), obj_element, etree)
    
    return new_pil_img, new_xml_etree

def do_inset_obj_to_an_image_and_xml(img_obj, img, obj_element, etree, insert_point):
    new_pil_img, new_xml_etree = past_and_insert(img_obj, img, insert_point, obj_element, etree)    
    return new_pil_img, new_xml_etree

def inset_dobule_obj_to_an_image_and_xml(img_obj1, img_obj2, img, obj_element1, obj_element2, etree):
    new_bbox = generate_new_bbox(img.shape[:2], img_obj.shape[:2])
    bboxes = get_bboxes_from_etree(etree)
    retry_times = 0
    while(not check_bbox(new_bbox, bboxes)):
       #print('new_bbox not suitable, retry...')
        retry_times = retry_times + 1
        if(retry_times > 50):
            return False, False
        new_bbox = generate_new_bbox(img.shape[:2], img_obj.shape[:2])
    #print('new_bbox succussful')
    new_pil_img, new_xml_etree = past_and_insert(img_obj, img, (new_bbox[0], new_bbox[2]), obj_element, etree)
    
    return new_pil_img, new_xml_etree

def check_bbox(new_bbox, bboxes):
    for bbox in bboxes:
        if(IOU(new_bbox, bbox) > 0):
            return False
    return True
def caculate_move_vector(bbox, new_point):
    original_xmin, original_ymin = bbox[0], bbox[2]
    diffx, diffy = new_point[0] - original_xmin, new_point[1] - original_ymin
    return (diffx, diffy)

def rotate_img(img, thealta):
    (h_, w_) = img.shape[:2]
    point_list = [(0, 0), (0, h_), (w_, h_), (w_, 0)]
    center = (w_ // 2, h_ // 2)
    roted_point_list = [((point[0]-center[0])*np.cos(np.pi*thealta/180) 
                         - (point[1]-center[1])*np.sin(np.pi*thealta/180) 
                         + center[0], (point[0]-center[0])*np.sin(np.pi*thealta/180) 
                         + (point[1]-center[1])*np.cos(np.pi*thealta/180) + center[1]) for point in point_list]
    #print(roted_point_list)

    temp = np.zeros((2, 4))
    temp[0] = [roted_point[0] for roted_point in roted_point_list]
    temp[1] = [roted_point[1] for roted_point in roted_point_list]
    (xmin, xmax, ymin, ymax) = (np.min(temp[0]), np.max(temp[0]), np.min(temp[1]), np.max(temp[1]))
   #print('xmin: {0}, xmax: {1}, ymin: {2}, ymax: {3}'.format(xmin, xmax, ymin, ymax))

    roted_h, roted_w = ymax - ymin, xmax - xmin
   #print('roted_h: {0}, roted_w: {1}'.format(roted_w, roted_h))
    
    top_bottom, left_right = int((roted_h - h_)/2), int((roted_w - w_)/2)
   #print('top_bottom:{0}, left_right_:{1}'.format(top_bottom, left_right))
    padding = lambda arg : max(arg, 0)
    #dst = cv2.copyMakeBorder(img, padding(top_bottom), padding(top_bottom), padding(left_right), 
    #padding(left_right), cv2.BORDER_CONSTANT)
    dst = cv2.copyMakeBorder(img, padding(top_bottom), padding(top_bottom), padding(left_right), 
                             padding(left_right), cv2.BORDER_CONSTANT)
    
    (h, w) = dst.shape[:2]   
    center = (w // 2, h // 2)
    M = cv2.getRotationMatrix2D(center, thealta, 1.0)
    rotated_img = cv2.warpAffine(dst, M, (w, h))
    if(top_bottom < 0):
        top_bottom = abs(top_bottom)
        rotated_img = rotated_img[top_bottom:-top_bottom, :, :]
    if(left_right < 0):
        left_right = abs(left_right)
        rotated_img = rotated_img[:, left_right:-left_right, :]
    return rotated_img

def get_fliped_bbox(bbox, img_w):
    return (img_w-bbox[0], img_w-bbox[1], bbox[2], bbox[3])

def generate_etree(etree_old):
    root_old = etree_old.getroot()    
    root = ET.Element('annotation')
    root.append(root_old.find('folder'))
    root.append(root_old.find('filename'))
    root.append(root_old.find('source'))
    root.append(root_old.find('size'))
    root.append(root_old.find('segmented'))    
    tree = ET.ElementTree(root)    
    return tree
def get_intercouse_box(bbox_a, bbox_b):
    xmin_ = max(bbox_a[0], bbox_b[0])
    xmax_ = min(bbox_a[1], bbox_b[1])
    ymin_ = max(bbox_a[2], bbox_b[2])
    ymax_ = min(bbox_a[3], bbox_b[3])
    if((xmax_ - xmin_ < 20) or (ymax_ - ymin_ < 20)):
        return False
    return [xmin_, xmax_, ymin_, ymax_]

def generate_new_bbox_within_distance(img_size, img_obj_size, old_bbox, scale=2.5):
    array_x = np.arange(int(img_size[1] - img_obj_size[1]))
    #array_y = np.arange(int(img_size[0] - img_obj_size[0])/3, int(img_size[0] - img_obj_size[0])/3*2)
    array_y = np.arange(max(0, int((old_bbox[3]+old_bbox[2])/2 - scale*img_obj_size[0])),
                        min(int((old_bbox[3]+old_bbox[2])/2 + scale*img_obj_size[0]), int(img_size[0] - img_obj_size[0])))
    random_x = random.sample(list(array_x), 1)[0]
    random_y = random.sample(list(array_y), 1)[0]
    new_position = (random_x, random_y)
    new_bbox = [random_x, random_x + img_obj_size[1], random_y, random_y + img_obj_size[0]]
    #print(new_bbox)
    return new_bbox

############################# for expand obj target-intercouses (overlaps) ##################################
LOOP_TIMES = 1
REPEAT_TIMES = 1
seed_xml_names = os.listdir(SEED_XML_DIR)
seed_xml_names.sort()
cls_to_rotate = ['rider-mo', 'rider-bi']

for i in range (LOOP_TIMES):
    for xml_name in seed_xml_names:
        img_name = SEED_IMG_DIR + xml_name[:-3] + 'jpg'
        xml_name = SEED_XML_DIR + xml_name
       #print(img_name)
       #print(xml_name)
        
        tree=ET.parse(xml_name)
        img = cv2.imread(img_name)
        objs = get_obj_from_xml(xml_name)
        bboxes = get_bboxes_from_etree(tree)
        flag_found = False
        i = 0
        #------------------------------------------------------------
        bboxes_target = {}
        for obj_element in objs:
            bbox = get_bbox_from_xmlobj(obj_element)           
            img_obj = get_obj_from_image_file(img_name, bbox)

            cls = get_cls_from_xmlobj(obj_element)
            if (cls in cls_to_rotate):
                bboxes_target[(i)] = bbox
            i = i + 1
        id_dic = {}
        ##------------------------------------------------##
        target_keys = bboxes_target.keys()
        target_bboxes = bboxes_target.values()
        target_keys_list = list(target_keys)
        target_bboxes_list = list(target_bboxes)
        #print(target_keys_list)
        #print(target_bboxes_list)
        _i = 0
        for _bbx in target_bboxes_list:
            _i = _i + 1
            id_list = []
            #for __bbx in target_bboxes_list[_i:]: ##forward
            for __bbx in target_bboxes_list:
                if(_bbx == __bbx): ##the same id
                    continue
                if(IOU(_bbx, __bbx) > 0.1):
                    id_list.append(target_keys_list[target_bboxes_list.index(__bbx)])
            id_dic[(target_keys_list[_i-1])] = id_list
        #print('id_dic:{0}'.format(id_dic))
        for k__, v__ in id_dic.items():
            for v_ in v__:
                if(len(id_dic[v_]) == 0):
                    continue
                id_dic[k__] = id_dic[k__] + id_dic[v_]
                id_dic[k__] = list(set(id_dic[k__]))
                id_dic[k__].sort()
        #print('id_dic:{0}'.format(id_dic))

        '''
        for __k in list(id_dic.keys()):
            if(len(id_dic[__k]) == 0):
                id_dic.pop(__k)       
        #print('id_dic:{0}'.format(id_dic))
        '''
        
        v_list = []
        id_dic_refine = {}
        for __k, __v in id_dic.items():
            if(__k not in v_list):
                v_list = v_list + __v
                #print('k:{0};v_list:{1}'.format(__k, v_list))
                id_dic_refine[(__k)] = __v
                
        id_dic = id_dic_refine
       #print('id_dic:{0}'.format(id_dic))

        #continue;
        
        FLAG = False
        for i in range(REPEAT_TIMES):
            for kk, vv in id_dic.items():
                if(len(vv) == 0):
                    templist = [bboxes[kk]]
                    ##templist.append(bboxes[kk])
                    img_obj_shape = generate_union_bbox_shape(templist)
                    union_bbox = generate_union_bbox_(templist)
                    (xmin, ymin) = check_before_insert(img.shape[:2], img_obj_shape, tree, union_bbox)
                    if(xmin == False) or (ymin == False):
                       #print("give up, try next bbox")
                        continue
                    (diffx, diffy) = caculate_move_vector(union_bbox, (xmin, ymin))
                   #print(diffx)
                    new_left_top = (int(bboxes[kk][0] + diffx), int(bboxes[kk][2] + diffy))
                    img_obj = get_obj_from_image_file(img_name, bboxes[kk])
                    new_pil_img, new_xml_etree = past_and_insert(img_obj, img, new_left_top, objs[kk], tree)
                    if((new_pil_img == False) or (new_xml_etree == False)):
                        continue
                    tree = new_xml_etree
                    img = np.array(new_pil_img)
                    FLAG = True
                elif(len(vv) >= 1):
                    templist = [bboxes[v] for v in vv]
                    ##templist.append(bboxes[kk])
                    img_obj_shape = generate_union_bbox_shape(templist)
                    union_bbox = generate_union_bbox_(templist)
                    (xmin, ymin) = check_before_insert(img.shape[:2], img_obj_shape, tree, union_bbox)
                    if(xmin == False) or (ymin == False):
                       #print("give up, try next bbox")
                        continue
                    (diffx, diffy) = caculate_move_vector(union_bbox, (xmin, ymin))
                    for v in vv:
                        new_left_top = (int(bboxes[v][0] + diffx), int(bboxes[v][2] + diffy))
                        img_obj = get_obj_from_image_file(img_name, bboxes[v])
                        new_pil_img, new_xml_etree = past_and_insert(img_obj, img, new_left_top, objs[v], tree)
                        if((new_pil_img == False) or (new_xml_etree == False)):
                            continue
                        tree = new_xml_etree
                        img = np.array(new_pil_img)
                        FLAG = True
        ## save xml and img
        if(FLAG != True):
            continue
        time_mark = datetime.datetime.now()
        time_str = time_mark.strftime("%Y%m%d%H%M%S%f_")
        new_pil_img = Image.fromarray(img[:,:,(2,1,0)])
        new_pil_img.save(GENE_IMG_DIR + time_str + img_name.split('/')[-1])
        tree.write(GENE_XML_DIR + time_str + xml_name.split('/')[-1])
        
        
############################# for flip ##################################
SEED_XML_DIR = generated_xml_dir
SEED_IMG_DIR = generated_image_dir
GENE_IMG_DIR = generated_image_dir
GENE_XML_DIR = generated_xml_dir

seed_xml_names = os.listdir(SEED_XML_DIR)
seed_xml_names.sort()

print(len(seed_xml_names))
for xml_name in seed_xml_names:
        img_name = SEED_IMG_DIR + xml_name[:-3] + 'jpg'
        xml_name = SEED_XML_DIR + xml_name
       #print(img_name)
       #print(xml_name)
        
        tree=ET.parse(xml_name)
        new_tree = generate_etree(tree)
        img = cv2.imread(img_name)
       #print(img.shape)
        
        objs = get_obj_from_xml(xml_name)
        for obj_element in objs:
            bbox = get_bbox_from_xmlobj(obj_element)
            new_bbox = get_fliped_bbox(bbox, img.shape[1])
            #print(bbox)
            #print(new_bbox)
            new_obj_element = generate_new_xmlobj_simple(obj_element, new_bbox)
            new_tree = insert_to_xml(new_obj_element, new_tree)
        time_mark = datetime.datetime.now()
        time_str = time_mark.strftime("%Y%m%d%H%M%S%f_")
        #new_tree.write(GENE_XML_DIR + 'fliped_' + time_str + xml_name.split('/')[-1])
        new_tree.write(GENE_XML_DIR + 'fliped_'  + xml_name.split('/')[-1])
        h_flip = cv2.flip(img, 1)
        #cv2.imwrite(GENE_IMG_DIR + 'fliped_' + time_str + img_name.split('/')[-1], h_flip)
        cv2.imwrite(GENE_IMG_DIR + 'fliped_'  + img_name.split('/')[-1], h_flip)
        
        
        
############################# for crop flip ##################################        
SEED_XML_DIR = generated_xml_dir
SEED_IMG_DIR = generated_image_dir
GENE_IMG_DIR = generated_image_dir
GENE_XML_DIR = generated_xml_dir

seed_xml_names = os.listdir(SEED_XML_DIR)
seed_xml_names.sort()

croped_shape = [480, 640]
LOOPTIMES = 1
for L in range(LOOPTIMES):
    for xml_name in seed_xml_names:
        img_name = SEED_IMG_DIR + xml_name[:-3] + 'jpg'
        xml_name = SEED_XML_DIR + xml_name
        #print(img_name)
        #print(xml_name)

        etree=ET.parse(xml_name)
        img = cv2.imread(img_name)
        croped_shape = [int(img.shape[0]/1.5), int(img.shape[1]/2)]
        objs = get_obj_from_xml(xml_name)
        bboxes = get_bboxes_from_etree(tree)

        ## 0.generate new empty element tree
        new_etree = generate_etree(etree)
        root = new_etree.getroot()
        xml_obj_size = root.find('size')
        xml_obj_size.find('width').text = str(croped_shape[1])
        xml_obj_size.find('height').text = str(croped_shape[0])
        #new_etree.write('/data/test.xml')

        ## 1.generate crop box
        new_bbox = generate_new_bbox(img.shape[:2], croped_shape)
        img_obj = get_obj_from_image_file(img_name, new_bbox)
        (diffx, diffy) = caculate_move_vector(new_bbox, (0, 0))

        ## 2.find the obj that in crop box
        new_objs = []
        for obj_element in objs:
            bbox = get_bbox_from_xmlobj(obj_element)
            inter_bbox = get_intercouse_box(bbox, new_bbox)
            if(inter_bbox == False):
                continue            
            inter_bbox_trans = [int(inter_bbox[0] + diffx), int(inter_bbox[1] + diffx), 
                                int(inter_bbox[2] + diffy), int(inter_bbox[3] + diffy)]
            cls = get_cls_from_xmlobj(obj_element)
            new_xmlobj = generate_new_xmlobj(obj_element, (inter_bbox_trans[0], inter_bbox_trans[2]), 
                                (int(inter_bbox[3] - inter_bbox[2]), int(inter_bbox[1] - inter_bbox[0])))
            new_objs.append(new_xmlobj)
        if(len(new_objs) > 0):
            for i in new_objs:
                root.append(i)
        else:
            continue   

        ## save xml and img
        time_mark = datetime.datetime.now()
        time_str = time_mark.strftime("%Y%m%d%H%M%S%f_")
        cv2.imwrite(GENE_IMG_DIR + 'croped_' + img_name.split('/')[-1], img_obj)    
        new_etree.write(GENE_XML_DIR + 'croped_' + xml_name.split('/')[-1])

############################# for rescale ##################################              
SEED_XML_DIR = generated_xml_dir
SEED_IMG_DIR = generated_image_dir
GENE_IMG_DIR = generated_image_dir
GENE_XML_DIR = generated_xml_dir

seed_xml_names = os.listdir(SEED_XML_DIR)
seed_xml_names.sort()

for i in [0.3]:
    x_shrink_scale = i
    y_shrink_scale = 0
    padding = 127.5
    for xml in seed_xml_names:

        # generate new jpg image file
        img_file = xml[:-4] + '.jpg'
        img_path = SEED_IMG_DIR + img_file
       #print(img_path)
        img = cv2.imread(img_path)
        array = np.zeros_like(img)
        array.fill(padding)   
        new_w = int(img.shape[1]*(1-x_shrink_scale))
        new_h = int(img.shape[0]*(1-y_shrink_scale))
        shrink_width = img.shape[1] - new_w
        shrink_heigt = img.shape[0] - new_h
        #img = cv2.resize(img, (new_w, img.shape[0]))
        #array[:, int(shrink_width/2):int(shrink_width/2) + new_w] = img
        img = cv2.resize(img, (new_w, new_h))
        array[int(shrink_heigt/2):int(shrink_heigt/2) + new_h, int(shrink_width/2):int(shrink_width/2) + new_w] = img
        cv2.imwrite(GENE_IMG_DIR + "ge_shrink_scale_" + str(x_shrink_scale) + "_" + str(y_shrink_scale) + "_" + str(padding) + "_"+ img_file, array)

        # generate new anotation xml file    
        xml_path = SEED_XML_DIR + xml
        in_file = open(xml_path)
        tree=ET.parse(in_file)
        root = tree.getroot()

        for obj in root.iter('object'):
            '''
            difficult = obj.find('difficult').text
            cls_ = obj.find('name').text
            if cls_ not in classes_ or int(difficult)==1:
                continue
            '''
            xmlbox = obj.find('bndbox')
            xmin, xmax = int(xmlbox.find('xmin').text), int(xmlbox.find('xmax').text)
            ymin, ymax = int(xmlbox.find('ymin').text), int(xmlbox.find('ymax').text)
            xmlbox.find('xmin').text = str(int(xmin*(1-x_shrink_scale) + shrink_width/2))
            xmlbox.find('xmax').text = str(int(xmax*(1-x_shrink_scale) + shrink_width/2))
            xmlbox.find('ymin').text = str(int(ymin*(1-y_shrink_scale) + shrink_heigt/2))
            xmlbox.find('ymax').text = str(int(ymax*(1-y_shrink_scale) + shrink_heigt/2))
        tree.write(GENE_XML_DIR + "ge_shrink_scale_" + str(x_shrink_scale) + "_" + str(y_shrink_scale) +  "_" + str(padding) +"_" + xml)
        
for i in [0.3]:
    x_shrink_scale = 0
    y_shrink_scale = i
    padding = 127.5
    for xml in seed_xml_names:

        # generate new jpg image file
        img_file = xml[:-4] + '.jpg'
        img_path = SEED_IMG_DIR + img_file
        img = cv2.imread(img_path)
        array = np.zeros_like(img)
        array.fill(padding)   
        new_w = int(img.shape[1]*(1-x_shrink_scale))
        new_h = int(img.shape[0]*(1-y_shrink_scale))
        shrink_width = img.shape[1] - new_w
        shrink_heigt = img.shape[0] - new_h
        #img = cv2.resize(img, (new_w, img.shape[0]))
        #array[:, int(shrink_width/2):int(shrink_width/2) + new_w] = img
        img = cv2.resize(img, (new_w, new_h))
        array[int(shrink_heigt/2):int(shrink_heigt/2) + new_h, int(shrink_width/2):int(shrink_width/2) + new_w] = img
        cv2.imwrite(GENE_IMG_DIR + "ge_shrink_scale_" + str(x_shrink_scale) + "_" + str(y_shrink_scale) + "_" + str(padding) + "_"+ img_file, array)

        # generate new anotation xml file    
        xml_path = SEED_XML_DIR + xml
        in_file = open(xml_path)
        tree=ET.parse(in_file)
        root = tree.getroot()

        for obj in root.iter('object'):
            '''
            difficult = obj.find('difficult').text
            cls_ = obj.find('name').text
            if cls_ not in classes_ or int(difficult)==1:
                continue
            '''
            xmlbox = obj.find('bndbox')
            xmin, xmax = int(xmlbox.find('xmin').text), int(xmlbox.find('xmax').text)
            ymin, ymax = int(xmlbox.find('ymin').text), int(xmlbox.find('ymax').text)
            xmlbox.find('xmin').text = str(int(xmin*(1-x_shrink_scale) + shrink_width/2))
            xmlbox.find('xmax').text = str(int(xmax*(1-x_shrink_scale) + shrink_width/2))
            xmlbox.find('ymin').text = str(int(ymin*(1-y_shrink_scale) + shrink_heigt/2))
            xmlbox.find('ymax').text = str(int(ymax*(1-y_shrink_scale) + shrink_heigt/2))
        tree.write(GENE_XML_DIR + "ge_shrink_scale_" + str(x_shrink_scale) + "_" + str(y_shrink_scale) +  "_" + str(padding) +"_" + xml)
        
        
os.system('python3 /datasets/labelImg/labelImg.py &')

# %%
# Out:
# 574

# %%
# Out:
# /media/yyp/DATA/Public_Datasets/ZENITH_DATASETS/VOCdevkit_Rider/VOC2007//images/20190524105552432499_00003002000.jpg
# /media/yyp/DATA/Public_Datasets/ZENITH_DATASETS/VOCdevkit_Rider/VOC2007//images/20190524105552653946_00003002001.jpg
# /media/yyp/DATA/Public_Datasets/ZENITH_DATASETS/VOCdevkit_Rider/VOC2007//images/20190524105552891799_00003002002.jpg
# /media/yyp/DATA/Public_Datasets/ZENITH_DATASETS/VOCdevkit_Rider/VOC2007//images/20190524105553113187_00003002003.jpg
# /media/yyp/DATA/Public_Datasets/ZENITH_DATASETS/VOCdevkit_Rider/VOC2007//images/20190524105553333807_00003002004.jpg
# /media/yyp/DATA/Public_Datasets/ZENITH_DATASETS/VOCdevkit_Rider/VOC2007//images/20190524105553562756_00003002005.jpg
# /media/yyp/DATA/Public_Datasets/ZENITH_DATASETS/VOCdevkit_Rider/VOC2007//images/20190524105553795942_00003002006.jpg
# /media/yyp/DATA/Public_Datasets/ZENITH_DATASETS/VOCdevkit_Rider/VOC2007//images/20190524105554031740_00003002007.jpg
# /media/yyp/DATA/Public_Datasets/ZENITH_DATASETS/VOCdevkit_Rider/VOC2007//images/20190524105554253753_00003002008.jpg
# /media/yyp/DATA/Public_Datasets/ZENITH_DATASETS/VOCdevkit_Rider/VOC2007//images/20190524105554480116_00003002009.jpg
# /media/yyp/DATA/Public_Datasets/ZENITH_DATASETS/VOCdevkit_Rider/VOC2007//images/20190524105554704736_00003002010.jpg
# /media/yyp/DATA/Public_Datasets/ZENITH_DATASETS/VOCdevkit_Rider/VOC2007//images/20190524105554900615_00003002011.jpg
# /media/yyp/DATA/Public_Datasets/ZENITH_DATASETS/VOCdevkit_Rider/VOC2007//images/20190524105555088128_00003002012.jpg
# /media/yyp/DATA/Public_Datasets/ZENITH_DATASETS/VOCdevkit_Rider/VOC2007//images/20190524105555235245_00003002013.jpg
# /media/yyp/DATA/Public_Datasets/ZENITH_DATASETS/VOCdevkit_Rider/VOC2007//images/20190524105555378770_00003002014.jpg
# /media/yyp/DATA/Public_Datasets/ZENITH_DATASETS/VOCdevkit_Rider/VOC2007//images/20190524105555523191_00003002015.jpg
# /media/yyp/DATA/Public_Datasets/ZENITH_DATASETS/VOCdevkit_Rider/VOC2007//images/20190524105555743088_00003002016.jpg
# /media/yyp/DATA/Public_Datasets/ZENITH_DATASETS/VOCdevkit_Rider/VOC2007//images/20190524105555971289_00003002017.jpg
# /media/yyp/DATA/Public_Datasets/ZENITH_DATASETS/VOCdevkit_Rider/VOC2007//images/20190524105556208763_00003002018.jpg
# /media/yyp/DATA/Public_Datasets/ZENITH_DATASETS/VOCdevkit_Rider/VOC2007//images/20190524105556432260_00003002019.jpg
# /media/yyp/DATA/Public_Datasets/ZENITH_DATASETS/VOCdevkit_Rider/VOC2007//images/20190524105556650627_00003002020.jpg
# /media/yyp/DATA/Public_Datasets/ZENITH_DATASETS/VOCdevkit_Rider/VOC2007//images/20190524105556879176_00003002021.jpg
# /media/yyp/DATA/Public_Datasets/ZENITH_DATASETS/VOCdevkit_Rider/VOC2007//images/20190524105557120088_00003002022.jpg
# /media/yyp/DATA/Public_Datasets/ZENITH_DATASETS/VOCdevkit_Rider/VOC2007//images/20190524105557343010_00003002023.jpg
# /media/yyp/DATA/Public_Datasets/ZENITH_DATASETS/VOCdevkit_Rider/VOC2007//images/20190524105557580184_00003002024.jpg
# /media/yyp/DATA/Public_Datasets/ZENITH_DATASETS/VOCdevkit_Rider/VOC2007//images/20190524105557838424_00003002025.jpg
# /media/yyp/DATA/Public_Datasets/ZENITH_DATASETS/VOCdevkit_Rider/VOC2007//images/20190524105558101343_00003002026.jpg
# /media/yyp/DATA/Public_Datasets/ZENITH_DATASETS/VOCdevkit_Rider/VOC2007//images/20190524105558396752_00003002027.jpg
# /media/yyp/DATA/Public_Datasets/ZENITH_DATASETS/VOCdevkit_Rider/VOC2007//images/20190524105558697533_00003002028.jpg
# /media/yyp/DATA/Public_Datasets/ZENITH_DATASETS/VOCdevkit_Rider/VOC2007//images/20190524105559030656_00003002029.jpg
# /media/yyp/DATA/Public_Datasets/ZENITH_DATASETS/VOCdevkit_Rider/VOC2007//images/20190524105559364940_00003002030.jpg
# /media/yyp/DATA/Public_Datasets/ZENITH_DATASETS/VOCdevkit_Rider/VOC2007//images/20190524105559703692_00003002031.jpg
# /media/yyp/DATA/Public_Datasets/ZENITH_DATASETS/VOCdevkit_Rider/VOC2007//images/20190524105600078148_00003002032.jpg
# /media/yyp/DATA/Public_Datasets/ZENITH_DATASETS/VOCdevkit_Rider/VOC2007//images/20190524105600410838_00003002033.jpg
# /media/yyp/DATA/Public_Datasets/ZENITH_DATASETS/VOCdevkit_Rider/VOC2007//images/20190524105600721369_00003002034.jpg
# /media/yyp/DATA/Public_Datasets/ZENITH_DATASETS/VOCdevkit_Rider/VOC2007//images/20190524105601034806_00003002035.jpg
# /media/yyp/DATA/Public_Datasets/ZENITH_DATASETS/VOCdevkit_Rider/VOC2007//images/20190524105601346068_00003002036.jpg
# /media/yyp/DATA/Public_Datasets/ZENITH_DATASETS/VOCdevkit_Rider/VOC2007//images/20190524105601664125_00003002037.jpg
# /media/yyp/DATA/Public_Datasets/ZENITH_DATASETS/VOCdevkit_Rider/VOC2007//images/20190524105601966369_00003002038.jpg
# /media/yyp/DATA/Public_Datasets/ZENITH_DATASETS/VOCdevkit_Rider/VOC2007//images/20190524105602266141_00003002039.jpg
# /media/yyp/DATA/Public_Datasets/ZENITH_DATASETS/VOCdevkit_Rider/VOC2007//images/20190524105602605265_00003002040.jpg
# /media/yyp/DATA/Public_Datasets/ZENITH_DATASETS/VOCdevkit_Rider/VOC2007//images/20190524105602922201_00003002041.jpg
# /media/yyp/DATA/Public_Datasets/ZENITH_DATASETS/VOCdevkit_Rider/VOC2007//images/20190524105603223427_00003002042.jpg
# /media/yyp/DATA/Public_Datasets/ZENITH_DATASETS/VOCdevkit_Rider/VOC2007//images/20190524105603479192_00003002043.jpg
# /media/yyp/DATA/Public_Datasets/ZENITH_DATASETS/VOCdevkit_Rider/VOC2007//images/20190524105603734950_00003002044.jpg
# /media/yyp/DATA/Public_Datasets/ZENITH_DATASETS/VOCdevkit_Rider/VOC2007//images/20190524105603994037_00003002045.jpg
# /media/yyp/DATA/Public_Datasets/ZENITH_DATASETS/VOCdevkit_Rider/VOC2007//images/20190524105604256448_00003002046.jpg
# /media/yyp/DATA/Public_Datasets/ZENITH_DATASETS/VOCdevkit_Rider/VOC2007//images/20190524105604519484_00003002047.jpg
# /media/yyp/DATA/Public_Datasets/ZENITH_DATASETS/VOCdevkit_Rider/VOC2007//images/20190524105604742914_00003002048.jpg
# /media/yyp/DATA/Public_Datasets/ZENITH_DATASETS/VOCdevkit_Rider/VOC2007//images/20190524105605001189_00003002049.jpg
# /media/yyp/DATA/Public_Datasets/ZENITH_DATASETS/VOCdevkit_Rider/VOC2007//images/20190524105605261555_00003002050.jpg
# /media/yyp/DATA/Public_Datasets/ZENITH_DATASETS/VOCdevkit_Rider/VOC2007//images/20190524105605521603_00003002051.jpg
# /media/yyp/DATA/Public_Datasets/ZENITH_DATASETS/VOCdevkit_Rider/VOC2007//images/20190524105605784888_00003002052.jpg
# /media/yyp/DATA/Public_Datasets/ZENITH_DATASETS/VOCdevkit_Rider/VOC2007//images/20190524105606044218_00003002053.jpg
# /media/yyp/DATA/Public_Datasets/ZENITH_DATASETS/VOCdevkit_Rider/VOC2007//images/20190524105606303889_00003002054.jpg
# /media/yyp/DATA/Public_Datasets/ZENITH_DATASETS/VOCdevkit_Rider/VOC2007//images/20190524105606563126_00003002055.jpg
# /media/yyp/DATA/Public_Datasets/ZENITH_DATASETS/VOCdevkit_Rider/VOC2007//images/20190524105606827494_00003002056.jpg
# /media/yyp/DATA/Public_Datasets/ZENITH_DATASETS/VOCdevkit_Rider/VOC2007//images/20190524105607088644_00003002057.jpg
# /media/yyp/DATA/Public_Datasets/ZENITH_DATASETS/VOCdevkit_Rider/VOC2007//images/20190524105607350403_00003002058.jpg
# /media/yyp/DATA/Public_Datasets/ZENITH_DATASETS/VOCdevkit_Rider/VOC2007//images/20190524105607573254_00003002059.jpg
# /media/yyp/DATA/Public_Datasets/ZENITH_DATASETS/VOCdevkit_Rider/VOC2007//images/20190524105607832160_00003002060.jpg
# /media/yyp/DATA/Public_Datasets/ZENITH_DATASETS/VOCdevkit_Rider/VOC2007//images/20190524105608068232_00003002061.jpg
# /media/yyp/DATA/Public_Datasets/ZENITH_DATASETS/VOCdevkit_Rider/VOC2007//images/20190524105608303274_00003002062.jpg
# /media/yyp/DATA/Public_Datasets/ZENITH_DATASETS/VOCdevkit_Rider/VOC2007//images/20190524105608527558_00003002063.jpg
# /media/yyp/DATA/Public_Datasets/ZENITH_DATASETS/VOCdevkit_Rider/VOC2007//images/20190524105608748122_00003002064.jpg
# /media/yyp/DATA/Public_Datasets/ZENITH_DATASETS/VOCdevkit_Rider/VOC2007//images/20190524105609009497_00003002065.jpg
# /media/yyp/DATA/Public_Datasets/ZENITH_DATASETS/VOCdevkit_Rider/VOC2007//images/20190524105609251424_00003002066.jpg
# /media/yyp/DATA/Public_Datasets/ZENITH_DATASETS/VOCdevkit_Rider/VOC2007//images/20190524105609492469_00003002067.jpg
# /media/yyp/DATA/Public_Datasets/ZENITH_DATASETS/VOCdevkit_Rider/VOC2007//images/20190524105609719111_00003002068.jpg
# /media/yyp/DATA/Public_Datasets/ZENITH_DATASETS/VOCdevkit_Rider/VOC2007//images/20190524105609940686_00003002069.jpg
# /media/yyp/DATA/Public_Datasets/ZENITH_DATASETS/VOCdevkit_Rider/VOC2007//images/20190524105610163325_00003002070.jpg
# /media/yyp/DATA/Public_Datasets/ZENITH_DATASETS/VOCdevkit_Rider/VOC2007//images/20190524105610394282_00003002071.jpg
# /media/yyp/DATA/Public_Datasets/ZENITH_DATASETS/VOCdevkit_Rider/VOC2007//images/20190524105610625314_00003002072.jpg
# /media/yyp/DATA/Public_Datasets/ZENITH_DATASETS/VOCdevkit_Rider/VOC2007//images/20190524105610851686_00003002073.jpg
# /media/yyp/DATA/Public_Datasets/ZENITH_DATASETS/VOCdevkit_Rider/VOC2007//images/20190524105611075258_00003002074.jpg
# /media/yyp/DATA/Public_Datasets/ZENITH_DATASETS/VOCdevkit_Rider/VOC2007//images/20190524105611295700_00003002075.jpg
# /media/yyp/DATA/Public_Datasets/ZENITH_DATASETS/VOCdevkit_Rider/VOC2007//images/20190524105611518758_00003002076.jpg
# /media/yyp/DATA/Public_Datasets/ZENITH_DATASETS/VOCdevkit_Rider/VOC2007//images/20190524105611740868_00003002077.jpg
# /media/yyp/DATA/Public_Datasets/ZENITH_DATASETS/VOCdevkit_Rider/VOC2007//images/20190524105611961740_00003002078.jpg
# /media/yyp/DATA/Public_Datasets/ZENITH_DATASETS/VOCdevkit_Rider/VOC2007//images/20190524105612182461_00003002079.jpg
# /media/yyp/DATA/Public_Datasets/ZENITH_DATASETS/VOCdevkit_Rider/VOC2007//images/20190524105612418884_00003002080.jpg
# /media/yyp/DATA/Public_Datasets/ZENITH_DATASETS/VOCdevkit_Rider/VOC2007//images/20190524105612657717_00003002081.jpg
# /media/yyp/DATA/Public_Datasets/ZENITH_DATASETS/VOCdevkit_Rider/VOC2007//images/20190524105612894242_00003002082.jpg
# /media/yyp/DATA/Public_Datasets/ZENITH_DATASETS/VOCdevkit_Rider/VOC2007//images/20190524105613128840_00003002083.jpg
# /media/yyp/DATA/Public_Datasets/ZENITH_DATASETS/VOCdevkit_Rider/VOC2007//images/20190524105613363641_00003002084.jpg
# /media/yyp/DATA/Public_Datasets/ZENITH_DATASETS/VOCdevkit_Rider/VOC2007//images/20190524105613598199_00003002085.jpg
# /media/yyp/DATA/Public_Datasets/ZENITH_DATASETS/VOCdevkit_Rider/VOC2007//images/20190524105613831897_00003002086.jpg
# /media/yyp/DATA/Public_Datasets/ZENITH_DATASETS/VOCdevkit_Rider/VOC2007//images/20190524105614059887_00003002089.jpg
# /media/yyp/DATA/Public_Datasets/ZENITH_DATASETS/VOCdevkit_Rider/VOC2007//images/20190524105614239246_00003002090.jpg
# /media/yyp/DATA/Public_Datasets/ZENITH_DATASETS/VOCdevkit_Rider/VOC2007//images/20190524105614423119_00003002091.jpg
# /media/yyp/DATA/Public_Datasets/ZENITH_DATASETS/VOCdevkit_Rider/VOC2007//images/20190524105614591674_00003002092.jpg
# /media/yyp/DATA/Public_Datasets/ZENITH_DATASETS/VOCdevkit_Rider/VOC2007//images/20190524105614845869_00003002094.jpg
# /media/yyp/DATA/Public_Datasets/ZENITH_DATASETS/VOCdevkit_Rider/VOC2007//images/20190524105615012139_00003002095.jpg
# /media/yyp/DATA/Public_Datasets/ZENITH_DATASETS/VOCdevkit_Rider/VOC2007//images/20190524105615229706_00003002096.jpg
# /media/yyp/DATA/Public_Datasets/ZENITH_DATASETS/VOCdevkit_Rider/VOC2007//images/20190524105615446975_00003002097.jpg
# /media/yyp/DATA/Public_Datasets/ZENITH_DATASETS/VOCdevkit_Rider/VOC2007//images/20190524105615663131_00003002098.jpg
# /media/yyp/DATA/Public_Datasets/ZENITH_DATASETS/VOCdevkit_Rider/VOC2007//images/20190524105615880974_00003002104.jpg
# /media/yyp/DATA/Public_Datasets/ZENITH_DATASETS/VOCdevkit_Rider/VOC2007//images/20190524105616059419_00003002105.jpg
# /media/yyp/DATA/Public_Datasets/ZENITH_DATASETS/VOCdevkit_Rider/VOC2007//images/20190524105616239858_00003002107.jpg
# /media/yyp/DATA/Public_Datasets/ZENITH_DATASETS/VOCdevkit_Rider/VOC2007//images/20190524105616422136_00003002108.jpg
# /media/yyp/DATA/Public_Datasets/ZENITH_DATASETS/VOCdevkit_Rider/VOC2007//images/20190524105616640078_00003002110.jpg
# /media/yyp/DATA/Public_Datasets/ZENITH_DATASETS/VOCdevkit_Rider/VOC2007//images/20190524105616854500_00003002111.jpg
# /media/yyp/DATA/Public_Datasets/ZENITH_DATASETS/VOCdevkit_Rider/VOC2007//images/20190524105617114434_00003002117.jpg
# /media/yyp/DATA/Public_Datasets/ZENITH_DATASETS/VOCdevkit_Rider/VOC2007//images/20190524105617374594_00003002122.jpg
# /media/yyp/DATA/Public_Datasets/ZENITH_DATASETS/VOCdevkit_Rider/VOC2007//images/20190524105617660077_00003002123.jpg
# /media/yyp/DATA/Public_Datasets/ZENITH_DATASETS/VOCdevkit_Rider/VOC2007//images/20190524105617888791_00003002129.jpg
# /media/yyp/DATA/Public_Datasets/ZENITH_DATASETS/VOCdevkit_Rider/VOC2007//images/20190524105618105638_00003002130.jpg
# /media/yyp/DATA/Public_Datasets/ZENITH_DATASETS/VOCdevkit_Rider/VOC2007//images/20190524105618352426_00003002134.jpg
# /media/yyp/DATA/Public_Datasets/ZENITH_DATASETS/VOCdevkit_Rider/VOC2007//images/20190524105618599046_00003002137.jpg
# /media/yyp/DATA/Public_Datasets/ZENITH_DATASETS/VOCdevkit_Rider/VOC2007//images/20190524105618904142_00003002141.jpg
# /media/yyp/DATA/Public_Datasets/ZENITH_DATASETS/VOCdevkit_Rider/VOC2007//images/20190524105619186810_00003002146.jpg
# /media/yyp/DATA/Public_Datasets/ZENITH_DATASETS/VOCdevkit_Rider/VOC2007//images/20190524105619441444_00003002149.jpg
# /media/yyp/DATA/Public_Datasets/ZENITH_DATASETS/VOCdevkit_Rider/VOC2007//images/20190524105619696669_00003002153.jpg
# /media/yyp/DATA/Public_Datasets/ZENITH_DATASETS/VOCdevkit_Rider/VOC2007//images/20190524105619978503_00003002171.jpg
# /media/yyp/DATA/Public_Datasets/ZENITH_DATASETS/VOCdevkit_Rider/VOC2007//images/20190524105620255278_00003002176.jpg
# /media/yyp/DATA/Public_Datasets/ZENITH_DATASETS/VOCdevkit_Rider/VOC2007//images/20190524105620577148_00003002212.jpg
# /media/yyp/DATA/Public_Datasets/ZENITH_DATASETS/VOCdevkit_Rider/VOC2007//images/20190524105620914552_00003002221.jpg
# /media/yyp/DATA/Public_Datasets/ZENITH_DATASETS/VOCdevkit_Rider/VOC2007//images/20190524105621235374_00003002251.jpg
# /media/yyp/DATA/Public_Datasets/ZENITH_DATASETS/VOCdevkit_Rider/VOC2007//images/20190524105621553434_00003002252.jpg
# /media/yyp/DATA/Public_Datasets/ZENITH_DATASETS/VOCdevkit_Rider/VOC2007//images/20190524105621847230_00003002257.jpg
# /media/yyp/DATA/Public_Datasets/ZENITH_DATASETS/VOCdevkit_Rider/VOC2007//images/20190524105622141531_00003002262.jpg
# /media/yyp/DATA/Public_Datasets/ZENITH_DATASETS/VOCdevkit_Rider/VOC2007//images/20190524105622546334_00003002269.jpg
# /media/yyp/DATA/Public_Datasets/ZENITH_DATASETS/VOCdevkit_Rider/VOC2007//images/20190524105622963858_00003002277.jpg
# /media/yyp/DATA/Public_Datasets/ZENITH_DATASETS/VOCdevkit_Rider/VOC2007//images/20190524105623358516_00003002282.jpg
# /media/yyp/DATA/Public_Datasets/ZENITH_DATASETS/VOCdevkit_Rider/VOC2007//images/20190524105623725937_00003002284.jpg
# /media/yyp/DATA/Public_Datasets/ZENITH_DATASETS/VOCdevkit_Rider/VOC2007//images/20190524105624105121_00003002351.jpg
# /media/yyp/DATA/Public_Datasets/ZENITH_DATASETS/VOCdevkit_Rider/VOC2007//images/20190524105624515391_00003002354.jpg
# /media/yyp/DATA/Public_Datasets/ZENITH_DATASETS/VOCdevkit_Rider/VOC2007//images/20190524105624885404_00003002367.jpg
# /media/yyp/DATA/Public_Datasets/ZENITH_DATASETS/VOCdevkit_Rider/VOC2007//images/20190524105625236521_00003002387.jpg
# /media/yyp/DATA/Public_Datasets/ZENITH_DATASETS/VOCdevkit_Rider/VOC2007//images/20190524105625635974_00003002388.jpg
# /media/yyp/DATA/Public_Datasets/ZENITH_DATASETS/VOCdevkit_Rider/VOC2007//images/20190524105626026991_00003002389.jpg
# /media/yyp/DATA/Public_Datasets/ZENITH_DATASETS/VOCdevkit_Rider/VOC2007//images/20190524105626408569_00003002390.jpg
# /media/yyp/DATA/Public_Datasets/ZENITH_DATASETS/VOCdevkit_Rider/VOC2007//images/20190524105626829301_00003002391.jpg
# /media/yyp/DATA/Public_Datasets/ZENITH_DATASETS/VOCdevkit_Rider/VOC2007//images/20190524105627288602_00003002392.jpg
# /media/yyp/DATA/Public_Datasets/ZENITH_DATASETS/VOCdevkit_Rider/VOC2007//images/20190524105627760153_00003002393.jpg
# /media/yyp/DATA/Public_Datasets/ZENITH_DATASETS/VOCdevkit_Rider/VOC2007//images/20190524105628181088_00003002394.jpg
# /media/yyp/DATA/Public_Datasets/ZENITH_DATASETS/VOCdevkit_Rider/VOC2007//images/20190524105628647057_00003002395.jpg
# /media/yyp/DATA/Public_Datasets/ZENITH_DATASETS/VOCdevkit_Rider/VOC2007//images/20190524105629066160_00003002396.jpg
# /media/yyp/DATA/Public_Datasets/ZENITH_DATASETS/VOCdevkit_Rider/VOC2007//images/20190524105629553768_00003002397.jpg
# /media/yyp/DATA/Public_Datasets/ZENITH_DATASETS/VOCdevkit_Rider/VOC2007//images/20190524105630042165_00003002398.jpg
# /media/yyp/DATA/Public_Datasets/ZENITH_DATASETS/VOCdevkit_Rider/VOC2007//images/20190524105630578332_00003002399.jpg
# /media/yyp/DATA/Public_Datasets/ZENITH_DATASETS/VOCdevkit_Rider/VOC2007//images/20190524105631114615_00003002408.jpg
# /media/yyp/DATA/Public_Datasets/ZENITH_DATASETS/VOCdevkit_Rider/VOC2007//images/20190524105631625972_00003002409.jpg
# /media/yyp/DATA/Public_Datasets/ZENITH_DATASETS/VOCdevkit_Rider/VOC2007//images/20190524105632192553_00003002414.jpg
# /media/yyp/DATA/Public_Datasets/ZENITH_DATASETS/VOCdevkit_Rider/VOC2007//images/20190524105632617142_00003002427.jpg
# /media/yyp/DATA/Public_Datasets/ZENITH_DATASETS/VOCdevkit_Rider/VOC2007//images/20190524105632951943_00003002430.jpg
# /media/yyp/DATA/Public_Datasets/ZENITH_DATASETS/VOCdevkit_Rider/VOC2007//images/20190524105633174846_00003002438.jpg
# /media/yyp/DATA/Public_Datasets/ZENITH_DATASETS/VOCdevkit_Rider/VOC2007//images/20190524105633476169_00003002449.jpg
# /media/yyp/DATA/Public_Datasets/ZENITH_DATASETS/VOCdevkit_Rider/VOC2007//images/20190524105634071673_00003002486.jpg
# /media/yyp/DATA/Public_Datasets/ZENITH_DATASETS/VOCdevkit_Rider/VOC2007//images/20190524105634584161_00003002499.jpg
# /media/yyp/DATA/Public_Datasets/ZENITH_DATASETS/VOCdevkit_Rider/VOC2007//images/20190524105635099369_00003002502.jpg
# /media/yyp/DATA/Public_Datasets/ZENITH_DATASETS/VOCdevkit_Rider/VOC2007//images/20190524105635658960_00003002530.jpg
# /media/yyp/DATA/Public_Datasets/ZENITH_DATASETS/VOCdevkit_Rider/VOC2007//images/20190524105636113026_00003002543.jpg
# /media/yyp/DATA/Public_Datasets/ZENITH_DATASETS/VOCdevkit_Rider/VOC2007//images/20190524105636353971_00003006002.jpg
# /media/yyp/DATA/Public_Datasets/ZENITH_DATASETS/VOCdevkit_Rider/VOC2007//images/20190524105636602723_00003006010.jpg
# /media/yyp/DATA/Public_Datasets/ZENITH_DATASETS/VOCdevkit_Rider/VOC2007//images/20190524105636835174_00003006018.jpg
# /media/yyp/DATA/Public_Datasets/ZENITH_DATASETS/VOCdevkit_Rider/VOC2007//images/20190524105637032679_00003006023.jpg
# /media/yyp/DATA/Public_Datasets/ZENITH_DATASETS/VOCdevkit_Rider/VOC2007//images/20190524105637213542_00003006024.jpg
# /media/yyp/DATA/Public_Datasets/ZENITH_DATASETS/VOCdevkit_Rider/VOC2007//images/20190524105637499590_00003006025.jpg
# /media/yyp/DATA/Public_Datasets/ZENITH_DATASETS/VOCdevkit_Rider/VOC2007//images/20190524105637779500_00003006026.jpg
# /media/yyp/DATA/Public_Datasets/ZENITH_DATASETS/VOCdevkit_Rider/VOC2007//images/20190524105638041862_00003006030.jpg
# /media/yyp/DATA/Public_Datasets/ZENITH_DATASETS/VOCdevkit_Rider/VOC2007//images/20190524105638263870_00003006033.jpg
# /media/yyp/DATA/Public_Datasets/ZENITH_DATASETS/VOCdevkit_Rider/VOC2007//images/20190524105638451046_00003006035.jpg
# /media/yyp/DATA/Public_Datasets/ZENITH_DATASETS/VOCdevkit_Rider/VOC2007//images/20190524105638686456_00003006038.jpg
# /media/yyp/DATA/Public_Datasets/ZENITH_DATASETS/VOCdevkit_Rider/VOC2007//images/20190524105638940159_00003006041.jpg
# /media/yyp/DATA/Public_Datasets/ZENITH_DATASETS/VOCdevkit_Rider/VOC2007//images/20190524105639242293_00003006046.jpg
# /media/yyp/DATA/Public_Datasets/ZENITH_DATASETS/VOCdevkit_Rider/VOC2007//images/20190524105639513877_00003006047.jpg
# /media/yyp/DATA/Public_Datasets/ZENITH_DATASETS/VOCdevkit_Rider/VOC2007//images/20190524105639832467_00003006051.jpg
# /media/yyp/DATA/Public_Datasets/ZENITH_DATASETS/VOCdevkit_Rider/VOC2007//images/20190524105640061540_00003006053.jpg
# /media/yyp/DATA/Public_Datasets/ZENITH_DATASETS/VOCdevkit_Rider/VOC2007//images/20190524105640288718_00003006055.jpg
# /media/yyp/DATA/Public_Datasets/ZENITH_DATASETS/VOCdevkit_Rider/VOC2007//images/20190524105640597726_00003006059.jpg
# /media/yyp/DATA/Public_Datasets/ZENITH_DATASETS/VOCdevkit_Rider/VOC2007//images/20190524105640843522_00003006061.jpg
# /media/yyp/DATA/Public_Datasets/ZENITH_DATASETS/VOCdevkit_Rider/VOC2007//images/20190524105641073575_00003006064.jpg
# /media/yyp/DATA/Public_Datasets/ZENITH_DATASETS/VOCdevkit_Rider/VOC2007//images/20190524105641297814_00003006065.jpg
# /media/yyp/DATA/Public_Datasets/ZENITH_DATASETS/VOCdevkit_Rider/VOC2007//images/20190524105641521911_00003006066.jpg
# /media/yyp/DATA/Public_Datasets/ZENITH_DATASETS/VOCdevkit_Rider/VOC2007//images/20190524105641821574_00003006074.jpg
# /media/yyp/DATA/Public_Datasets/ZENITH_DATASETS/VOCdevkit_Rider/VOC2007//images/20190524105642160964_00003006081.jpg
# /media/yyp/DATA/Public_Datasets/ZENITH_DATASETS/VOCdevkit_Rider/VOC2007//images/20190524105642474713_00003006083.jpg
# /media/yyp/DATA/Public_Datasets/ZENITH_DATASETS/VOCdevkit_Rider/VOC2007//images/20190524105642779786_00003006084.jpg
# /media/yyp/DATA/Public_Datasets/ZENITH_DATASETS/VOCdevkit_Rider/VOC2007//images/20190524105643067520_00003006091.jpg
# /media/yyp/DATA/Public_Datasets/ZENITH_DATASETS/VOCdevkit_Rider/VOC2007//images/20190524105643425287_00003006112.jpg
# /media/yyp/DATA/Public_Datasets/ZENITH_DATASETS/VOCdevkit_Rider/VOC2007//images/20190524105643781680_00003006114.jpg
# /media/yyp/DATA/Public_Datasets/ZENITH_DATASETS/VOCdevkit_Rider/VOC2007//images/20190524105644144208_00003006117.jpg
# /media/yyp/DATA/Public_Datasets/ZENITH_DATASETS/VOCdevkit_Rider/VOC2007//images/20190524105644428448_00003006124.jpg
# /media/yyp/DATA/Public_Datasets/ZENITH_DATASETS/VOCdevkit_Rider/VOC2007//images/20190524105644746715_00003006129.jpg
# /media/yyp/DATA/Public_Datasets/ZENITH_DATASETS/VOCdevkit_Rider/VOC2007//images/20190524105644966377_00003006140.jpg
# /media/yyp/DATA/Public_Datasets/ZENITH_DATASETS/VOCdevkit_Rider/VOC2007//images/20190524105645186765_00003006143.jpg
# /media/yyp/DATA/Public_Datasets/ZENITH_DATASETS/VOCdevkit_Rider/VOC2007//images/20190524105645386387_00003006144.jpg
# /media/yyp/DATA/Public_Datasets/ZENITH_DATASETS/VOCdevkit_Rider/VOC2007//images/20190524105645574464_00003006145.jpg
# /media/yyp/DATA/Public_Datasets/ZENITH_DATASETS/VOCdevkit_Rider/VOC2007//images/20190524105645765723_00003006146.jpg
# /media/yyp/DATA/Public_Datasets/ZENITH_DATASETS/VOCdevkit_Rider/VOC2007//images/20190524105645951453_00003006149.jpg
# /media/yyp/DATA/Public_Datasets/ZENITH_DATASETS/VOCdevkit_Rider/VOC2007//images/20190524105646205328_00003006164.jpg
# /media/yyp/DATA/Public_Datasets/ZENITH_DATASETS/VOCdevkit_Rider/VOC2007//images/20190524105646475199_00003006170.jpg
# /media/yyp/DATA/Public_Datasets/ZENITH_DATASETS/VOCdevkit_Rider/VOC2007//images/20190524105646702108_00003006173.jpg
# /media/yyp/DATA/Public_Datasets/ZENITH_DATASETS/VOCdevkit_Rider/VOC2007//images/20190524105646928669_00003006174.jpg
# /media/yyp/DATA/Public_Datasets/ZENITH_DATASETS/VOCdevkit_Rider/VOC2007//images/20190524105647159646_00003006176.jpg
# /media/yyp/DATA/Public_Datasets/ZENITH_DATASETS/VOCdevkit_Rider/VOC2007//images/20190524105647384200_00003006181.jpg
# /media/yyp/DATA/Public_Datasets/ZENITH_DATASETS/VOCdevkit_Rider/VOC2007//images/20190524105647609312_00003006183.jpg
# /media/yyp/DATA/Public_Datasets/ZENITH_DATASETS/VOCdevkit_Rider/VOC2007//images/20190524105647848390_00003006189.jpg
# /media/yyp/DATA/Public_Datasets/ZENITH_DATASETS/VOCdevkit_Rider/VOC2007//images/20190524105648045760_00003006195.jpg
# /media/yyp/DATA/Public_Datasets/ZENITH_DATASETS/VOCdevkit_Rider/VOC2007//images/20190524105648266778_00003006196.jpg
# /media/yyp/DATA/Public_Datasets/ZENITH_DATASETS/VOCdevkit_Rider/VOC2007//images/20190524105648490670_00003006204.jpg
# /media/yyp/DATA/Public_Datasets/ZENITH_DATASETS/VOCdevkit_Rider/VOC2007//images/20190524105648673628_00003006205.jpg
# /media/yyp/DATA/Public_Datasets/ZENITH_DATASETS/VOCdevkit_Rider/VOC2007//images/20190524105648876438_00003007000.jpg
# /media/yyp/DATA/Public_Datasets/ZENITH_DATASETS/VOCdevkit_Rider/VOC2007//images/20190524105649123348_00003007001.jpg
# /media/yyp/DATA/Public_Datasets/ZENITH_DATASETS/VOCdevkit_Rider/VOC2007//images/20190524105649371842_00003007002.jpg
# /media/yyp/DATA/Public_Datasets/ZENITH_DATASETS/VOCdevkit_Rider/VOC2007//images/20190524105649631710_00003007005.jpg
# /media/yyp/DATA/Public_Datasets/ZENITH_DATASETS/VOCdevkit_Rider/VOC2007//images/20190524105649872766_00003007008.jpg
# /media/yyp/DATA/Public_Datasets/ZENITH_DATASETS/VOCdevkit_Rider/VOC2007//images/20190524105650082965_00003007014.jpg
# /media/yyp/DATA/Public_Datasets/ZENITH_DATASETS/VOCdevkit_Rider/VOC2007//images/20190524105650349664_00003007015.jpg
# /media/yyp/DATA/Public_Datasets/ZENITH_DATASETS/VOCdevkit_Rider/VOC2007//images/20190524105650665413_00003007023.jpg
# /media/yyp/DATA/Public_Datasets/ZENITH_DATASETS/VOCdevkit_Rider/VOC2007//images/20190524105650949692_00003007033.jpg
# /media/yyp/DATA/Public_Datasets/ZENITH_DATASETS/VOCdevkit_Rider/VOC2007//images/20190524105651264399_00003007039.jpg
# /media/yyp/DATA/Public_Datasets/ZENITH_DATASETS/VOCdevkit_Rider/VOC2007//images/20190524105651467854_00003007044.jpg
# /media/yyp/DATA/Public_Datasets/ZENITH_DATASETS/VOCdevkit_Rider/VOC2007//images/20190524105651762918_00003007045.jpg
# /media/yyp/DATA/Public_Datasets/ZENITH_DATASETS/VOCdevkit_Rider/VOC2007//images/20190524105652019934_00003007049.jpg
# /media/yyp/DATA/Public_Datasets/ZENITH_DATASETS/VOCdevkit_Rider/VOC2007//images/20190524105652277006_00003007051.jpg
# /media/yyp/DATA/Public_Datasets/ZENITH_DATASETS/VOCdevkit_Rider/VOC2007//images/20190524105652534269_00003007053.jpg
# /media/yyp/DATA/Public_Datasets/ZENITH_DATASETS/VOCdevkit_Rider/VOC2007//images/20190524105652798206_00003007054.jpg
# /media/yyp/DATA/Public_Datasets/ZENITH_DATASETS/VOCdevkit_Rider/VOC2007//images/20190524105653113550_00003007055.jpg
# /media/yyp/DATA/Public_Datasets/ZENITH_DATASETS/VOCdevkit_Rider/VOC2007//images/20190524105653437681_00003007059.jpg
# /media/yyp/DATA/Public_Datasets/ZENITH_DATASETS/VOCdevkit_Rider/VOC2007//images/20190524105653829982_00003007063.jpg
# /media/yyp/DATA/Public_Datasets/ZENITH_DATASETS/VOCdevkit_Rider/VOC2007//images/20190524105654107528_00003007073.jpg
# /media/yyp/DATA/Public_Datasets/ZENITH_DATASETS/VOCdevkit_Rider/VOC2007//images/20190524105654477689_00003007078.jpg
# /media/yyp/DATA/Public_Datasets/ZENITH_DATASETS/VOCdevkit_Rider/VOC2007//images/20190524105654788240_00003007103.jpg
# /media/yyp/DATA/Public_Datasets/ZENITH_DATASETS/VOCdevkit_Rider/VOC2007//images/20190524105655132723_00003007107.jpg
# /media/yyp/DATA/Public_Datasets/ZENITH_DATASETS/VOCdevkit_Rider/VOC2007//images/20190524105655501306_00003007118.jpg
# /media/yyp/DATA/Public_Datasets/ZENITH_DATASETS/VOCdevkit_Rider/VOC2007//images/20190524105655916009_00003007119.jpg
# /media/yyp/DATA/Public_Datasets/ZENITH_DATASETS/VOCdevkit_Rider/VOC2007//images/20190524105656346178_00003007122.jpg
# /media/yyp/DATA/Public_Datasets/ZENITH_DATASETS/VOCdevkit_Rider/VOC2007//images/20190524105656801975_00003007128.jpg
# /media/yyp/DATA/Public_Datasets/ZENITH_DATASETS/VOCdevkit_Rider/VOC2007//images/20190524105657211908_00003007134.jpg
# /media/yyp/DATA/Public_Datasets/ZENITH_DATASETS/VOCdevkit_Rider/VOC2007//images/20190524105657654973_00003007138.jpg
# /media/yyp/DATA/Public_Datasets/ZENITH_DATASETS/VOCdevkit_Rider/VOC2007//images/20190524105658031449_00003007153.jpg
# /media/yyp/DATA/Public_Datasets/ZENITH_DATASETS/VOCdevkit_Rider/VOC2007//images/20190524105658272181_00003007174.jpg
# /media/yyp/DATA/Public_Datasets/ZENITH_DATASETS/VOCdevkit_Rider/VOC2007//images/20190524105658477409_00003008000.jpg
# /media/yyp/DATA/Public_Datasets/ZENITH_DATASETS/VOCdevkit_Rider/VOC2007//images/20190524105658715638_00003008001.jpg
# /media/yyp/DATA/Public_Datasets/ZENITH_DATASETS/VOCdevkit_Rider/VOC2007//images/20190524105659398679_00003020300.jpg
# /media/yyp/DATA/Public_Datasets/ZENITH_DATASETS/VOCdevkit_Rider/VOC2007//images/20190524105703036696_00003020329.jpg
# /media/yyp/DATA/Public_Datasets/ZENITH_DATASETS/VOCdevkit_Rider/VOC2007//images/20190524105704105659_00003020344.jpg
# /media/yyp/DATA/Public_Datasets/ZENITH_DATASETS/VOCdevkit_Rider/VOC2007//images/20190524105705823210_00003020394.jpg
# /media/yyp/DATA/Public_Datasets/ZENITH_DATASETS/VOCdevkit_Rider/VOC2007//images/20190524105706652437_00003020427.jpg
# /media/yyp/DATA/Public_Datasets/ZENITH_DATASETS/VOCdevkit_Rider/VOC2007//images/20190524105707844658_00003020521.jpg
# /media/yyp/DATA/Public_Datasets/ZENITH_DATASETS/VOCdevkit_Rider/VOC2007//images/20190524105708598068_00003020591.jpg
# /media/yyp/DATA/Public_Datasets/ZENITH_DATASETS/VOCdevkit_Rider/VOC2007//images/20190524105709657918_00003020599.jpg
# /media/yyp/DATA/Public_Datasets/ZENITH_DATASETS/VOCdevkit_Rider/VOC2007//images/20190524105710546278_00003020600.jpg
# /media/yyp/DATA/Public_Datasets/ZENITH_DATASETS/VOCdevkit_Rider/VOC2007//images/20190524105711394064_00003020603.jpg
# /media/yyp/DATA/Public_Datasets/ZENITH_DATASETS/VOCdevkit_Rider/VOC2007//images/20190524105712221826_00003020621.jpg
# /media/yyp/DATA/Public_Datasets/ZENITH_DATASETS/VOCdevkit_Rider/VOC2007//images/20190524105713011758_00003020624.jpg
# /media/yyp/DATA/Public_Datasets/ZENITH_DATASETS/VOCdevkit_Rider/VOC2007//images/20190524105713792486_00003020644.jpg
# /media/yyp/DATA/Public_Datasets/ZENITH_DATASETS/VOCdevkit_Rider/VOC2007//images/20190524105714477257_00003020649.jpg
# /media/yyp/DATA/Public_Datasets/ZENITH_DATASETS/VOCdevkit_Rider/VOC2007//images/20190524105715205143_00003020654.jpg
# /media/yyp/DATA/Public_Datasets/ZENITH_DATASETS/VOCdevkit_Rider/VOC2007//images/20190524105715962709_00003020659.jpg
# /media/yyp/DATA/Public_Datasets/ZENITH_DATASETS/VOCdevkit_Rider/VOC2007//images/20190524105716703863_00003020663.jpg
# /media/yyp/DATA/Public_Datasets/ZENITH_DATASETS/VOCdevkit_Rider/VOC2007//images/20190524105717457980_00003020666.jpg
# /media/yyp/DATA/Public_Datasets/ZENITH_DATASETS/VOCdevkit_Rider/VOC2007//images/20190524105718180823_00003020671.jpg
# /media/yyp/DATA/Public_Datasets/ZENITH_DATASETS/VOCdevkit_Rider/VOC2007//images/20190524105718983377_00003020673.jpg
# /media/yyp/DATA/Public_Datasets/ZENITH_DATASETS/VOCdevkit_Rider/VOC2007//images/20190524105719773359_00003020679.jpg
# /media/yyp/DATA/Public_Datasets/ZENITH_DATASETS/VOCdevkit_Rider/VOC2007//images/20190524105720729973_00003020702.jpg
# /media/yyp/DATA/Public_Datasets/ZENITH_DATASETS/VOCdevkit_Rider/VOC2007//images/20190524105721647753_00003020710.jpg
# /media/yyp/DATA/Public_Datasets/ZENITH_DATASETS/VOCdevkit_Rider/VOC2007//images/20190524105722500836_00003020738.jpg
# /media/yyp/DATA/Public_Datasets/ZENITH_DATASETS/VOCdevkit_Rider/VOC2007//images/20190524105723273767_00003020741.jpg
# /media/yyp/DATA/Public_Datasets/ZENITH_DATASETS/VOCdevkit_Rider/VOC2007//images/20190524105723576547_00003020900.jpg
# /media/yyp/DATA/Public_Datasets/ZENITH_DATASETS/VOCdevkit_Rider/VOC2007//images/20190524105723833088_00003020902.jpg
# /media/yyp/DATA/Public_Datasets/ZENITH_DATASETS/VOCdevkit_Rider/VOC2007//images/20190524105724102296_00003020914.jpg
# /media/yyp/DATA/Public_Datasets/ZENITH_DATASETS/VOCdevkit_Rider/VOC2007//images/20190524105724352906_00003020920.jpg
# /media/yyp/DATA/Public_Datasets/ZENITH_DATASETS/VOCdevkit_Rider/VOC2007//images/20190524105724583654_00003020930.jpg
# /media/yyp/DATA/Public_Datasets/ZENITH_DATASETS/VOCdevkit_Rider/VOC2007//images/20190524105724829743_00003020940.jpg
# /media/yyp/DATA/Public_Datasets/ZENITH_DATASETS/VOCdevkit_Rider/VOC2007//images/20190524105725116035_00003020942.jpg
# /media/yyp/DATA/Public_Datasets/ZENITH_DATASETS/VOCdevkit_Rider/VOC2007//images/20190524105725345036_00003020956.jpg
# /media/yyp/DATA/Public_Datasets/ZENITH_DATASETS/VOCdevkit_Rider/VOC2007//images/20190524105725595821_00003020960.jpg
# /media/yyp/DATA/Public_Datasets/ZENITH_DATASETS/VOCdevkit_Rider/VOC2007//images/20190524105725794243_00003020970.jpg
# /media/yyp/DATA/Public_Datasets/ZENITH_DATASETS/VOCdevkit_Rider/VOC2007//images/20190524105725993016_00003020974.jpg
# /media/yyp/DATA/Public_Datasets/ZENITH_DATASETS/VOCdevkit_Rider/VOC2007//images/20190524105726187555_00003020978.jpg
# /media/yyp/DATA/Public_Datasets/ZENITH_DATASETS/VOCdevkit_Rider/VOC2007//images/20190524105726356730_00003020982.jpg
# /media/yyp/DATA/Public_Datasets/ZENITH_DATASETS/VOCdevkit_Rider/VOC2007//images/20190524105726618172_00003020988.jpg
# /media/yyp/DATA/Public_Datasets/ZENITH_DATASETS/VOCdevkit_Rider/VOC2007//images/20190524105726808401_00003020994.jpg
# /media/yyp/DATA/Public_Datasets/ZENITH_DATASETS/VOCdevkit_Rider/VOC2007//images/20190524105727014421_00003020996.jpg
# /media/yyp/DATA/Public_Datasets/ZENITH_DATASETS/VOCdevkit_Rider/VOC2007//images/20190524105727205966_00003021006.jpg
# /media/yyp/DATA/Public_Datasets/ZENITH_DATASETS/VOCdevkit_Rider/VOC2007//images/20190524105727437905_00003021008.jpg
# /media/yyp/DATA/Public_Datasets/ZENITH_DATASETS/VOCdevkit_Rider/VOC2007//images/20190524105727623408_00003021014.jpg
# /media/yyp/DATA/Public_Datasets/ZENITH_DATASETS/VOCdevkit_Rider/VOC2007//images/20190524105727780232_00003021016.jpg
# /media/yyp/DATA/Public_Datasets/ZENITH_DATASETS/VOCdevkit_Rider/VOC2007//images/20190524105727894542_00003021020.jpg
# /media/yyp/DATA/Public_Datasets/ZENITH_DATASETS/VOCdevkit_Rider/VOC2007//images/20190524105728135515_00003021036.jpg
# /media/yyp/DATA/Public_Datasets/ZENITH_DATASETS/VOCdevkit_Rider/VOC2007//images/20190524105728381323_00003021040.jpg
# /media/yyp/DATA/Public_Datasets/ZENITH_DATASETS/VOCdevkit_Rider/VOC2007//images/20190524105728640208_00003021042.jpg
# /media/yyp/DATA/Public_Datasets/ZENITH_DATASETS/VOCdevkit_Rider/VOC2007//images/20190524105728827107_00003021046.jpg
# /media/yyp/DATA/Public_Datasets/ZENITH_DATASETS/VOCdevkit_Rider/VOC2007//images/20190524105729044794_00003021048.jpg
# /media/yyp/DATA/Public_Datasets/ZENITH_DATASETS/VOCdevkit_Rider/VOC2007//images/20190524111457781906_20190524105552432499_00003002000.jpg
# /media/yyp/DATA/Public_Datasets/ZENITH_DATASETS/VOCdevkit_Rider/VOC2007//images/20190524111457821074_20190524105552653946_00003002001.jpg
# /media/yyp/DATA/Public_Datasets/ZENITH_DATASETS/VOCdevkit_Rider/VOC2007//images/20190524111457855243_20190524105552891799_00003002002.jpg
# /media/yyp/DATA/Public_Datasets/ZENITH_DATASETS/VOCdevkit_Rider/VOC2007//images/20190524111457889498_20190524105553113187_00003002003.jpg
# /media/yyp/DATA/Public_Datasets/ZENITH_DATASETS/VOCdevkit_Rider/VOC2007//images/20190524111457922476_20190524105553333807_00003002004.jpg
# /media/yyp/DATA/Public_Datasets/ZENITH_DATASETS/VOCdevkit_Rider/VOC2007//images/20190524111457955701_20190524105553562756_00003002005.jpg
# /media/yyp/DATA/Public_Datasets/ZENITH_DATASETS/VOCdevkit_Rider/VOC2007//images/20190524111457991392_20190524105553795942_00003002006.jpg
# /media/yyp/DATA/Public_Datasets/ZENITH_DATASETS/VOCdevkit_Rider/VOC2007//images/20190524111458026041_20190524105554031740_00003002007.jpg
# /media/yyp/DATA/Public_Datasets/ZENITH_DATASETS/VOCdevkit_Rider/VOC2007//images/20190524111458058942_20190524105554253753_00003002008.jpg
# /media/yyp/DATA/Public_Datasets/ZENITH_DATASETS/VOCdevkit_Rider/VOC2007//images/20190524111458093293_20190524105554480116_00003002009.jpg
# /media/yyp/DATA/Public_Datasets/ZENITH_DATASETS/VOCdevkit_Rider/VOC2007//images/20190524111458127819_20190524105554704736_00003002010.jpg
# /media/yyp/DATA/Public_Datasets/ZENITH_DATASETS/VOCdevkit_Rider/VOC2007//images/20190524111458160607_20190524105554900615_00003002011.jpg
# /media/yyp/DATA/Public_Datasets/ZENITH_DATASETS/VOCdevkit_Rider/VOC2007//images/20190524111458199210_20190524105555088128_00003002012.jpg
# /media/yyp/DATA/Public_Datasets/ZENITH_DATASETS/VOCdevkit_Rider/VOC2007//images/20190524111458235941_20190524105555235245_00003002013.jpg
# /media/yyp/DATA/Public_Datasets/ZENITH_DATASETS/VOCdevkit_Rider/VOC2007//images/20190524111458271035_20190524105555378770_00003002014.jpg
# /media/yyp/DATA/Public_Datasets/ZENITH_DATASETS/VOCdevkit_Rider/VOC2007//images/20190524111458332970_20190524105555743088_00003002016.jpg
# /media/yyp/DATA/Public_Datasets/ZENITH_DATASETS/VOCdevkit_Rider/VOC2007//images/20190524111458367005_20190524105555971289_00003002017.jpg
# /media/yyp/DATA/Public_Datasets/ZENITH_DATASETS/VOCdevkit_Rider/VOC2007//images/20190524111458404152_20190524105556208763_00003002018.jpg
# /media/yyp/DATA/Public_Datasets/ZENITH_DATASETS/VOCdevkit_Rider/VOC2007//images/20190524111458438825_20190524105556432260_00003002019.jpg
# /media/yyp/DATA/Public_Datasets/ZENITH_DATASETS/VOCdevkit_Rider/VOC2007//images/20190524111458473710_20190524105556650627_00003002020.jpg
# /media/yyp/DATA/Public_Datasets/ZENITH_DATASETS/VOCdevkit_Rider/VOC2007//images/20190524111458507773_20190524105556879176_00003002021.jpg
# /media/yyp/DATA/Public_Datasets/ZENITH_DATASETS/VOCdevkit_Rider/VOC2007//images/20190524111458543157_20190524105557120088_00003002022.jpg
# /media/yyp/DATA/Public_Datasets/ZENITH_DATASETS/VOCdevkit_Rider/VOC2007//images/20190524111458577398_20190524105557343010_00003002023.jpg
# /media/yyp/DATA/Public_Datasets/ZENITH_DATASETS/VOCdevkit_Rider/VOC2007//images/20190524111458615313_20190524105557580184_00003002024.jpg
# /media/yyp/DATA/Public_Datasets/ZENITH_DATASETS/VOCdevkit_Rider/VOC2007//images/20190524111458650041_20190524105557838424_00003002025.jpg
# /media/yyp/DATA/Public_Datasets/ZENITH_DATASETS/VOCdevkit_Rider/VOC2007//images/20190524111458684023_20190524105558101343_00003002026.jpg
# /media/yyp/DATA/Public_Datasets/ZENITH_DATASETS/VOCdevkit_Rider/VOC2007//images/20190524111458717463_20190524105558396752_00003002027.jpg
# /media/yyp/DATA/Public_Datasets/ZENITH_DATASETS/VOCdevkit_Rider/VOC2007//images/20190524111458750226_20190524105558697533_00003002028.jpg
# /media/yyp/DATA/Public_Datasets/ZENITH_DATASETS/VOCdevkit_Rider/VOC2007//images/20190524111458783063_20190524105559030656_00003002029.jpg
# /media/yyp/DATA/Public_Datasets/ZENITH_DATASETS/VOCdevkit_Rider/VOC2007//images/20190524111458819637_20190524105559364940_00003002030.jpg
# /media/yyp/DATA/Public_Datasets/ZENITH_DATASETS/VOCdevkit_Rider/VOC2007//images/20190524111458854027_20190524105559703692_00003002031.jpg
# /media/yyp/DATA/Public_Datasets/ZENITH_DATASETS/VOCdevkit_Rider/VOC2007//images/20190524111458888660_20190524105600078148_00003002032.jpg
# /media/yyp/DATA/Public_Datasets/ZENITH_DATASETS/VOCdevkit_Rider/VOC2007//images/20190524111458928517_20190524105600410838_00003002033.jpg
# /media/yyp/DATA/Public_Datasets/ZENITH_DATASETS/VOCdevkit_Rider/VOC2007//images/20190524111458965444_20190524105600721369_00003002034.jpg
# /media/yyp/DATA/Public_Datasets/ZENITH_DATASETS/VOCdevkit_Rider/VOC2007//images/20190524111459003855_20190524105601034806_00003002035.jpg
# /media/yyp/DATA/Public_Datasets/ZENITH_DATASETS/VOCdevkit_Rider/VOC2007//images/20190524111459044869_20190524105601346068_00003002036.jpg
# /media/yyp/DATA/Public_Datasets/ZENITH_DATASETS/VOCdevkit_Rider/VOC2007//images/20190524111459080945_20190524105601664125_00003002037.jpg
# /media/yyp/DATA/Public_Datasets/ZENITH_DATASETS/VOCdevkit_Rider/VOC2007//images/20190524111459117717_20190524105601966369_00003002038.jpg
# /media/yyp/DATA/Public_Datasets/ZENITH_DATASETS/VOCdevkit_Rider/VOC2007//images/20190524111459153360_20190524105602266141_00003002039.jpg
# /media/yyp/DATA/Public_Datasets/ZENITH_DATASETS/VOCdevkit_Rider/VOC2007//images/20190524111459191085_20190524105602605265_00003002040.jpg
# /media/yyp/DATA/Public_Datasets/ZENITH_DATASETS/VOCdevkit_Rider/VOC2007//images/20190524111459225835_20190524105602922201_00003002041.jpg
# /media/yyp/DATA/Public_Datasets/ZENITH_DATASETS/VOCdevkit_Rider/VOC2007//images/20190524111459262721_20190524105603223427_00003002042.jpg
# /media/yyp/DATA/Public_Datasets/ZENITH_DATASETS/VOCdevkit_Rider/VOC2007//images/20190524111459296063_20190524105603479192_00003002043.jpg
# /media/yyp/DATA/Public_Datasets/ZENITH_DATASETS/VOCdevkit_Rider/VOC2007//images/20190524111459329553_20190524105603734950_00003002044.jpg
# /media/yyp/DATA/Public_Datasets/ZENITH_DATASETS/VOCdevkit_Rider/VOC2007//images/20190524111459362692_20190524105603994037_00003002045.jpg
# /media/yyp/DATA/Public_Datasets/ZENITH_DATASETS/VOCdevkit_Rider/VOC2007//images/20190524111459397297_20190524105604256448_00003002046.jpg
# /media/yyp/DATA/Public_Datasets/ZENITH_DATASETS/VOCdevkit_Rider/VOC2007//images/20190524111459433809_20190524105604519484_00003002047.jpg
# /media/yyp/DATA/Public_Datasets/ZENITH_DATASETS/VOCdevkit_Rider/VOC2007//images/20190524111459470577_20190524105604742914_00003002048.jpg
# /media/yyp/DATA/Public_Datasets/ZENITH_DATASETS/VOCdevkit_Rider/VOC2007//images/20190524111459503334_20190524105605001189_00003002049.jpg
# /media/yyp/DATA/Public_Datasets/ZENITH_DATASETS/VOCdevkit_Rider/VOC2007//images/20190524111459535891_20190524105605261555_00003002050.jpg
# /media/yyp/DATA/Public_Datasets/ZENITH_DATASETS/VOCdevkit_Rider/VOC2007//images/20190524111459569102_20190524105605521603_00003002051.jpg
# /media/yyp/DATA/Public_Datasets/ZENITH_DATASETS/VOCdevkit_Rider/VOC2007//images/20190524111459602283_20190524105605784888_00003002052.jpg
# /media/yyp/DATA/Public_Datasets/ZENITH_DATASETS/VOCdevkit_Rider/VOC2007//images/20190524111459635213_20190524105606044218_00003002053.jpg
# /media/yyp/DATA/Public_Datasets/ZENITH_DATASETS/VOCdevkit_Rider/VOC2007//images/20190524111459668438_20190524105606303889_00003002054.jpg
# /media/yyp/DATA/Public_Datasets/ZENITH_DATASETS/VOCdevkit_Rider/VOC2007//images/20190524111459701970_20190524105606563126_00003002055.jpg
# /media/yyp/DATA/Public_Datasets/ZENITH_DATASETS/VOCdevkit_Rider/VOC2007//images/20190524111459735133_20190524105606827494_00003002056.jpg
# /media/yyp/DATA/Public_Datasets/ZENITH_DATASETS/VOCdevkit_Rider/VOC2007//images/20190524111459768174_20190524105607088644_00003002057.jpg
# /media/yyp/DATA/Public_Datasets/ZENITH_DATASETS/VOCdevkit_Rider/VOC2007//images/20190524111459802549_20190524105607350403_00003002058.jpg
# /media/yyp/DATA/Public_Datasets/ZENITH_DATASETS/VOCdevkit_Rider/VOC2007//images/20190524111459834811_20190524105607573254_00003002059.jpg
# /media/yyp/DATA/Public_Datasets/ZENITH_DATASETS/VOCdevkit_Rider/VOC2007//images/20190524111459869382_20190524105607832160_00003002060.jpg
# /media/yyp/DATA/Public_Datasets/ZENITH_DATASETS/VOCdevkit_Rider/VOC2007//images/20190524111459905683_20190524105608068232_00003002061.jpg
# /media/yyp/DATA/Public_Datasets/ZENITH_DATASETS/VOCdevkit_Rider/VOC2007//images/20190524111459940047_20190524105608303274_00003002062.jpg
# /media/yyp/DATA/Public_Datasets/ZENITH_DATASETS/VOCdevkit_Rider/VOC2007//images/20190524111459974044_20190524105608527558_00003002063.jpg
# /media/yyp/DATA/Public_Datasets/ZENITH_DATASETS/VOCdevkit_Rider/VOC2007//images/20190524111500007921_20190524105608748122_00003002064.jpg
# /media/yyp/DATA/Public_Datasets/ZENITH_DATASETS/VOCdevkit_Rider/VOC2007//images/20190524111500043057_20190524105609009497_00003002065.jpg
# /media/yyp/DATA/Public_Datasets/ZENITH_DATASETS/VOCdevkit_Rider/VOC2007//images/20190524111500077677_20190524105609251424_00003002066.jpg
# /media/yyp/DATA/Public_Datasets/ZENITH_DATASETS/VOCdevkit_Rider/VOC2007//images/20190524111500116268_20190524105609492469_00003002067.jpg
# /media/yyp/DATA/Public_Datasets/ZENITH_DATASETS/VOCdevkit_Rider/VOC2007//images/20190524111500150687_20190524105609719111_00003002068.jpg
# /media/yyp/DATA/Public_Datasets/ZENITH_DATASETS/VOCdevkit_Rider/VOC2007//images/20190524111500185098_20190524105609940686_00003002069.jpg
# /media/yyp/DATA/Public_Datasets/ZENITH_DATASETS/VOCdevkit_Rider/VOC2007//images/20190524111500219300_20190524105610163325_00003002070.jpg
# /media/yyp/DATA/Public_Datasets/ZENITH_DATASETS/VOCdevkit_Rider/VOC2007//images/20190524111500252693_20190524105610394282_00003002071.jpg
# /media/yyp/DATA/Public_Datasets/ZENITH_DATASETS/VOCdevkit_Rider/VOC2007//images/20190524111500285754_20190524105610625314_00003002072.jpg
# /media/yyp/DATA/Public_Datasets/ZENITH_DATASETS/VOCdevkit_Rider/VOC2007//images/20190524111500320983_20190524105610851686_00003002073.jpg
# /media/yyp/DATA/Public_Datasets/ZENITH_DATASETS/VOCdevkit_Rider/VOC2007//images/20190524111500354798_20190524105611075258_00003002074.jpg
# /media/yyp/DATA/Public_Datasets/ZENITH_DATASETS/VOCdevkit_Rider/VOC2007//images/20190524111500389189_20190524105611295700_00003002075.jpg
# /media/yyp/DATA/Public_Datasets/ZENITH_DATASETS/VOCdevkit_Rider/VOC2007//images/20190524111500423304_20190524105611518758_00003002076.jpg
# /media/yyp/DATA/Public_Datasets/ZENITH_DATASETS/VOCdevkit_Rider/VOC2007//images/20190524111500459012_20190524105611740868_00003002077.jpg
# /media/yyp/DATA/Public_Datasets/ZENITH_DATASETS/VOCdevkit_Rider/VOC2007//images/20190524111500492553_20190524105611961740_00003002078.jpg
# /media/yyp/DATA/Public_Datasets/ZENITH_DATASETS/VOCdevkit_Rider/VOC2007//images/20190524111500528477_20190524105612182461_00003002079.jpg
# /media/yyp/DATA/Public_Datasets/ZENITH_DATASETS/VOCdevkit_Rider/VOC2007//images/20190524111500567919_20190524105612418884_00003002080.jpg
# /media/yyp/DATA/Public_Datasets/ZENITH_DATASETS/VOCdevkit_Rider/VOC2007//images/20190524111500603651_20190524105612657717_00003002081.jpg
# /media/yyp/DATA/Public_Datasets/ZENITH_DATASETS/VOCdevkit_Rider/VOC2007//images/20190524111500638926_20190524105612894242_00003002082.jpg
# /media/yyp/DATA/Public_Datasets/ZENITH_DATASETS/VOCdevkit_Rider/VOC2007//images/20190524111500674844_20190524105613128840_00003002083.jpg
# /media/yyp/DATA/Public_Datasets/ZENITH_DATASETS/VOCdevkit_Rider/VOC2007//images/20190524111500711609_20190524105613363641_00003002084.jpg
# /media/yyp/DATA/Public_Datasets/ZENITH_DATASETS/VOCdevkit_Rider/VOC2007//images/20190524111500749851_20190524105613598199_00003002085.jpg
# /media/yyp/DATA/Public_Datasets/ZENITH_DATASETS/VOCdevkit_Rider/VOC2007//images/20190524111500787369_20190524105613831897_00003002086.jpg
# /media/yyp/DATA/Public_Datasets/ZENITH_DATASETS/VOCdevkit_Rider/VOC2007//images/20190524111500822875_20190524105614059887_00003002089.jpg
# /media/yyp/DATA/Public_Datasets/ZENITH_DATASETS/VOCdevkit_Rider/VOC2007//images/20190524111500860859_20190524105614239246_00003002090.jpg
# /media/yyp/DATA/Public_Datasets/ZENITH_DATASETS/VOCdevkit_Rider/VOC2007//images/20190524111500897321_20190524105614423119_00003002091.jpg
# /media/yyp/DATA/Public_Datasets/ZENITH_DATASETS/VOCdevkit_Rider/VOC2007//images/20190524111500930424_20190524105614591674_00003002092.jpg
# /media/yyp/DATA/Public_Datasets/ZENITH_DATASETS/VOCdevkit_Rider/VOC2007//images/20190524111500966188_20190524105614845869_00003002094.jpg
# /media/yyp/DATA/Public_Datasets/ZENITH_DATASETS/VOCdevkit_Rider/VOC2007//images/20190524111501001345_20190524105615012139_00003002095.jpg
# /media/yyp/DATA/Public_Datasets/ZENITH_DATASETS/VOCdevkit_Rider/VOC2007//images/20190524111501036391_20190524105615229706_00003002096.jpg
# /media/yyp/DATA/Public_Datasets/ZENITH_DATASETS/VOCdevkit_Rider/VOC2007//images/20190524111501071204_20190524105615446975_00003002097.jpg
# /media/yyp/DATA/Public_Datasets/ZENITH_DATASETS/VOCdevkit_Rider/VOC2007//images/20190524111501106416_20190524105615663131_00003002098.jpg
# /media/yyp/DATA/Public_Datasets/ZENITH_DATASETS/VOCdevkit_Rider/VOC2007//images/20190524111501141243_20190524105615880974_00003002104.jpg
# /media/yyp/DATA/Public_Datasets/ZENITH_DATASETS/VOCdevkit_Rider/VOC2007//images/20190524111501175842_20190524105616059419_00003002105.jpg
# /media/yyp/DATA/Public_Datasets/ZENITH_DATASETS/VOCdevkit_Rider/VOC2007//images/20190524111501209895_20190524105616239858_00003002107.jpg
# /media/yyp/DATA/Public_Datasets/ZENITH_DATASETS/VOCdevkit_Rider/VOC2007//images/20190524111501242724_20190524105616422136_00003002108.jpg
# /media/yyp/DATA/Public_Datasets/ZENITH_DATASETS/VOCdevkit_Rider/VOC2007//images/20190524111501275529_20190524105616640078_00003002110.jpg
# /media/yyp/DATA/Public_Datasets/ZENITH_DATASETS/VOCdevkit_Rider/VOC2007//images/20190524111501307936_20190524105616854500_00003002111.jpg
# /media/yyp/DATA/Public_Datasets/ZENITH_DATASETS/VOCdevkit_Rider/VOC2007//images/20190524111501341329_20190524105617114434_00003002117.jpg
# /media/yyp/DATA/Public_Datasets/ZENITH_DATASETS/VOCdevkit_Rider/VOC2007//images/20190524111501376081_20190524105617374594_00003002122.jpg
# /media/yyp/DATA/Public_Datasets/ZENITH_DATASETS/VOCdevkit_Rider/VOC2007//images/20190524111501410508_20190524105617660077_00003002123.jpg
# ...
# /media/yyp/DATA/Public_Datasets/ZENITH_DATASETS/VOCdevkit_Rider/VOC2007//images/fliped_fliped_20190524105639242293_00003006046.jpg
# /media/yyp/DATA/Public_Datasets/ZENITH_DATASETS/VOCdevkit_Rider/VOC2007//images/fliped_fliped_20190524105639513877_00003006047.jpg
# /media/yyp/DATA/Public_Datasets/ZENITH_DATASETS/VOCdevkit_Rider/VOC2007//images/fliped_fliped_20190524105639832467_00003006051.jpg
# /media/yyp/DATA/Public_Datasets/ZENITH_DATASETS/VOCdevkit_Rider/VOC2007//images/fliped_fliped_20190524105640061540_00003006053.jpg
# /media/yyp/DATA/Public_Datasets/ZENITH_DATASETS/VOCdevkit_Rider/VOC2007//images/fliped_fliped_20190524105640288718_00003006055.jpg
# /media/yyp/DATA/Public_Datasets/ZENITH_DATASETS/VOCdevkit_Rider/VOC2007//images/fliped_fliped_20190524105640597726_00003006059.jpg
# /media/yyp/DATA/Public_Datasets/ZENITH_DATASETS/VOCdevkit_Rider/VOC2007//images/fliped_fliped_20190524105640843522_00003006061.jpg
# /media/yyp/DATA/Public_Datasets/ZENITH_DATASETS/VOCdevkit_Rider/VOC2007//images/fliped_fliped_20190524105641073575_00003006064.jpg
# /media/yyp/DATA/Public_Datasets/ZENITH_DATASETS/VOCdevkit_Rider/VOC2007//images/fliped_fliped_20190524105641297814_00003006065.jpg
# /media/yyp/DATA/Public_Datasets/ZENITH_DATASETS/VOCdevkit_Rider/VOC2007//images/fliped_fliped_20190524105641521911_00003006066.jpg
# /media/yyp/DATA/Public_Datasets/ZENITH_DATASETS/VOCdevkit_Rider/VOC2007//images/fliped_fliped_20190524105641821574_00003006074.jpg
# /media/yyp/DATA/Public_Datasets/ZENITH_DATASETS/VOCdevkit_Rider/VOC2007//images/fliped_fliped_20190524105642160964_00003006081.jpg
# /media/yyp/DATA/Public_Datasets/ZENITH_DATASETS/VOCdevkit_Rider/VOC2007//images/fliped_fliped_20190524105642474713_00003006083.jpg
# /media/yyp/DATA/Public_Datasets/ZENITH_DATASETS/VOCdevkit_Rider/VOC2007//images/fliped_fliped_20190524105642779786_00003006084.jpg
# /media/yyp/DATA/Public_Datasets/ZENITH_DATASETS/VOCdevkit_Rider/VOC2007//images/fliped_fliped_20190524105643067520_00003006091.jpg
# /media/yyp/DATA/Public_Datasets/ZENITH_DATASETS/VOCdevkit_Rider/VOC2007//images/fliped_fliped_20190524105643425287_00003006112.jpg
# /media/yyp/DATA/Public_Datasets/ZENITH_DATASETS/VOCdevkit_Rider/VOC2007//images/fliped_fliped_20190524105643781680_00003006114.jpg
# /media/yyp/DATA/Public_Datasets/ZENITH_DATASETS/VOCdevkit_Rider/VOC2007//images/fliped_fliped_20190524105644144208_00003006117.jpg
# /media/yyp/DATA/Public_Datasets/ZENITH_DATASETS/VOCdevkit_Rider/VOC2007//images/fliped_fliped_20190524105644428448_00003006124.jpg
# /media/yyp/DATA/Public_Datasets/ZENITH_DATASETS/VOCdevkit_Rider/VOC2007//images/fliped_fliped_20190524105644746715_00003006129.jpg
# /media/yyp/DATA/Public_Datasets/ZENITH_DATASETS/VOCdevkit_Rider/VOC2007//images/fliped_fliped_20190524105644966377_00003006140.jpg
# /media/yyp/DATA/Public_Datasets/ZENITH_DATASETS/VOCdevkit_Rider/VOC2007//images/fliped_fliped_20190524105645186765_00003006143.jpg
# /media/yyp/DATA/Public_Datasets/ZENITH_DATASETS/VOCdevkit_Rider/VOC2007//images/fliped_fliped_20190524105645386387_00003006144.jpg
# /media/yyp/DATA/Public_Datasets/ZENITH_DATASETS/VOCdevkit_Rider/VOC2007//images/fliped_fliped_20190524105645574464_00003006145.jpg
# /media/yyp/DATA/Public_Datasets/ZENITH_DATASETS/VOCdevkit_Rider/VOC2007//images/fliped_fliped_20190524105645765723_00003006146.jpg
# /media/yyp/DATA/Public_Datasets/ZENITH_DATASETS/VOCdevkit_Rider/VOC2007//images/fliped_fliped_20190524105645951453_00003006149.jpg
# /media/yyp/DATA/Public_Datasets/ZENITH_DATASETS/VOCdevkit_Rider/VOC2007//images/fliped_fliped_20190524105646205328_00003006164.jpg
# /media/yyp/DATA/Public_Datasets/ZENITH_DATASETS/VOCdevkit_Rider/VOC2007//images/fliped_fliped_20190524105646475199_00003006170.jpg
# /media/yyp/DATA/Public_Datasets/ZENITH_DATASETS/VOCdevkit_Rider/VOC2007//images/fliped_fliped_20190524105646702108_00003006173.jpg
# /media/yyp/DATA/Public_Datasets/ZENITH_DATASETS/VOCdevkit_Rider/VOC2007//images/fliped_fliped_20190524105646928669_00003006174.jpg
# /media/yyp/DATA/Public_Datasets/ZENITH_DATASETS/VOCdevkit_Rider/VOC2007//images/fliped_fliped_20190524105647159646_00003006176.jpg
# /media/yyp/DATA/Public_Datasets/ZENITH_DATASETS/VOCdevkit_Rider/VOC2007//images/fliped_fliped_20190524105647384200_00003006181.jpg
# /media/yyp/DATA/Public_Datasets/ZENITH_DATASETS/VOCdevkit_Rider/VOC2007//images/fliped_fliped_20190524105647609312_00003006183.jpg
# /media/yyp/DATA/Public_Datasets/ZENITH_DATASETS/VOCdevkit_Rider/VOC2007//images/fliped_fliped_20190524105647848390_00003006189.jpg
# /media/yyp/DATA/Public_Datasets/ZENITH_DATASETS/VOCdevkit_Rider/VOC2007//images/fliped_fliped_20190524105648045760_00003006195.jpg
# /media/yyp/DATA/Public_Datasets/ZENITH_DATASETS/VOCdevkit_Rider/VOC2007//images/fliped_fliped_20190524105648266778_00003006196.jpg
# /media/yyp/DATA/Public_Datasets/ZENITH_DATASETS/VOCdevkit_Rider/VOC2007//images/fliped_fliped_20190524105648490670_00003006204.jpg
# /media/yyp/DATA/Public_Datasets/ZENITH_DATASETS/VOCdevkit_Rider/VOC2007//images/fliped_fliped_20190524105648673628_00003006205.jpg
# /media/yyp/DATA/Public_Datasets/ZENITH_DATASETS/VOCdevkit_Rider/VOC2007//images/fliped_fliped_20190524105648876438_00003007000.jpg
# /media/yyp/DATA/Public_Datasets/ZENITH_DATASETS/VOCdevkit_Rider/VOC2007//images/fliped_fliped_20190524105649123348_00003007001.jpg
# /media/yyp/DATA/Public_Datasets/ZENITH_DATASETS/VOCdevkit_Rider/VOC2007//images/fliped_fliped_20190524105649371842_00003007002.jpg
# /media/yyp/DATA/Public_Datasets/ZENITH_DATASETS/VOCdevkit_Rider/VOC2007//images/fliped_fliped_20190524105649631710_00003007005.jpg
# /media/yyp/DATA/Public_Datasets/ZENITH_DATASETS/VOCdevkit_Rider/VOC2007//images/fliped_fliped_20190524105649872766_00003007008.jpg
# /media/yyp/DATA/Public_Datasets/ZENITH_DATASETS/VOCdevkit_Rider/VOC2007//images/fliped_fliped_20190524105650082965_00003007014.jpg
# /media/yyp/DATA/Public_Datasets/ZENITH_DATASETS/VOCdevkit_Rider/VOC2007//images/fliped_fliped_20190524105650349664_00003007015.jpg
# /media/yyp/DATA/Public_Datasets/ZENITH_DATASETS/VOCdevkit_Rider/VOC2007//images/fliped_fliped_20190524105650665413_00003007023.jpg
# /media/yyp/DATA/Public_Datasets/ZENITH_DATASETS/VOCdevkit_Rider/VOC2007//images/fliped_fliped_20190524105650949692_00003007033.jpg
# /media/yyp/DATA/Public_Datasets/ZENITH_DATASETS/VOCdevkit_Rider/VOC2007//images/fliped_fliped_20190524105651264399_00003007039.jpg
# /media/yyp/DATA/Public_Datasets/ZENITH_DATASETS/VOCdevkit_Rider/VOC2007//images/fliped_fliped_20190524105651467854_00003007044.jpg
# /media/yyp/DATA/Public_Datasets/ZENITH_DATASETS/VOCdevkit_Rider/VOC2007//images/fliped_fliped_20190524105651762918_00003007045.jpg
# /media/yyp/DATA/Public_Datasets/ZENITH_DATASETS/VOCdevkit_Rider/VOC2007//images/fliped_fliped_20190524105652019934_00003007049.jpg
# /media/yyp/DATA/Public_Datasets/ZENITH_DATASETS/VOCdevkit_Rider/VOC2007//images/fliped_fliped_20190524105652277006_00003007051.jpg
# /media/yyp/DATA/Public_Datasets/ZENITH_DATASETS/VOCdevkit_Rider/VOC2007//images/fliped_fliped_20190524105652534269_00003007053.jpg
# /media/yyp/DATA/Public_Datasets/ZENITH_DATASETS/VOCdevkit_Rider/VOC2007//images/fliped_fliped_20190524105652798206_00003007054.jpg
# /media/yyp/DATA/Public_Datasets/ZENITH_DATASETS/VOCdevkit_Rider/VOC2007//images/fliped_fliped_20190524105653113550_00003007055.jpg
# /media/yyp/DATA/Public_Datasets/ZENITH_DATASETS/VOCdevkit_Rider/VOC2007//images/fliped_fliped_20190524105653437681_00003007059.jpg
# /media/yyp/DATA/Public_Datasets/ZENITH_DATASETS/VOCdevkit_Rider/VOC2007//images/fliped_fliped_20190524105653829982_00003007063.jpg
# /media/yyp/DATA/Public_Datasets/ZENITH_DATASETS/VOCdevkit_Rider/VOC2007//images/fliped_fliped_20190524105654107528_00003007073.jpg
# /media/yyp/DATA/Public_Datasets/ZENITH_DATASETS/VOCdevkit_Rider/VOC2007//images/fliped_fliped_20190524105654477689_00003007078.jpg
# /media/yyp/DATA/Public_Datasets/ZENITH_DATASETS/VOCdevkit_Rider/VOC2007//images/fliped_fliped_20190524105654788240_00003007103.jpg
# /media/yyp/DATA/Public_Datasets/ZENITH_DATASETS/VOCdevkit_Rider/VOC2007//images/fliped_fliped_20190524105655132723_00003007107.jpg
# /media/yyp/DATA/Public_Datasets/ZENITH_DATASETS/VOCdevkit_Rider/VOC2007//images/fliped_fliped_20190524105655501306_00003007118.jpg
# /media/yyp/DATA/Public_Datasets/ZENITH_DATASETS/VOCdevkit_Rider/VOC2007//images/fliped_fliped_20190524105655916009_00003007119.jpg
# /media/yyp/DATA/Public_Datasets/ZENITH_DATASETS/VOCdevkit_Rider/VOC2007//images/fliped_fliped_20190524105656346178_00003007122.jpg
# /media/yyp/DATA/Public_Datasets/ZENITH_DATASETS/VOCdevkit_Rider/VOC2007//images/fliped_fliped_20190524105656801975_00003007128.jpg
# /media/yyp/DATA/Public_Datasets/ZENITH_DATASETS/VOCdevkit_Rider/VOC2007//images/fliped_fliped_20190524105657211908_00003007134.jpg
# /media/yyp/DATA/Public_Datasets/ZENITH_DATASETS/VOCdevkit_Rider/VOC2007//images/fliped_fliped_20190524105657654973_00003007138.jpg
# /media/yyp/DATA/Public_Datasets/ZENITH_DATASETS/VOCdevkit_Rider/VOC2007//images/fliped_fliped_20190524105658031449_00003007153.jpg
# /media/yyp/DATA/Public_Datasets/ZENITH_DATASETS/VOCdevkit_Rider/VOC2007//images/fliped_fliped_20190524105658272181_00003007174.jpg
# /media/yyp/DATA/Public_Datasets/ZENITH_DATASETS/VOCdevkit_Rider/VOC2007//images/fliped_fliped_20190524105658477409_00003008000.jpg
# /media/yyp/DATA/Public_Datasets/ZENITH_DATASETS/VOCdevkit_Rider/VOC2007//images/fliped_fliped_20190524105658715638_00003008001.jpg
# /media/yyp/DATA/Public_Datasets/ZENITH_DATASETS/VOCdevkit_Rider/VOC2007//images/fliped_fliped_20190524105659398679_00003020300.jpg
# /media/yyp/DATA/Public_Datasets/ZENITH_DATASETS/VOCdevkit_Rider/VOC2007//images/fliped_fliped_20190524105703036696_00003020329.jpg
# /media/yyp/DATA/Public_Datasets/ZENITH_DATASETS/VOCdevkit_Rider/VOC2007//images/fliped_fliped_20190524105704105659_00003020344.jpg
# /media/yyp/DATA/Public_Datasets/ZENITH_DATASETS/VOCdevkit_Rider/VOC2007//images/fliped_fliped_20190524105705823210_00003020394.jpg
# /media/yyp/DATA/Public_Datasets/ZENITH_DATASETS/VOCdevkit_Rider/VOC2007//images/fliped_fliped_20190524105706652437_00003020427.jpg
# /media/yyp/DATA/Public_Datasets/ZENITH_DATASETS/VOCdevkit_Rider/VOC2007//images/fliped_fliped_20190524105707844658_00003020521.jpg
# /media/yyp/DATA/Public_Datasets/ZENITH_DATASETS/VOCdevkit_Rider/VOC2007//images/fliped_fliped_20190524105708598068_00003020591.jpg
# /media/yyp/DATA/Public_Datasets/ZENITH_DATASETS/VOCdevkit_Rider/VOC2007//images/fliped_fliped_20190524105709657918_00003020599.jpg
# /media/yyp/DATA/Public_Datasets/ZENITH_DATASETS/VOCdevkit_Rider/VOC2007//images/fliped_fliped_20190524105710546278_00003020600.jpg
# /media/yyp/DATA/Public_Datasets/ZENITH_DATASETS/VOCdevkit_Rider/VOC2007//images/fliped_fliped_20190524105711394064_00003020603.jpg
# /media/yyp/DATA/Public_Datasets/ZENITH_DATASETS/VOCdevkit_Rider/VOC2007//images/fliped_fliped_20190524105712221826_00003020621.jpg
# /media/yyp/DATA/Public_Datasets/ZENITH_DATASETS/VOCdevkit_Rider/VOC2007//images/fliped_fliped_20190524105713011758_00003020624.jpg
# /media/yyp/DATA/Public_Datasets/ZENITH_DATASETS/VOCdevkit_Rider/VOC2007//images/fliped_fliped_20190524105713792486_00003020644.jpg
# /media/yyp/DATA/Public_Datasets/ZENITH_DATASETS/VOCdevkit_Rider/VOC2007//images/fliped_fliped_20190524105714477257_00003020649.jpg
# /media/yyp/DATA/Public_Datasets/ZENITH_DATASETS/VOCdevkit_Rider/VOC2007//images/fliped_fliped_20190524105715205143_00003020654.jpg
# /media/yyp/DATA/Public_Datasets/ZENITH_DATASETS/VOCdevkit_Rider/VOC2007//images/fliped_fliped_20190524105715962709_00003020659.jpg
# /media/yyp/DATA/Public_Datasets/ZENITH_DATASETS/VOCdevkit_Rider/VOC2007//images/fliped_fliped_20190524105716703863_00003020663.jpg
# /media/yyp/DATA/Public_Datasets/ZENITH_DATASETS/VOCdevkit_Rider/VOC2007//images/fliped_fliped_20190524105717457980_00003020666.jpg
# /media/yyp/DATA/Public_Datasets/ZENITH_DATASETS/VOCdevkit_Rider/VOC2007//images/fliped_fliped_20190524105718180823_00003020671.jpg
# /media/yyp/DATA/Public_Datasets/ZENITH_DATASETS/VOCdevkit_Rider/VOC2007//images/fliped_fliped_20190524105718983377_00003020673.jpg
# /media/yyp/DATA/Public_Datasets/ZENITH_DATASETS/VOCdevkit_Rider/VOC2007//images/fliped_fliped_20190524105719773359_00003020679.jpg
# /media/yyp/DATA/Public_Datasets/ZENITH_DATASETS/VOCdevkit_Rider/VOC2007//images/fliped_fliped_20190524105720729973_00003020702.jpg
# /media/yyp/DATA/Public_Datasets/ZENITH_DATASETS/VOCdevkit_Rider/VOC2007//images/fliped_fliped_20190524105721647753_00003020710.jpg
# /media/yyp/DATA/Public_Datasets/ZENITH_DATASETS/VOCdevkit_Rider/VOC2007//images/fliped_fliped_20190524105722500836_00003020738.jpg
# /media/yyp/DATA/Public_Datasets/ZENITH_DATASETS/VOCdevkit_Rider/VOC2007//images/fliped_fliped_20190524105723273767_00003020741.jpg
# /media/yyp/DATA/Public_Datasets/ZENITH_DATASETS/VOCdevkit_Rider/VOC2007//images/fliped_fliped_20190524105723576547_00003020900.jpg
# /media/yyp/DATA/Public_Datasets/ZENITH_DATASETS/VOCdevkit_Rider/VOC2007//images/fliped_fliped_20190524105723833088_00003020902.jpg
# /media/yyp/DATA/Public_Datasets/ZENITH_DATASETS/VOCdevkit_Rider/VOC2007//images/fliped_fliped_20190524105724102296_00003020914.jpg
# /media/yyp/DATA/Public_Datasets/ZENITH_DATASETS/VOCdevkit_Rider/VOC2007//images/fliped_fliped_20190524105724352906_00003020920.jpg
# /media/yyp/DATA/Public_Datasets/ZENITH_DATASETS/VOCdevkit_Rider/VOC2007//images/fliped_fliped_20190524105724583654_00003020930.jpg
# /media/yyp/DATA/Public_Datasets/ZENITH_DATASETS/VOCdevkit_Rider/VOC2007//images/fliped_fliped_20190524105724829743_00003020940.jpg
# /media/yyp/DATA/Public_Datasets/ZENITH_DATASETS/VOCdevkit_Rider/VOC2007//images/fliped_fliped_20190524105725116035_00003020942.jpg
# /media/yyp/DATA/Public_Datasets/ZENITH_DATASETS/VOCdevkit_Rider/VOC2007//images/fliped_fliped_20190524105725345036_00003020956.jpg
# /media/yyp/DATA/Public_Datasets/ZENITH_DATASETS/VOCdevkit_Rider/VOC2007//images/fliped_fliped_20190524105725595821_00003020960.jpg
# /media/yyp/DATA/Public_Datasets/ZENITH_DATASETS/VOCdevkit_Rider/VOC2007//images/fliped_fliped_20190524105725794243_00003020970.jpg
# /media/yyp/DATA/Public_Datasets/ZENITH_DATASETS/VOCdevkit_Rider/VOC2007//images/fliped_fliped_20190524105725993016_00003020974.jpg
# /media/yyp/DATA/Public_Datasets/ZENITH_DATASETS/VOCdevkit_Rider/VOC2007//images/fliped_fliped_20190524105726187555_00003020978.jpg
# /media/yyp/DATA/Public_Datasets/ZENITH_DATASETS/VOCdevkit_Rider/VOC2007//images/fliped_fliped_20190524105726356730_00003020982.jpg
# /media/yyp/DATA/Public_Datasets/ZENITH_DATASETS/VOCdevkit_Rider/VOC2007//images/fliped_fliped_20190524105726618172_00003020988.jpg
# /media/yyp/DATA/Public_Datasets/ZENITH_DATASETS/VOCdevkit_Rider/VOC2007//images/fliped_fliped_20190524105726808401_00003020994.jpg
# /media/yyp/DATA/Public_Datasets/ZENITH_DATASETS/VOCdevkit_Rider/VOC2007//images/fliped_fliped_20190524105727014421_00003020996.jpg
# /media/yyp/DATA/Public_Datasets/ZENITH_DATASETS/VOCdevkit_Rider/VOC2007//images/fliped_fliped_20190524105727205966_00003021006.jpg
# /media/yyp/DATA/Public_Datasets/ZENITH_DATASETS/VOCdevkit_Rider/VOC2007//images/fliped_fliped_20190524105727437905_00003021008.jpg
# /media/yyp/DATA/Public_Datasets/ZENITH_DATASETS/VOCdevkit_Rider/VOC2007//images/fliped_fliped_20190524105727623408_00003021014.jpg
# /media/yyp/DATA/Public_Datasets/ZENITH_DATASETS/VOCdevkit_Rider/VOC2007//images/fliped_fliped_20190524105727780232_00003021016.jpg
# /media/yyp/DATA/Public_Datasets/ZENITH_DATASETS/VOCdevkit_Rider/VOC2007//images/fliped_fliped_20190524105727894542_00003021020.jpg
# /media/yyp/DATA/Public_Datasets/ZENITH_DATASETS/VOCdevkit_Rider/VOC2007//images/fliped_fliped_20190524105728135515_00003021036.jpg
# /media/yyp/DATA/Public_Datasets/ZENITH_DATASETS/VOCdevkit_Rider/VOC2007//images/fliped_fliped_20190524105728381323_00003021040.jpg
# /media/yyp/DATA/Public_Datasets/ZENITH_DATASETS/VOCdevkit_Rider/VOC2007//images/fliped_fliped_20190524105728640208_00003021042.jpg
# /media/yyp/DATA/Public_Datasets/ZENITH_DATASETS/VOCdevkit_Rider/VOC2007//images/fliped_fliped_20190524105728827107_00003021046.jpg
# /media/yyp/DATA/Public_Datasets/ZENITH_DATASETS/VOCdevkit_Rider/VOC2007//images/fliped_fliped_20190524105729044794_00003021048.jpg
