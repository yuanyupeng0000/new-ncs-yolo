# %%
import os, time
import xml.etree.ElementTree as ET
#SEED_XML_DIR = '/media/yyp/DATA/Public_Datasets/COCO/Annotations/'
#GENE_XML_DIR = '/media/yyp/DATA/Public_Datasets/COCO/Generated_Annotations/'
SEED_XML_DIR = '/media/yyp/DATA/Public_Datasets/BITVehicle/Annotations/'
GENE_XML_DIR = '/media/yyp/DATA/Public_Datasets/BITVehicle/Annotations/'
seed_xml_names = os.listdir(SEED_XML_DIR)
seed_xml_names.sort(reverse=False)
#print(seed_xml_names)
for xml_name in seed_xml_names:
    if((int(xml_name[-9:-4]) < 2311) or (int(xml_name[-9:-4]) > 2801)):
        continue
    in_file = open(SEED_XML_DIR + xml_name)
    tree=ET.parse(in_file)
    root = tree.getroot()

    for obj in root.iter('object'):
        cls = obj.find('name').text
        if(cls == 'car'):
            obj.find('name').text = 'bus'
            tree.write(SEED_XML_DIR + xml_name)
            print('xml {0} changed'.format(xml_name))
# Out:
# xml vehicle_0002316.xml changed
# xml vehicle_0002323.xml changed
# xml vehicle_0002324.xml changed
# xml vehicle_0002325.xml changed
# xml vehicle_0002326.xml changed
# xml vehicle_0002330.xml changed
# xml vehicle_0002332.xml changed
# xml vehicle_0002351.xml changed
# xml vehicle_0002353.xml changed
# xml vehicle_0002355.xml changed
# xml vehicle_0002360.xml changed
# xml vehicle_0002361.xml changed
# xml vehicle_0002365.xml changed
# xml vehicle_0002372.xml changed
# xml vehicle_0002373.xml changed
# xml vehicle_0002377.xml changed
# xml vehicle_0002378.xml changed
# xml vehicle_0002379.xml changed
# xml vehicle_0002380.xml changed
# xml vehicle_0002398.xml changed
# xml vehicle_0002408.xml changed
# xml vehicle_0002416.xml changed
# xml vehicle_0002417.xml changed
# xml vehicle_0002417.xml changed
# xml vehicle_0002424.xml changed
# xml vehicle_0002428.xml changed
# xml vehicle_0002430.xml changed
# xml vehicle_0002434.xml changed
# xml vehicle_0002446.xml changed
# xml vehicle_0002454.xml changed
# xml vehicle_0002456.xml changed
# xml vehicle_0002458.xml changed
# xml vehicle_0002459.xml changed
# xml vehicle_0002465.xml changed
# xml vehicle_0002478.xml changed
# xml vehicle_0002481.xml changed
# xml vehicle_0002483.xml changed
# xml vehicle_0002486.xml changed
# xml vehicle_0002487.xml changed
# xml vehicle_0002490.xml changed
# xml vehicle_0002494.xml changed
# xml vehicle_0002498.xml changed
# xml vehicle_0002503.xml changed
# xml vehicle_0002508.xml changed
# xml vehicle_0002516.xml changed
# xml vehicle_0002517.xml changed
# xml vehicle_0002518.xml changed
# xml vehicle_0002519.xml changed
# xml vehicle_0002522.xml changed
# xml vehicle_0002522.xml changed
# xml vehicle_0002527.xml changed
# xml vehicle_0002528.xml changed
# xml vehicle_0002534.xml changed
# xml vehicle_0002537.xml changed
# xml vehicle_0002540.xml changed
# xml vehicle_0002541.xml changed
# xml vehicle_0002543.xml changed
# xml vehicle_0002552.xml changed
# xml vehicle_0002553.xml changed
# xml vehicle_0002555.xml changed
# xml vehicle_0002558.xml changed
# xml vehicle_0002568.xml changed
# xml vehicle_0002596.xml changed
# xml vehicle_0002601.xml changed
# xml vehicle_0002602.xml changed
# xml vehicle_0002603.xml changed
# xml vehicle_0002606.xml changed
# xml vehicle_0002607.xml changed
# xml vehicle_0002610.xml changed
# xml vehicle_0002619.xml changed
# xml vehicle_0002621.xml changed
# xml vehicle_0002625.xml changed
# xml vehicle_0002631.xml changed
# xml vehicle_0002641.xml changed
# xml vehicle_0002645.xml changed
# xml vehicle_0002654.xml changed
# xml vehicle_0002658.xml changed
# xml vehicle_0002660.xml changed
# xml vehicle_0002661.xml changed
# xml vehicle_0002664.xml changed
# xml vehicle_0002669.xml changed
# xml vehicle_0002673.xml changed
# xml vehicle_0002681.xml changed
# xml vehicle_0002682.xml changed
# xml vehicle_0002683.xml changed
# xml vehicle_0002685.xml changed
# xml vehicle_0002686.xml changed
# xml vehicle_0002688.xml changed
# xml vehicle_0002689.xml changed
# xml vehicle_0002696.xml changed
# xml vehicle_0002700.xml changed
# xml vehicle_0002708.xml changed
# xml vehicle_0002709.xml changed
# xml vehicle_0002710.xml changed
# xml vehicle_0002715.xml changed
# xml vehicle_0002718.xml changed
# xml vehicle_0002719.xml changed
# xml vehicle_0002720.xml changed
# xml vehicle_0002728.xml changed
# xml vehicle_0002747.xml changed
# xml vehicle_0002748.xml changed
# xml vehicle_0002749.xml changed
# xml vehicle_0002754.xml changed
# xml vehicle_0002759.xml changed
# xml vehicle_0002761.xml changed
# xml vehicle_0002764.xml changed
# xml vehicle_0002768.xml changed
# xml vehicle_0002770.xml changed
# xml vehicle_0002777.xml changed
# xml vehicle_0002780.xml changed
# xml vehicle_0002782.xml changed
# xml vehicle_0002784.xml changed
# xml vehicle_0002785.xml changed
# xml vehicle_0002793.xml changed
# xml vehicle_0002801.xml changed
