# %%
import os, time
import cv2
import xml.etree.ElementTree as ET
from PIL import Image
import numpy as np
import random
from pathlib import Path
SEED_XML_DIR = '/data/darknet/python/20190517_xml/'
SEED_IMG_DIR = '/data/darknet/python/20190517_image/'
GENE_XML_DIR = SEED_XML_DIR
# RT:RightTop 
# LB:LeftBottom 
# bbox: [xmin, xax, ymin, ymax]
def IOU(bbox_a, bbox_b):
    '''
    W = min(A.RT.x, B.RT.x) - max(A.LB.x, B.LB.x) 
    H = min(A.RT.y, B.RT.y) - max(A.LB.y, B.LB.y) 
    if W <= 0 or H <= 0: 
        return 0 
    SA = (A.RT.x - A.LB.x) * (A.RT.y - A.LB.y) 
    SB = (B.RT.x - B.LB.x) * (B.RT.y - B.LB.y) 
    cross = W * H return cross/(SA + SB - cross)
    '''
    W = min(bbox_a[1], bbox_b[1]) - max(bbox_a[0], bbox_b[0]) 
    H = min(bbox_a[3], bbox_b[3]) - max(bbox_a[2], bbox_b[2]) 
    if W <= 0 or H <= 0: 
        return 0
    SA = (bbox_a[1] - bbox_a[0]) * (bbox_a[3] - bbox_a[2]) 
    SB = (bbox_b[1] - bbox_b[0]) * (bbox_b[3] - bbox_b[2])  
    cross = W * H 
    return cross/(SA + SB - cross)

def get_obj_from_xml(xml):
    in_file = open(xml_name)
    tree=ET.parse(in_file)
    root = tree.getroot()
    return [obj for obj in root.iter('object')]

def get_obj_from_image_file(file, bbox):
    img = cv2.imread(file)
    img_obj = img[int(bbox[2]):int(bbox[3]), int(bbox[0]):int(bbox[1])]
    return img_obj

def get_bboxes_from_etree(etree):
    root = etree.getroot()  
    objects = root.findall('object')
    bboxes = []
    for obj in objects:
        xmlbox = obj.find('bndbox')
        b = [float(xmlbox.find('xmin').text), float(xmlbox.find('xmax').text), float(xmlbox.find('ymin').text), float(xmlbox.find('ymax').text)]
        bboxes.append(b)
    return bboxes

seed_xml_names = os.listdir(SEED_XML_DIR)
seed_xml_names.sort()
print(len(seed_xml_names))

#classes_ = ['bus', 'car', 'truck', 'motorbike', 'bicycle', 'person']
classes_ = ['motorbike', 'bicycle', 'person']
N = 0
for xml_name in seed_xml_names:   
    if(not xml_name.endswith('.xml')):
        continue
    #print(SEED_XML_DIR + xml_name)
    in_file = open(SEED_XML_DIR + xml_name)
    tree=ET.parse(in_file)

    root = tree.getroot()
    size = root.find('size')   
    boxes = []
    b = []  
    
    array_object = root.findall('object')
    for obj in array_object:
    '''
    ############################this section for remove small objs#############################################
        difficult = obj.find('difficult').text
        cls_ = obj.find('name').text
        if cls_ not in classes_ or int(difficult)==1:
            continue
        xmlbox = obj.find('bndbox')
        b = [float(xmlbox.find('xmin').text), float(xmlbox.find('xmax').text), float(xmlbox.find('ymin').text), float(xmlbox.find('ymax').text)]
        
        #filter size which smaller than 16X16 fit for SSD300
        bbox_width = b[1] - b[0]
        bbox_heigt = b[3] - b[2]
        
        if(not((bbox_width > 15 and bbox_heigt > 7) or (bbox_heigt > 15 and bbox_width > 7) or (bbox_width * bbox_heigt > 15*15))):
            print('remove:{0}:{1}'.format(bbox_width, bbox_heigt))
            root.remove(obj)
            N = N + 1
            continue 
    ##########################################################################################################
    '''
    ###########################this section for remove certain classes objs###################################
        cls_ = obj.find('name').text
        if cls_ not in classes_:
            continue
        root.remove(obj)
    
    tree.write(GENE_XML_DIR + xml_name)
print('removed {0} small objxml'.format(N))
# Out:
# 23172
# remove:7.0:17.0
# remove:7.0:18.0
# remove:5.0:42.0
# remove:7.0:18.0
# remove:6.0:17.0
# remove:7.0:19.0
# remove:6.0:17.0
# remove:6.0:23.0
# remove:5.0:18.0
# remove:4.0:17.0
# remove:3.0:20.0
# remove:4.0:18.0
# remove:7.0:18.0
# remove:6.0:18.0
# remove:6.0:17.0
# remove:5.0:17.0
# remove:5.0:18.0
# remove:3.0:19.0
# remove:6.0:19.0
# remove:5.0:21.0
# remove:5.0:17.0
# remove:6.0:22.0
# remove:3.0:22.0
# remove:6.0:19.0
# remove:5.0:20.0
# remove:3.0:18.0
# remove:5.0:17.0
# remove:6.0:19.0
# remove:5.0:17.0
# remove:6.0:19.0
# remove:6.0:18.0
# remove:5.0:17.0
# remove:6.0:17.0
# remove:5.0:18.0
# remove:7.0:21.0
# remove:7.0:18.0
# remove:7.0:23.0
# remove:7.0:17.0
# remove:7.0:18.0
# remove:5.0:22.0
# remove:6.0:18.0
# remove:4.0:19.0
# remove:7.0:17.0
# remove:5.0:31.0
# remove:7.0:19.0
# remove:7.0:23.0
# remove:6.0:21.0
# remove:7.0:19.0
# remove:7.0:22.0
# remove:7.0:17.0
# remove:7.0:20.0
# remove:6.0:20.0
# remove:7.0:19.0
# remove:7.0:18.0
# remove:7.0:18.0
# remove:7.0:21.0
# remove:7.0:17.0
# remove:7.0:17.0
# remove:7.0:19.0
# remove:7.0:18.0
# remove:4.0:22.0
# remove:7.0:24.0
# remove:3.0:22.0
# remove:7.0:25.0
# remove:6.0:17.0
# remove:7.0:25.0
# remove:5.0:18.0
# remove:5.0:24.0
# remove:4.0:44.0
# remove:6.0:36.0
# remove:7.0:18.0
# remove:6.0:18.0
# remove:7.0:17.0
# remove:7.0:17.0
# remove:5.0:19.0
# remove:5.0:19.0
# remove:6.0:19.0
# remove:6.0:23.0
# remove:7.0:17.0
# remove:6.0:23.0
# remove:5.0:24.0
# remove:7.0:23.0
# remove:7.0:22.0
# remove:7.0:22.0
# remove:7.0:18.0
# remove:6.0:22.0
# remove:6.0:19.0
# remove:7.0:20.0
# remove:7.0:19.0
# remove:7.0:22.0
# remove:7.0:19.0
# remove:7.0:17.0
# remove:6.0:18.0
# remove:7.0:18.0
# remove:7.0:20.0
# remove:7.0:19.0
# remove:6.0:19.0
# remove:7.0:18.0
# remove:7.0:18.0
# remove:7.0:20.0
# remove:7.0:19.0
# remove:7.0:17.0
# remove:7.0:17.0
# remove:6.0:18.0
# remove:7.0:19.0
# remove:7.0:18.0
# remove:6.0:17.0
# remove:7.0:17.0
# remove:7.0:19.0
# remove:7.0:20.0
# remove:7.0:18.0
# remove:7.0:18.0
# remove:7.0:18.0
# remove:6.0:17.0
# remove:6.0:17.0
# remove:7.0:19.0
# remove:7.0:19.0
# remove:7.0:18.0
# remove:7.0:18.0
# remove:7.0:17.0
# remove:7.0:19.0
# remove:7.0:17.0
# remove:7.0:18.0
# remove:7.0:17.0
# remove:7.0:18.0
# remove:6.0:20.0
# remove:7.0:18.0
# remove:5.0:20.0
# remove:6.0:17.0
# remove:6.0:19.0
# remove:6.0:18.0
# remove:6.0:20.0
# remove:6.0:17.0
# remove:6.0:18.0
# remove:6.0:17.0
# remove:7.0:19.0
# remove:4.0:17.0
# remove:7.0:20.0
# remove:7.0:18.0
# remove:7.0:22.0
# remove:7.0:17.0
# remove:7.0:21.0
# remove:7.0:18.0
# remove:7.0:20.0
# remove:21.0:6.0
# remove:7.0:18.0
# remove:7.0:21.0
# remove:6.0:18.0
# remove:7.0:19.0
# remove:7.0:17.0
# remove:7.0:20.0
# remove:19.0:5.0
# remove:7.0:17.0
# remove:6.0:18.0
# remove:5.0:19.0
# remove:7.0:17.0
# remove:7.0:19.0
# remove:6.0:17.0
# remove:7.0:17.0
# remove:6.0:17.0
# remove:7.0:17.0
# remove:7.0:19.0
# remove:6.0:18.0
# remove:7.0:17.0
# remove:7.0:19.0
# remove:6.0:18.0
# remove:6.0:17.0
# remove:5.0:17.0
# remove:6.0:17.0
# remove:6.0:18.0
# remove:7.0:17.0
# remove:7.0:21.0
# remove:7.0:21.0
# remove:7.0:17.0
# remove:7.0:17.0
# remove:6.0:17.0
# remove:5.0:17.0
# remove:6.0:18.0
# remove:5.0:19.0
# remove:6.0:20.0
# remove:7.0:19.0
# remove:7.0:18.0
# remove:7.0:17.0
# remove:6.0:20.0
# remove:5.0:21.0
# remove:7.0:17.0
# remove:6.0:21.0
# remove:6.0:19.0
# remove:7.0:19.0
# remove:5.0:19.0
# remove:6.0:19.0
# remove:7.0:22.0
# remove:7.0:18.0
# remove:7.0:17.0
# remove:6.0:21.0
# remove:7.0:18.0
# remove:6.0:17.0
# remove:7.0:17.0
# remove:6.0:18.0
# remove:6.0:24.0
# remove:7.0:18.0
# remove:7.0:18.0
# remove:20.0:7.0
# remove:7.0:20.0
# remove:6.0:20.0
# remove:19.0:7.0
# remove:18.0:6.0
# remove:7.0:19.0
# remove:7.0:18.0
# remove:7.0:17.0
# remove:6.0:17.0
# remove:6.0:17.0
# remove:4.0:19.0
# remove:7.0:21.0
# remove:7.0:18.0
# remove:7.0:19.0
# remove:7.0:20.0
# remove:7.0:18.0
# remove:3.0:19.0
# remove:7.0:19.0
# remove:7.0:18.0
# remove:6.0:18.0
# remove:7.0:18.0
# remove:3.0:17.0
# remove:7.0:17.0
# remove:7.0:17.0
# remove:7.0:17.0
# remove:7.0:18.0
# remove:7.0:20.0
# remove:6.0:19.0
# remove:7.0:26.0
# remove:6.0:24.0
# remove:6.0:21.0
# remove:6.0:29.0
# remove:5.0:38.0
# remove:6.0:17.0
# remove:6.0:18.0
# remove:7.0:23.0
# remove:5.0:18.0
# remove:6.0:17.0
# remove:7.0:17.0
# remove:6.0:23.0
# remove:6.0:26.0
# remove:7.0:19.0
# remove:4.0:25.0
# remove:6.0:24.0
# remove:5.0:27.0
# remove:3.0:34.0
# remove:7.0:20.0
# remove:7.0:18.0
# remove:6.0:22.0
# remove:22.0:7.0
# remove:7.0:17.0
# remove:7.0:22.0
# remove:7.0:24.0
# remove:7.0:23.0
# remove:7.0:18.0
# remove:22.0:7.0
# remove:6.0:25.0
# remove:17.0:7.0
# remove:7.0:19.0
# remove:24.0:6.0
# remove:5.0:18.0
# remove:21.0:7.0
# remove:7.0:17.0
# remove:18.0:6.0
# remove:22.0:5.0
# remove:19.0:4.0
# remove:6.0:18.0
# remove:7.0:18.0
# remove:7.0:19.0
# remove:7.0:17.0
# remove:6.0:18.0
# remove:7.0:17.0
# remove:6.0:17.0
# remove:5.0:17.0
# remove:6.0:17.0
# remove:7.0:18.0
# remove:6.0:17.0
# remove:7.0:19.0
# remove:7.0:18.0
# remove:7.0:23.0
# remove:7.0:22.0
# remove:7.0:21.0
# remove:7.0:20.0
# remove:7.0:20.0
# remove:5.0:23.0
# remove:6.0:17.0
# remove:7.0:17.0
# remove:4.0:25.0
# remove:5.0:23.0
# remove:6.0:23.0
# remove:7.0:17.0
# remove:7.0:18.0
# remove:7.0:18.0
# remove:7.0:18.0
# remove:7.0:19.0
# remove:7.0:18.0
# remove:5.0:24.0
# remove:7.0:17.0
# remove:6.0:22.0
# remove:7.0:18.0
# remove:7.0:17.0
# remove:7.0:21.0
# remove:7.0:18.0
# remove:7.0:20.0
# remove:6.0:17.0
# remove:7.0:18.0
# remove:6.0:17.0
# remove:7.0:18.0
# remove:7.0:17.0
# remove:7.0:18.0
# remove:7.0:20.0
# remove:7.0:17.0
# remove:7.0:17.0
# remove:7.0:18.0
# remove:7.0:17.0
# remove:6.0:18.0
# remove:6.0:18.0
# remove:7.0:17.0
# remove:7.0:20.0
# remove:6.0:17.0
# remove:5.0:26.0
# remove:7.0:20.0
# remove:5.0:25.0
# remove:7.0:20.0
# remove:7.0:24.0
# remove:7.0:22.0
# remove:7.0:29.0
# remove:3.0:32.0
# remove:6.0:19.0
# remove:7.0:17.0
# remove:6.0:17.0
# remove:7.0:18.0
# remove:7.0:18.0
# remove:6.0:18.0
# remove:28.0:6.0
# remove:7.0:17.0
# remove:7.0:18.0
# remove:6.0:17.0
# remove:6.0:17.0
# remove:7.0:19.0
# remove:7.0:22.0
# remove:6.0:20.0
# remove:7.0:17.0
# remove:4.0:26.0
# remove:7.0:21.0
# remove:7.0:18.0
# remove:18.0:7.0
# remove:6.0:20.0
# remove:7.0:21.0
# remove:7.0:20.0
# remove:6.0:21.0
# remove:5.0:21.0
# remove:7.0:19.0
# remove:7.0:19.0
# remove:7.0:18.0
# remove:7.0:22.0
# remove:7.0:17.0
# remove:7.0:23.0
# remove:7.0:19.0
# remove:7.0:18.0
# remove:7.0:21.0
# remove:7.0:21.0
# remove:7.0:18.0
# remove:7.0:17.0
# remove:7.0:17.0
# remove:7.0:22.0
# remove:7.0:23.0
# remove:7.0:24.0
# remove:7.0:23.0
# remove:7.0:23.0
# remove:7.0:21.0
# remove:7.0:24.0
# remove:7.0:23.0
# remove:7.0:26.0
# remove:7.0:22.0
# remove:7.0:21.0
# remove:7.0:25.0
# remove:7.0:25.0
# remove:7.0:26.0
# remove:7.0:18.0
# remove:7.0:19.0
# remove:6.0:20.0
# remove:6.0:17.0
# remove:7.0:17.0
# remove:6.0:17.0
# remove:7.0:18.0
# remove:7.0:17.0
# remove:6.0:19.0
# remove:6.0:23.0
# remove:7.0:19.0
# remove:6.0:18.0
# remove:7.0:21.0
# remove:6.0:20.0
# remove:6.0:20.0
# remove:6.0:19.0
# remove:7.0:19.0
# remove:6.0:18.0
# remove:3.0:30.0
# remove:7.0:19.0
# remove:3.0:57.0
# remove:3.0:61.0
# remove:3.0:53.0
# remove:4.0:53.0
# remove:5.0:17.0
# remove:6.0:18.0
# remove:4.0:24.0
# remove:7.0:18.0
# remove:6.0:17.0
# remove:5.0:18.0
# remove:7.0:20.0
# remove:6.0:21.0
# remove:6.0:17.0
# remove:7.0:19.0
# remove:7.0:23.0
# remove:7.0:20.0
# remove:6.0:18.0
# remove:5.0:22.0
# remove:6.0:22.0
# remove:7.0:20.0
# remove:7.0:17.0
# remove:7.0:18.0
# remove:7.0:18.0
# remove:7.0:20.0
# remove:7.0:17.0
# remove:7.0:17.0
# remove:7.0:22.0
# remove:7.0:19.0
# remove:7.0:19.0
# remove:6.0:19.0
# remove:7.0:22.0
# remove:7.0:21.0
# remove:7.0:18.0
# remove:7.0:22.0
# remove:7.0:20.0
# remove:6.0:17.0
# remove:7.0:17.0
# remove:6.0:20.0
# remove:7.0:19.0
# remove:6.0:20.0
# remove:7.0:20.0
# remove:7.0:23.0
# remove:7.0:20.0
# remove:6.0:19.0
# remove:6.0:21.0
# remove:7.0:20.0
# remove:7.0:21.0
# remove:7.0:21.0
# remove:7.0:20.0
# remove:7.0:24.0
# remove:7.0:18.0
# remove:7.0:19.0
# remove:7.0:19.0
# remove:7.0:20.0
# remove:6.0:19.0
# remove:6.0:18.0
# remove:6.0:18.0
# remove:7.0:19.0
# remove:7.0:20.0
# remove:7.0:17.0
# remove:7.0:19.0
# remove:7.0:19.0
# remove:7.0:19.0
# remove:6.0:18.0
# remove:7.0:17.0
# remove:7.0:19.0
# remove:7.0:18.0
# remove:5.0:18.0
# remove:7.0:19.0
# remove:7.0:20.0
# remove:6.0:19.0
# remove:6.0:17.0
# remove:6.0:17.0
# remove:7.0:17.0
# remove:6.0:19.0
# remove:5.0:21.0
# remove:4.0:21.0
# remove:7.0:17.0
# remove:6.0:17.0
# remove:6.0:18.0
# remove:7.0:18.0
# remove:7.0:18.0
# remove:7.0:19.0
# remove:7.0:18.0
# remove:7.0:21.0
# remove:6.0:19.0
# remove:5.0:19.0
# remove:7.0:17.0
# remove:4.0:24.0
# remove:5.0:23.0
# remove:4.0:22.0
# remove:7.0:19.0
# remove:7.0:18.0
# remove:7.0:18.0
# remove:6.0:17.0
# remove:7.0:17.0
# remove:7.0:17.0
# remove:7.0:18.0
# remove:7.0:18.0
# remove:7.0:20.0
# remove:7.0:19.0
# remove:7.0:17.0
# remove:7.0:18.0
# remove:7.0:18.0
# remove:7.0:21.0
# remove:7.0:21.0
# remove:7.0:19.0
# remove:7.0:19.0
# remove:6.0:18.0
# remove:7.0:20.0
# remove:7.0:17.0
# remove:6.0:18.0
# remove:7.0:21.0
# remove:7.0:18.0
# remove:7.0:17.0
# remove:7.0:18.0
# remove:7.0:17.0
# remove:7.0:17.0
# remove:7.0:18.0
# remove:7.0:18.0
# remove:7.0:19.0
# remove:7.0:24.0
# remove:7.0:17.0
# remove:6.0:19.0
# remove:7.0:17.0
# remove:7.0:19.0
# remove:7.0:20.0
# remove:7.0:19.0
# remove:7.0:21.0
# remove:7.0:21.0
# remove:6.0:18.0
# remove:7.0:18.0
# remove:7.0:17.0
# remove:7.0:17.0
# remove:6.0:18.0
# remove:6.0:17.0
# remove:7.0:18.0
# remove:7.0:18.0
# remove:6.0:18.0
# remove:7.0:20.0
# remove:6.0:17.0
# remove:7.0:18.0
# remove:6.0:19.0
# remove:7.0:17.0
# remove:7.0:19.0
# remove:7.0:18.0
# remove:7.0:17.0
# remove:6.0:18.0
# remove:6.0:17.0
# remove:6.0:18.0
# remove:7.0:17.0
# remove:4.0:23.0
# remove:5.0:19.0
# remove:4.0:20.0
# remove:6.0:21.0
# remove:7.0:19.0
# remove:7.0:17.0
# remove:7.0:21.0
# remove:7.0:17.0
# remove:7.0:22.0
# remove:6.0:18.0
# remove:7.0:17.0
# remove:7.0:22.0
# remove:7.0:17.0
# remove:7.0:20.0
# remove:7.0:18.0
# remove:7.0:21.0
# remove:7.0:17.0
# remove:7.0:20.0
# remove:3.0:25.0
# remove:7.0:19.0
# remove:7.0:17.0
# remove:7.0:17.0
# remove:6.0:17.0
# remove:6.0:17.0
# remove:6.0:18.0
# remove:6.0:17.0
# remove:7.0:25.0
# remove:7.0:25.0
# remove:7.0:21.0
# remove:7.0:24.0
# remove:7.0:24.0
# remove:7.0:22.0
# remove:7.0:24.0
# remove:7.0:24.0
# remove:7.0:22.0
# remove:7.0:20.0
# remove:6.0:18.0
# remove:7.0:19.0
# remove:7.0:19.0
# remove:7.0:20.0
# remove:7.0:17.0
# remove:7.0:18.0
# remove:7.0:18.0
# remove:7.0:17.0
# remove:7.0:17.0
# remove:6.0:18.0
# remove:7.0:18.0
# remove:7.0:22.0
# remove:7.0:17.0
# remove:5.0:18.0
# remove:7.0:17.0
# remove:6.0:17.0
# remove:7.0:18.0
# remove:7.0:17.0
# remove:7.0:19.0
# remove:7.0:20.0
# remove:6.0:18.0
# remove:6.0:20.0
# remove:7.0:22.0
# remove:7.0:20.0
# remove:7.0:17.0
# remove:7.0:19.0
# remove:7.0:17.0
# remove:7.0:18.0
# remove:7.0:19.0
# remove:6.0:17.0
# remove:7.0:17.0
# remove:7.0:20.0
# remove:6.0:18.0
# remove:7.0:18.0
# remove:6.0:17.0
# remove:7.0:19.0
# remove:7.0:22.0
# remove:7.0:17.0
# remove:7.0:22.0
# remove:7.0:19.0
# remove:7.0:23.0
# remove:7.0:17.0
# remove:7.0:18.0
# remove:6.0:36.0
# remove:7.0:17.0
# remove:7.0:17.0
# remove:7.0:17.0
# remove:7.0:19.0
# remove:7.0:17.0
# remove:7.0:18.0
# remove:7.0:18.0
# remove:6.0:18.0
# remove:7.0:18.0
# remove:6.0:17.0
# remove:7.0:19.0
# remove:7.0:19.0
# remove:7.0:19.0
# remove:7.0:19.0
# remove:7.0:17.0
# remove:7.0:18.0
# remove:7.0:19.0
# remove:7.0:17.0
# remove:7.0:21.0
# remove:7.0:21.0
# remove:7.0:21.0
# remove:6.0:20.0
# remove:5.0:26.0
# remove:7.0:19.0
# remove:7.0:21.0
# remove:7.0:25.0
# remove:7.0:25.0
# remove:7.0:23.0
# remove:7.0:23.0
# remove:5.0:23.0
# remove:4.0:23.0
# remove:5.0:23.0
# remove:4.0:24.0
# remove:5.0:21.0
# remove:6.0:19.0
# remove:7.0:17.0
# remove:3.0:25.0
# removed 669 small objxml

# %%
# Out:
# 0
